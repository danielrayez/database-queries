# %%
import requests

# %%
pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\danie\anaconda3\lib\site-packages (4.8.2)
# Requirement already satisfied: soupsieve>=1.2 in c:\users\danie\anaconda3\lib\site-packages (from beautifulsoup4) (1.9.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# ['https://www.resultados-futbol.com/Metropolitanos',
#  'https://www.resultados-futbol.com/Monagas-Sc',
#  'https://www.resultados-futbol.com/Zamora-Cf',
#  'https://www.resultados-futbol.com/Deportivo-Tachira-Fc',
#  'https://www.resultados-futbol.com/Deportivo-La-Guaira',
#  'https://www.resultados-futbol.com/Estudiantes-Merida-Fc',
#  'https://www.resultados-futbol.com/Portuguesa-Fc',
#  'https://www.resultados-futbol.com/Caracas-Venezuela',
#  'https://www.resultados-futbol.com/Carabobo',
#  'https://www.resultados-futbol.com/Cd-Hermanos-Colmenarez',
#  'https://www.resultados-futbol.com/Zulia-Fc',
#  'https://www.resultados-futbol.com/Academia-Puerto-Cabello',
#  'https://www.resultados-futbol.com/Mineros-Guayana',
#  'https://www.resultados-futbol.com/Ucv',
#  'https://www.resultados-futbol.com/Aragua-Fc',
#  'https://www.resultados-futbol.com/Deportivo-Lara']

# %%
url = 'https://www.resultados-futbol.com/Deportivo-Lara'
r = requests.get(url)
ccs_soup = BeautifulSoup(r.text, 'lxml')

# %%
tabla_plantilla = ccs_soup.find('table', attrs={'class':'sdata_table'})

# %%
lista_cruda_plantilla = ccs_soup.find_all('tr', attrs= {'itemprop':'employee'})

# %%
#EXTRAER NOMBRE
nombre = lista_cruda_plantilla[19].find('span').text

nombre
# Out:
# 'J. Rodriguez'

# %%
#EXTRAER NUMERO EN EL EQUIPO

numero_jugador = lista_cruda_plantilla[0].find('td', attrs= {"class":"num"}).text
numero_jugador
# Out:
# '12'

# %%
# EXTRACCIÓN DE LA EDAD

edad_jugador = lista_cruda_plantilla[0].find('td', attrs={'itemprop':"birthDate"}).text
edad_jugador
# Out:
# '27'

# %%
#EXTRACCION DE LA PROCEDENCIA (PAÍS)

tag_nacionalidad = lista_cruda_plantilla[19].find('td', attrs= {'itemprop':'nationality'})
str_nacionalidad = str(tag_nacionalidad)

nacionalidad = str_nacionalidad[104:106]
nacionalidad
# Out:
# 'PA'

# %%
# EXTRACCIÓN DEL PESO Y LA ALTURA. 1ER PASO

altura_peso = lista_cruda_plantilla[0].find_all('td', attrs= {'class':'dat'}, limit=2)
altura_peso
# Out:
# [<td class="dat">-</td>, <td class="dat">-</td>]

# %%
# EXTRACCION DE LA ALTURA
altura= altura_peso[0].text
altura
# Out:
# '-'

# %%
# EXTRACCION DEL PESO
peso= altura_peso[1].text
peso
# Out:
# '-'

# %%
# EXTRACCION DE POSICIÓN DE UN ATRIBUTO COLSPAN

posicion = lista_cruda_plantilla[0].find_previous_sibling('tr', attrs = {'class':'first-child'}).get_text(strip = True)
posicion
# Out:
# 'Portero'

# %%
#PREVISUALIZACIÓN DE LA LISTA DE DATOS DEL JUGADOR
datos_jugador = [nombre, edad_jugador, nacionalidad, altura, peso]
datos_jugador
# Out:
# ['J. Rodriguez', '27', 'PA', '-', '-']

# %%
#BUCLE DE EXTRACCION DE DATOS CON CICLO FOR
plantilla = []

contador = 0
for item in lista_cruda_plantilla:
    
    #posicion
    posicion = lista_cruda_plantilla[contador].find_previous_sibling('tr', attrs = {'class':'first-child'}).get_text(strip = True)
    #nombre
    nombre = lista_cruda_plantilla[contador].find('span').text
    #numero
    numero_jugador = lista_cruda_plantilla[contador].find('td', attrs= {"class":"num"}).text
    #edad
    edad_jugador = lista_cruda_plantilla[contador].find('td', attrs={'itemprop':"birthDate"}).text
    #nacionalidad
    tag_nacionalidad = lista_cruda_plantilla[contador].find('td', attrs= {'itemprop':'nationality'})
    str_nacionalidad = str(tag_nacionalidad)
    nacionalidad = str_nacionalidad[104:106]
    #Altura y peso
    altura_peso = lista_cruda_plantilla[contador].find_all('td', attrs= {'class':'dat'}, limit=2)
    altura= altura_peso[0].text
    peso= altura_peso[1].text

    #agregar nuevo elemento a la lista
    plantilla.append(numero_jugador)
    plantilla.append(posicion)
    plantilla.append(nombre)
    plantilla.append(edad_jugador)
    plantilla.append(nacionalidad)
    plantilla.append(altura)
    plantilla.append(peso)
    
    contador = contador +1

# %%
#VISTA DE LA PLANTILLA COMO DATOS CRUDOS
plantilla
# Out:
# ['12',
#  'Portero',
#  'J. Ambuila',
#  '27',
#  'VE',
#  '-',
#  '-',
#  '25',
#  'Portero',
#  'L. Curiel',
#  '32',
#  'VE',
#  '186',
#  '79',
#  '24',
#  'Defensa',
#  'A. RodrÃ\xadguez',
#  '18',
#  'VE',
#  '176',
#  '68',
#  '14',
#  'Defensa',
#  'C. RodrÃ\xadguez',
#  '24',
#  'VE',
#  '182',
#  '77',
#  '2',
#  'Defensa',
#  'D. MeleÃ¡n',
#  '30',
#  'VE',
#  '177',
#  '72',
#  '33',
#  'Defensa',
#  'H. Maestre',
#  '21',
#  'VE',
#  '184',
#  '70',
#  '13',
#  'Defensa',
#  'H. PernÃ\xada',
#  '31',
#  'VE',
#  '185',
#  '76',
#  '3',
#  'Defensa',
#  'I. Anzola',
#  '22',
#  'VE',
#  '181',
#  '77',
#  '80',
#  'Defensa',
#  'M. Granados',
#  '33',
#  'VE',
#  '172',
#  '71',
#  '34',
#  'Defensa',
#  'MoisÃ©s GonzÃ¡lez',
#  '22',
#  'VE',
#  '175',
#  '68',
#  '17',
#  'Defensa',
#  'R. Chirinos',
#  '26',
#  'VE',
#  '174',
#  '71',
#  '29',
#  'Defensa',
#  'S. Bustos',
#  '24',
#  'AR',
#  '175',
#  '-',
#  '23',
#  'Centrocampista',
#  'A. Flores',
#  '33',
#  'VE',
#  '179',
#  '73',
#  '8',
#  'Centrocampista',
#  'AristÃ³teles Romero',
#  '26',
#  'VE',
#  '184',
#  '84',
#  '5',
#  'Centrocampista',
#  'B. Manzano',
#  '32',
#  'VE',
#  '172',
#  '76',
#  '8',
#  'Centrocampista',
#  'C. Ramos',
#  '23',
#  'VE',
#  '177',
#  '70',
#  '15',
#  'Centrocampista',
#  'D. Rodriguez',
#  '28',
#  'VE',
#  '178',
#  '70',
#  '10',
#  'Centrocampista',
#  'J. Infante',
#  '29',
#  'VE',
#  '177',
#  '62',
#  '11',
#  'Centrocampista',
#  'J. Moreno',
#  '31',
#  'VE',
#  '170',
#  '69',
#  '27',
#  'Centrocampista',
#  'J. Rodriguez',
#  '27',
#  'PA',
#  '177',
#  '66',
#  '18',
#  'Centrocampista',
#  'J. Silva',
#  '21',
#  'VE',
#  '172',
#  '68',
#  '32',
#  'Centrocampista',
#  'JosÃ© Montilla',
#  '18',
#  'VE',
#  '174',
#  '70',
#  '30',
#  'Centrocampista',
#  'Luis Urbina',
#  '20',
#  'VE',
#  '174',
#  '68',
#  '28',
#  'Centrocampista',
#  'M. Palma',
#  '22',
#  'VE',
#  '168',
#  '63',
#  '6',
#  'Centrocampista',
#  'T. Segovia',
#  '19',
#  'VE',
#  '172',
#  '72',
#  '20',
#  'Delantero',
#  'A. Perugini',
#  '23',
#  'VE',
#  '-',
#  '-',
#  '9',
#  'Delantero',
#  'B. Castillo',
#  '21',
#  'VE',
#  '186',
#  '70',
#  '27',
#  'Delantero',
#  'E. Espinosa',
#  '26',
#  'CO',
#  '176',
#  '64',
#  '10',
#  'Delantero',
#  'F. Vargas',
#  '23',
#  'VE',
#  '178',
#  '72',
#  '21',
#  'Delantero',
#  'J. Arrieche',
#  '30',
#  'VE',
#  '176',
#  '74',
#  '19',
#  'Delantero',
#  'J. Castillo',
#  '19',
#  'VE',
#  '168',
#  '66',
#  '16',
#  'Delantero',
#  'L. Martell',
#  '27',
#  'VE',
#  '175',
#  '71',
#  '26',
#  'Delantero',
#  'L. MartÃ\xadnez',
#  '24',
#  'CL',
#  '-',
#  '-',
#  '7',
#  'Delantero',
#  'R. Rojas',
#  '30',
#  'VE',
#  '178',
#  '79',
#  '23',
#  'Delantero',
#  'T. BrandÃ£o',
#  '23',
#  'BR',
#  '191',
#  '-',
#  '31',
#  'Delantero',
#  'W. Virguez',
#  '21',
#  'VE',
#  '170',
#  '-',
#  '29',
#  'Delantero',
#  'Yanowsky Reyes',
#  '27',
#  'VE',
#  '163',
#  '50']

# %%
# SEPARANDO LA LISTA EN SUBLISTAS POR JUGADOR
n=7

plantilla_final =[plantilla[i:i + n] for i in range(0, len(plantilla), 
                                                    n)]
plantilla_final
# Out:
# [['12', 'Portero', 'J. Ambuila', '27', 'VE', '-', '-'],
#  ['25', 'Portero', 'L. Curiel', '32', 'VE', '186', '79'],
#  ['24', 'Defensa', 'A. RodrÃ\xadguez', '18', 'VE', '176', '68'],
#  ['14', 'Defensa', 'C. RodrÃ\xadguez', '24', 'VE', '182', '77'],
#  ['2', 'Defensa', 'D. MeleÃ¡n', '30', 'VE', '177', '72'],
#  ['33', 'Defensa', 'H. Maestre', '21', 'VE', '184', '70'],
#  ['13', 'Defensa', 'H. PernÃ\xada', '31', 'VE', '185', '76'],
#  ['3', 'Defensa', 'I. Anzola', '22', 'VE', '181', '77'],
#  ['80', 'Defensa', 'M. Granados', '33', 'VE', '172', '71'],
#  ['34', 'Defensa', 'MoisÃ©s GonzÃ¡lez', '22', 'VE', '175', '68'],
#  ['17', 'Defensa', 'R. Chirinos', '26', 'VE', '174', '71'],
#  ['29', 'Defensa', 'S. Bustos', '24', 'AR', '175', '-'],
#  ['23', 'Centrocampista', 'A. Flores', '33', 'VE', '179', '73'],
#  ['8', 'Centrocampista', 'AristÃ³teles Romero', '26', 'VE', '184', '84'],
#  ['5', 'Centrocampista', 'B. Manzano', '32', 'VE', '172', '76'],
#  ['8', 'Centrocampista', 'C. Ramos', '23', 'VE', '177', '70'],
#  ['15', 'Centrocampista', 'D. Rodriguez', '28', 'VE', '178', '70'],
#  ['10', 'Centrocampista', 'J. Infante', '29', 'VE', '177', '62'],
#  ['11', 'Centrocampista', 'J. Moreno', '31', 'VE', '170', '69'],
#  ['27', 'Centrocampista', 'J. Rodriguez', '27', 'PA', '177', '66'],
#  ['18', 'Centrocampista', 'J. Silva', '21', 'VE', '172', '68'],
#  ['32', 'Centrocampista', 'JosÃ© Montilla', '18', 'VE', '174', '70'],
#  ['30', 'Centrocampista', 'Luis Urbina', '20', 'VE', '174', '68'],
#  ['28', 'Centrocampista', 'M. Palma', '22', 'VE', '168', '63'],
#  ['6', 'Centrocampista', 'T. Segovia', '19', 'VE', '172', '72'],
#  ['20', 'Delantero', 'A. Perugini', '23', 'VE', '-', '-'],
#  ['9', 'Delantero', 'B. Castillo', '21', 'VE', '186', '70'],
#  ['27', 'Delantero', 'E. Espinosa', '26', 'CO', '176', '64'],
#  ['10', 'Delantero', 'F. Vargas', '23', 'VE', '178', '72'],
#  ['21', 'Delantero', 'J. Arrieche', '30', 'VE', '176', '74'],
#  ['19', 'Delantero', 'J. Castillo', '19', 'VE', '168', '66'],
#  ['16', 'Delantero', 'L. Martell', '27', 'VE', '175', '71'],
#  ['26', 'Delantero', 'L. MartÃ\xadnez', '24', 'CL', '-', '-'],
#  ['7', 'Delantero', 'R. Rojas', '30', 'VE', '178', '79'],
#  ['23', 'Delantero', 'T. BrandÃ£o', '23', 'BR', '191', '-'],
#  ['31', 'Delantero', 'W. Virguez', '21', 'VE', '170', '-'],
#  ['29', 'Delantero', 'Yanowsky Reyes', '27', 'VE', '163', '50']]

# %%
#PRESENTACIÓN DE PLANTILLA COMO DATAFRAME
import pandas as pd

plantilla_df = pd.DataFrame(plantilla_final)
plantilla_df
# Out:
#      0               1                    2   3   4    5   6
# 0   12         Portero           J. Ambuila  27  VE    -   -
# 1   25         Portero            L. Curiel  32  VE  186  79
# 2   24         Defensa        A. RodrÃ­guez  18  VE  176  68
# 3   14         Defensa        C. RodrÃ­guez  24  VE  182  77
# 4    2         Defensa           D. MeleÃ¡n  30  VE  177  72
# 5   33         Defensa           H. Maestre  21  VE  184  70
# 6   13         Defensa           H. PernÃ­a  31  VE  185  76
# 7    3         Defensa            I. Anzola  22  VE  181  77
# 8   80         Defensa          M. Granados  33  VE  172  71
# 9   34         Defensa    MoisÃ©s GonzÃ¡lez  22  VE  175  68
# 10  17         Defensa          R. Chirinos  26  VE  174  71
# 11  29         Defensa            S. Bustos  24  AR  175   -
# 12  23  Centrocampista            A. Flores  33  VE  179  73
# 13   8  Centrocampista  AristÃ³teles Romero  26  VE  184  84
# 14   5  Centrocampista           B. Manzano  32  VE  172  76
# 15   8  Centrocampista             C. Ramos  23  VE  177  70
# 16  15  Centrocampista         D. Rodriguez  28  VE  178  70
# 17  10  Centrocampista           J. Infante  29  VE  177  62
# 18  11  Centrocampista            J. Moreno  31  VE  170  69
# 19  27  Centrocampista         J. Rodriguez  27  PA  177  66
# 20  18  Centrocampista             J. Silva  21  VE  172  68
# 21  32  Centrocampista       JosÃ© Montilla  18  VE  174  70
# 22  30  Centrocampista          Luis Urbina  20  VE  174  68
# 23  28  Centrocampista             M. Palma  22  VE  168  63
# 24   6  Centrocampista           T. Segovia  19  VE  172  72
# 25  20       Delantero          A. Perugini  23  VE    -   -
# 26   9       Delantero          B. Castillo  21  VE  186  70
# 27  27       Delantero          E. Espinosa  26  CO  176  64
# 28  10       Delantero            F. Vargas  23  VE  178  72
# 29  21       Delantero          J. Arrieche  30  VE  176  74
# 30  19       Delantero          J. Castillo  19  VE  168  66
# 31  16       Delantero           L. Martell  27  VE  175  71
# 32  26       Delantero         L. MartÃ­nez  24  CL    -   -
# 33   7       Delantero             R. Rojas  30  VE  178  79
# 34  23       Delantero          T. BrandÃ£o  23  BR  191   -
# 35  31       Delantero           W. Virguez  21  VE  170   -
# 36  29       Delantero       Yanowsky Reyes  27  VE  163  50

# %%
#RENOMBRE DE LAS COLUMNAS
plantilla_df.columns= ['numero','posicion','nombre','edad','nacionalidad','altura','peso']
plantilla_df
# Out:
#    numero        posicion               nombre edad nacionalidad altura peso
# 0      12         Portero           J. Ambuila   27           VE      -    -
# 1      25         Portero            L. Curiel   32           VE    186   79
# 2      24         Defensa        A. RodrÃ­guez   18           VE    176   68
# 3      14         Defensa        C. RodrÃ­guez   24           VE    182   77
# 4       2         Defensa           D. MeleÃ¡n   30           VE    177   72
# 5      33         Defensa           H. Maestre   21           VE    184   70
# 6      13         Defensa           H. PernÃ­a   31           VE    185   76
# 7       3         Defensa            I. Anzola   22           VE    181   77
# 8      80         Defensa          M. Granados   33           VE    172   71
# 9      34         Defensa    MoisÃ©s GonzÃ¡lez   22           VE    175   68
# 10     17         Defensa          R. Chirinos   26           VE    174   71
# 11     29         Defensa            S. Bustos   24           AR    175    -
# 12     23  Centrocampista            A. Flores   33           VE    179   73
# 13      8  Centrocampista  AristÃ³teles Romero   26           VE    184   84
# 14      5  Centrocampista           B. Manzano   32           VE    172   76
# 15      8  Centrocampista             C. Ramos   23           VE    177   70
# 16     15  Centrocampista         D. Rodriguez   28           VE    178   70
# 17     10  Centrocampista           J. Infante   29           VE    177   62
# 18     11  Centrocampista            J. Moreno   31           VE    170   69
# 19     27  Centrocampista         J. Rodriguez   27           PA    177   66
# 20     18  Centrocampista             J. Silva   21           VE    172   68
# 21     32  Centrocampista       JosÃ© Montilla   18           VE    174   70
# 22     30  Centrocampista          Luis Urbina   20           VE    174   68
# 23     28  Centrocampista             M. Palma   22           VE    168   63
# 24      6  Centrocampista           T. Segovia   19           VE    172   72
# 25     20       Delantero          A. Perugini   23           VE      -    -
# 26      9       Delantero          B. Castillo   21           VE    186   70
# 27     27       Delantero          E. Espinosa   26           CO    176   64
# 28     10       Delantero            F. Vargas   23           VE    178   72
# 29     21       Delantero          J. Arrieche   30           VE    176   74
# 30     19       Delantero          J. Castillo   19           VE    168   66
# 31     16       Delantero           L. Martell   27           VE    175   71
# 32     26       Delantero         L. MartÃ­nez   24           CL      -    -
# 33      7       Delantero             R. Rojas   30           VE    178   79
# 34     23       Delantero          T. BrandÃ£o   23           BR    191    -
# 35     31       Delantero           W. Virguez   21           VE    170    -
# 36     29       Delantero       Yanowsky Reyes   27           VE    163   50

# %%
plantilla_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   numero        37 non-null     object
#  1   posicion      37 non-null     object
#  2   nombre        37 non-null     object
#  3   edad          37 non-null     object
#  4   nacionalidad  37 non-null     object
#  5   altura        37 non-null     object
#  6   peso          37 non-null     object
# dtypes: object(7)
# memory usage: 2.1+ KB

# %% [markdown]
# #### cambiando el tipo de datos a las columnas numericas

# %%
plantilla_df['altura'] = pd.to_numeric(plantilla_df['altura'], errors= 'coerce')

# %%
plantilla_df['edad'] = pd.to_numeric(plantilla_df['edad'], errors= 'coerce')

# %%
plantilla_df['peso'] = pd.to_numeric(plantilla_df['peso'], errors= 'coerce')

# %%
plantilla_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   numero        37 non-null     object
#  1   posicion      37 non-null     object
#  2   nombre        37 non-null     object
#  3   edad          37 non-null     int64
#  4   nacionalidad  37 non-null     object
#  5   altura        34 non-null     float64
#  6   peso          31 non-null     float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 2.1+ KB

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\danie\anaconda3\lib\site-packages (3.0.3)
# Requirement already satisfied: jdcal in c:\users\danie\anaconda3\lib\site-packages (from openpyxl) (1.4.1)
# Requirement already satisfied: et-xmlfile in c:\users\danie\anaconda3\lib\site-packages (from openpyxl) (1.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Exporto a CSV
with pd.ExcelWriter('Plantilla-LigaFutve-2022-2.xlsx', mode='a', engine ='openpyxl') as writer:
    plantilla_df.to_excel(writer, sheet_name='Lara')
