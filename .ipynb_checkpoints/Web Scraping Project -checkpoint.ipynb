# %%
import requests

# %%
pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\danie\anaconda3\lib\site-packages (4.8.2)
# Requirement already satisfied: soupsieve>=1.2 in c:\users\danie\anaconda3\lib\site-packages (from beautifulsoup4) (1.9.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup

# %%
#VOY A EXTRAER LA LISTA DE JUGADORES DEL EQUIPO CARACAS FC, LIMPIANDO Y ORGANIZANDO LOS DATOS HASTA PRESENTARLOS COMO UN DATA FRAME
url = 'https://www.resultados-futbol.com/Caracas-Venezuela'
url
# Out:
# 'https://www.resultados-futbol.com/Caracas-Venezuela'

# %%
r = requests.get(url)
r
# Out:
# <Response [200]>

# %%
r.text
# Out:
# 'ï»¿<!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 Transitional//EN" "https://www.w3.org/TR/xhtml1/DTD/xhtml1-transitional.dtd">\n<html xmlns="https://www.w3.org/1999/xhtml" xmlns:fb="https://www.facebook.com/2008/fbml" xml:lang="es" lang="es">\n<!-- PRODUCTION | NOT RENEW MEM\t| 1657829263 -->\n<head>\n<meta description="www.resultados-futbol.com/Caracas-Venezuela-181.130.10.164">\n\t<title>Caracas - Copa Libertadores  G 2</title>\n\t<meta http-equiv="Content-Type"  content="text/html; charset=utf-8" />\n\t<meta name="description" content="Plantilla Caracas: " />\n\t<meta name="keywords" content="resultados de futbol, primera division, segunda division, segunda b, tercera division, barcelona, real madrid, futbol, resultados, goles, jugadores, pplantillas">\n\t<meta name="apple-itunes-app" content="app-id=550928207">\n\t<meta name="google-play-app" content="app-id=com.resultadosfutbol.mobile">\n\t<meta name="verify-v1" content="J7YUFA5i8BiSLSb9d1KxXBpiMo91bb7C44CBsT78920=" />\n\t<meta http-equiv="Content-Style-Type" content="text/css" />\n\n\t<meta name="inmobi-site-verification" content="e5d5f91fdb693e94f895e44542511f08" />\n\n\t\n\t\n\t\t\t<meta name="robots" content="index, follow" />\n\t\n\t\n\t\t\t\t\t\t\t<meta http-equiv="refresh" content="300" />\n\t\t\t\t\t\t\n\t\n\t<link rel="search" type="application/opensearchdescription+xml" title="Buscador de resultados-Futbol.com" href="/media/osearch/osearch_es.xml" />\n\n\t<!-- android -->\n\t<link rel="apple-touch-icon-precomposed" href="https://t.resfu.com/media/images/favicon-152.png" />\n\t<!-- internet explorer y metro -->\n\t<meta name="msapplication-TileColor" content="#FFFFFF" />\n\t<meta name="msapplication-TileImage" content="https://t.resfu.com/media/images/favicon2-144.png" />\n\t<!-- apple -->\n\t<link rel="apple-touch-icon-precomposed" sizes="152x152" href="https://t.resfu.com/media/images/favicon-152.png" />\n\t<link rel="apple-touch-icon-precomposed" sizes="144x144" href="https://t.resfu.com/media/images/favicon-144.png" />\n\t<link rel="apple-touch-icon-precomposed" sizes="120x120" href="https://t.resfu.com/media/images/favicon-120.png" />\n\t<link rel="apple-touch-icon-precomposed" sizes="114x114" href="https://t.resfu.com/media/images/favicon-114.png" />\n\t<link rel="apple-touch-icon-precomposed" sizes="72x72" href="https://t.resfu.com/media/images/favicon-72.png" />\n\t<link rel="apple-touch-icon-precomposed" href="https://t.resfu.com/media/images/favicon-57.png" />\n\t<!-- otros -->\n\t<link rel="shortcut icon" href="/media/images/favicon.ico?v=2" />\n\t<link rel="icon" sizes="16x16 32x32" href="/media/images/favicon.ico?v=2" />\n\n\n<!-- PIXEL BESOCY -->\n\n<script>\n(function(d,s,id,h,t){\n   var js,r,djs = d.getElementsByTagName(s)[0];\n   if (d.getElementById(id)) {return;}\n   js = d.createElement(\'script\');js.id =id;js.async=1;\n   js.h=h;js.t=t;\n   r=encodeURI(btoa(d.referrer));\n   js.src="//"+h+"/pixel/js/"+t+"/"+r;\n   djs.parentNode.insertBefore(js, djs);\n  }(document, \'script\', \'dogtrack-pixel\',\'beso.spxl.socy.es\', \'BESO_923_842_998\'));\n</script>\n\n<!-- * end pixel Besocy * -->\n\n<!-- Start Alexa Certify Javascript -->\n<script type="text/javascript">\n_atrk_opts = { atrk_acct:"jrzPh1aon800EO", domain:"resultados-futbol.com",dynamic: true};\n(function() { var as = document.createElement(\'script\'); as.type = \'text/javascript\'; as.async = true; as.src = "https://certify-js.alexametrics.com/atrk.js"; var s = document.getElementsByTagName(\'script\')[0];s.parentNode.insertBefore(as, s); })();\n</script>\n<noscript><img src="https://certify.alexametrics.com/atrk.gif?account=jrzPh1aon800EO" style="display:none" height="1" width="1" alt="" /></noscript>\n<!-- End Alexa Certify Javascript -->\n\n\n<!-- Quantcast Choice. Consent Manager Tag v2.0 (for TCF 2.0) -->\n<script type="text/javascript" async=true>\n(function() {\n  var host = window.location.hostname;\n  var element = document.createElement(\'script\');\n  var firstScript = doc ...

# %%
ccs_soup = BeautifulSoup(r.text, 'lxml')
print(ccs_soup.prettify())
# Out:
# <html>
#  <body>
#   <p>
#    ï»¿
#    <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 Transitional//EN" "https://www.w3.org/TR/xhtml1/DTD/xhtml1-transitional.dtd">
#    <!-- PRODUCTION | NOT RENEW MEM	| 1657829263 -->
#   </p>
#   <meta description="www.resultados-futbol.com/Caracas-Venezuela-181.130.10.164"/>
#   <title>
#    Caracas - Copa Libertadores  G 2
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="Plantilla Caracas: " name="description"/>
#   <meta content="resultados de futbol, primera division, segunda division, segunda b, tercera division, barcelona, real madrid, futbol, resultados, goles, jugadores, pplantillas" name="keywords"/>
#   <meta content="app-id=550928207" name="apple-itunes-app"/>
#   <meta content="app-id=com.resultadosfutbol.mobile" name="google-play-app"/>
#   <meta content="J7YUFA5i8BiSLSb9d1KxXBpiMo91bb7C44CBsT78920=" name="verify-v1"/>
#   <meta content="text/css" http-equiv="Content-Style-Type"/>
#   <meta content="e5d5f91fdb693e94f895e44542511f08" name="inmobi-site-verification"/>
#   <meta content="index, follow" name="robots"/>
#   <meta content="300" http-equiv="refresh"/>
#   <link href="/media/osearch/osearch_es.xml" rel="search" title="Buscador de resultados-Futbol.com" type="application/opensearchdescription+xml"/>
#   <!-- android -->
#   <link href="https://t.resfu.com/media/images/favicon-152.png" rel="apple-touch-icon-precomposed"/>
#   <!-- internet explorer y metro -->
#   <meta content="#FFFFFF" name="msapplication-TileColor"/>
#   <meta content="https://t.resfu.com/media/images/favicon2-144.png" name="msapplication-TileImage"/>
#   <!-- apple -->
#   <link href="https://t.resfu.com/media/images/favicon-152.png" rel="apple-touch-icon-precomposed" sizes="152x152"/>
#   <link href="https://t.resfu.com/media/images/favicon-144.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>
#   <link href="https://t.resfu.com/media/images/favicon-120.png" rel="apple-touch-icon-precomposed" sizes="120x120"/>
#   <link href="https://t.resfu.com/media/images/favicon-114.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>
#   <link href="https://t.resfu.com/media/images/favicon-72.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>
#   <link href="https://t.resfu.com/media/images/favicon-57.png" rel="apple-touch-icon-precomposed"/>
#   <!-- otros -->
#   <link href="/media/images/favicon.ico?v=2" rel="shortcut icon"/>
#   <link href="/media/images/favicon.ico?v=2" rel="icon" sizes="16x16 32x32"/>
#   <!-- PIXEL BESOCY -->
#   <script>
#    (function(d,s,id,h,t){
#    var js,r,djs = d.getElementsByTagName(s)[0];
#    if (d.getElementById(id)) {return;}
#    js = d.createElement('script');js.id =id;js.async=1;
#    js.h=h;js.t=t;
#    r=encodeURI(btoa(d.referrer));
#    js.src="//"+h+"/pixel/js/"+t+"/"+r;
#    djs.parentNode.insertBefore(js, djs);
#   }(document, 'script', 'dogtrack-pixel','beso.spxl.socy.es', 'BESO_923_842_998'));
#   </script>
#   <!-- * end pixel Besocy * -->
#   <!-- Start Alexa Certify Javascript -->
#   <script type="text/javascript">
#    _atrk_opts = { atrk_acct:"jrzPh1aon800EO", domain:"resultados-futbol.com",dynamic: true};
# (function() { var as = document.createElement('script'); as.type = 'text/javascript'; as.async = true; as.src = "https://certify-js.alexametrics.com/atrk.js"; var s = document.getElementsByTagName('script')[0];s.parentNode.insertBefore(as, s); })();
#   </script>
#   <noscript>
#    <img alt="" height="1" src="https://certify.alexametrics.com/atrk.gif?account=jrzPh1aon800EO" style="display:none" width="1"/>
#   </noscript>
#   <!-- End Alexa Certify Javascript -->
#   <!-- Quantcast Choice. Consent Manager Tag v2.0 (for TCF 2.0) -->
#   <script async="true" type="text/javascript">
#    (function() {
#   var host = window.location.hostname;
#   var element = document.createElement('script');
#   var firstScript = document.getElementsByTagName('script')[0];
#   var url = 'https://cmp.quantcast.com'
#     .concat('/choice/', 'PM1PaqFTUH-yn', '/', host, '/choice.js');
#   var uspTries = 0;
#   var uspTriesLimit = 3;
#   element.async = true;
#   element.type = 'text/javascript';
#   element.src = url;
#
#   firstScript.parentNode.insertBefore(element, firstScript);
#
#   function makeStub() {
#     var TCF_LOCATOR_NAME = '__tcfapiLocator';
#     var queue = [];
#     var win = window;
#     var cmpFrame;
#
#     function addFrame() {
#       var doc = win.document;
#       var otherCMP = !!(win.frames[TCF_LOCATOR_NAME]);
#
#       if (!otherCMP) {
#         if (doc.body) {
#           var iframe = doc.createElement('iframe');
#
#           iframe.style.cssText = 'display:none';
#           iframe.name = TCF_LOCATOR_NAME;
#           doc.body.appendChild(iframe);
#         } else {
#           setTimeout(addFrame, 5);
#         }
#       }
#       return !otherCMP;
#     }
#
#     function tcfAPIHandler() {
#       var gdprApplies;
#       var args = arguments;
#
#       if (!args.length) {
#         return queue;
#       } else if (args[0] === 'setGdprApplies') {
#         if (
#           args.length > 3 &&
#           args[2] === 2 &&
#           typeof args[3] === 'boolean'
#         ) {
#           gdprApplies = args[3];
#           if (typeof args[2] === 'function') {
#             args[2]('set', true);
#           }
#         }
#       } else if (args[0] === 'ping') {
#         var retr = {
#           gdprApplies: gdprApplies,
#           cmpLoaded: false,
#           cmpStatus: 'stub'
#         };
#
#         if (typeof args[2] === 'function') {
#           args[2](retr);
#         }
#       } else {
#         if(args[0] === 'init' && typeof args[3] === 'object') {
#           args[3] = { ...args[3], tag_version: 'V2' };
#         }
#         queue.push(args);
#       }
#     }
#
#     function postMessageEventHandler(event) {
#       var msgIsString = typeof event.data === 'string';
#       var json = {};
#
#       try {
#         if (msgIsString) {
#           json = JSON.parse(event.data);
#         } else {
#           json = event.data;
#         }
#       } catch (ignore) {}
#
#       var payload = json.__tcfapiCall;
#
#       if (payload) {
#         window.__tcfapi(
#           payload.command,
#           payload.version,
#           function(retValue, success) {
#             var returnMsg = {
#               __tcfapiReturn: {
#                 returnValue: retValue,
#                 success: success,
#                 callId: payload.callId
#               }
#             };
#             if (msgIsString) {
#               returnMsg = JSON.stringify(returnMsg);
#             }
#             if (event && event.source && event.source.postMessage) {
#               event.source.postMessage(returnMsg, '*');
#             }
#           },
#           payload.parameter
#         );
#       }
#     }
#
#     while (win) {
#       try {
#         if (win.frames[TCF_LOCATOR_NAME]) {
#           cmpFrame = win;
#           break;
#         }
#       } catch (ignore) {}
#
#       if (win === window.top) {
#         break;
#       }
#       win = win.parent;
#     }
#     if (!cmpFrame) {
#       addFrame();
#       win.__tcfapi = tcfAPIHandler;
#       win.addEventListener('message', postMessageEventHandler, false);
#     }
#   };
#
#   makeStub();
#
#   var uspStubFunction = function() {
#     var arg = arguments;
#     if (typeof window.__uspapi !== uspStubFunction) {
#       setTimeout(function() {
#         if (typeof window.__uspapi !== 'undefined') {
#           window.__uspapi.apply(window.__uspapi, arg);
#         }
#       }, 500);
#     }
#   };
#
#   var checkIfUspIsReady = function() {
#     uspTries++;
#     if (window.__uspapi === uspStubFunction && uspTries < uspTriesLimit) {
#       console.warn('USP is not accessible');
#     } else {
#       clearInterval(uspInterval);
#     }
#   };
#
#   if (typeof window.__uspapi === 'undefined') {
#     window.__uspapi = uspStubFunction;
#     var uspInterval = setInterval(checkIfUspIsReady, 6000);
#   }
# })();
#   </script>
#   <!-- End Quantcast Choice. Consent Manager Tag v2.0 (for TCF 2.0) -->
#   <script async="" src="https://ssm.codes/smart-tag/resultados-futbolcom.js">
#   </script>
#   <script type="text/javascript">
#    _atrk_opts = { atrk_acct:"jrzPh1aon800EO", domain:"resultados-futbol.com",dynamic: true};
# (function() { var as = document.createElement('script'); as.type = 'text/javascript'; as.async = true; as.src = "https://d31qbv1cthcecs.cloudfront.net/atrk.js"; var s = document.getElementsByTagName('script')[0];s.parentNode.insertBefore(as, s); })();
#   </script>
#   <noscript>
#    <img alt="" height="1" src="https://d5nxst8fruw4z.cloudfront.net/atrk.gif?account=jrzPh1aon800EO" style="display:none" width="1"/>
#   </noscript>
#   <!-- Begin comScore Tag old:16785528-->
#   <script>
#    var _comscore = _comscore || [];
# 	_comscore.push({ c1: "2", c2: "20105429" });
# 	(function() {
# 	var s = document.createElement("script"), el =
# 	document.getElementsByTagName("script")[0]; s.async = true;
# 	s.src = (document.location.protocol == "https:" ? "https://sb" :
# 	"http://b") + ".scorecardresearch.com/beacon.js";
# 	el.parentNode.insertBefore(s, el);
# 	})();
#   </script>
#   <noscript>
#    <img src="https://b.scorecardresearch.com/p?c1=2&amp;c2=20105429&amp;cv=2.0&amp;cj=1"/>
#   </noscript>
#   <!-- End comScore Tag -->
#   <!-- Begin comScore Tag -->
#   <!--<script>
#   var _comscore = _comscore || [];
#   _comscore.push({ c1: "2", c2: "20113989" });
#   (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#     el.parentNode.insertBefore(s, el);
#   })();
# </script>
# <noscript>
#   <img src="http://b.scorecardresearch.com/p?c1=2&c2=20113989&cv=2.0&cj=1" />
# </noscript>-->
#   <!-- End comScore Tag -->
#   <link href="https://www.resultados-futbol.com/media/css_less/resultados-futbol/resultados-futbol.css?ch=401260121" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="https://www.resultados-futbol.com/media/css_less/resultados-futbol/secciones/team.css?ch=401260121" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="https://www.resultados-futbol.com/media/css_less/resultados-futbol/secciones/home_news.css?ch=401260121" media="screen" rel="stylesheet" type="text/css"/>
#   <!--[if IE]>
# 		<link href="https://st9.resfu.com/media/css/ie.css" rel="stylesheet" type="text/css" />
# 	<![endif]-->
#   <!--[if IE 6]>
# 	<link href="https://st9.resfu.com/media/css/menuie6.css" rel="stylesheet" type="text/css" />
# 	<link href="https://st9.resfu.com/media/css/ie6.css" rel="stylesheet" type="text/css" />
# 	<![endif]-->
#   <!--[if IE 7]>
# 		<link href="https://st9.resfu.com/media/css/menuie7.css" rel="stylesheet" type="text/css" />
# 	<![endif]-->
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 		(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 		m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 		})(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
# 		ga('create', 'UA-26865821-7', 'auto');
#
# 		ga('send', 'pageview');
#   </script>
#   <!-- Default Statcounter code for Resultados-Futbol -->
#   <script type="text/javascript">
#    var sc_project=1954957;
# 		var sc_invisible=1;
# 		var sc_security="f32d450e";
# 		var sc_https=1;
#   </script>
#   <script async="" src="https://www.statcounter.com/counter/counter.js" type="text/javascript">
#   </script>
#   <noscript>
#    <div class="statcounter">
#     <a href="https://statcounter.com/" target="_blank" title="Web Analytics">
#      <img alt="Web
# 			Analytics" class="statcounter" src="//c.statcounter.com/1954957/0/f32d450e/1/"/>
#     </a>
#    </div>
#   </noscript>
#   <!-- End of Statcounter Code -->
#   <script>
#    var APP_DIR = 'https://www.resultados-futbol.com/';
# 				APP_DIR = (document.location.protocol == "https:" ? APP_DIR.replace("http://", "https://") : 'https://www.resultados-futbol.com/');
#
# 				var COOKIE_NAME = 'rf_data';
# 				var APP_NAME = 'Resultados de FÃºtbol';
# 				var CATEGORIES = '2401-2434-1902-1903-1904-1905-1909-2440-2435';
# 				var IMG_DIR = APP_DIR + 'media/img/';
#   </script>
#   <script src="https://cdn2.resfu.com/media/js_basics/jquery-2.0.3.min.js?ch=401260121111" type="text/javascript">
#   </script>
#   <script src="https://cdn2.resfu.com/media/min/b=media/js_basics&amp;f=common.js?ch=401260121111" type="text/javascript">
#   </script>
#   <script src="https://cdn2.resfu.com/media/min/b=media/js_basics&amp;f=team.js?ch=401260121111" type="text/javascript">
#   </script>
#   <script src="https://cdn2.resfu.com/media/js_basics/jquery.smartbanner.js" type="text/javascript">
#   </script>
#   <script async="async" src="//widgets.outbrain.com/outbrain.js" type="text/javascript">
#   </script>
#   <!-- Facebook Pixel Code -->
#   <script>
#    !function(f,b,e,v,n,t,s)
# 	  {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# 	  n.callMethod.apply(n,arguments):n.queue.push(arguments)};
# 	  if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
# 	  n.queue=[];t=b.createElement(e);t.async=!0;
# 	  t.src=v;s=b.getElementsByTagName(e)[0];
# 	  s.parentNode.insertBefore(t,s)}(window, document,'script',
# 	  'https://connect.facebook.net/en_US/fbevents.js');
# 	  fbq('init', '1918202381837292');
# 	  fbq('track', 'PageView');
#   </script>
#   <noscript>
#    <img alt="noscript image" height="1" src="https://www.facebook.com/tr?id=1918202381837292&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
#   </noscript>
#   <!-- End Facebook Pixel Code -->
#   <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js">
#   </script>
#   <script>
#    window.googletag = window.googletag || {cmd: []};
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/12539845/RF_DESKTOP_1X1', [1, 1], 'div-gpt-ad-1634535563348-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
#   </script>
#   <script>
#    console.log('READYY2Â¡Â¡');
#   </script>
#   <meta content="aHR0cHM6Ly93d3cucmVzdWx0YWRvcy1mdXRib2wuY29tLw==" name="unancor-verify-code"/>
#   <!--TEST-->
#   <!--Array
# (
#     [type] => team
#     [slots] => Array
#         (
#             [0] => Array
#                 (
#                     [alias] => caracas-venezuela
#                     [id] => 5602
#                     [name] => Caracas Venezuela
#                     [id_slot] => 6508781
#                 )
#
#             [1] => Array
#                 (
#                     [alias] => copa_libertadores
#                     [id] => 204
#                     [name] => Copa Libertadores
#                     [id_slot] => 6508781
#                 )
#
#             [2] => Array
#                 (
#                     [alias] => torneo_transicion_venezuela
#                     [id] => 1807
#                     [name] => Primera DivisiÃ³n Venezuela
#                     [id_slot] => 6508781
#                 )
#
#         )
#
# )
# -->
#   <!-- -->
#   <script type="text/javascript">
#    window.ssmCustomTargetings = { alias: "caracas-venezuela", name: "Caracas Venezuela", idau: 5602, team: 6508781 };
#   </script>
#   <script type="text/javascript">
#    window.ssmCustomTargetings = { alias: "copa_libertadores", name: "Copa Libertadores", idau: 204, team: 6508781 };
#   </script>
#   <script type="text/javascript">
#    window.ssmCustomTargetings = { alias: "torneo_transicion_venezuela", name: "Primera DivisiÃ³n Venezuela", idau: 1807, team: 6508781 };
#   </script>
#   <meta content="da2a335f8282b3af76de22fac48b35dd9c63ebab" name="wearecontent-verify-code"/>
#   <!-- /12539845/RF_DESKTOP_1X1 -->
#   <div id="div-gpt-ad-1634535563348-0">
#    <script>
#     googletag.cmd.push(function() { googletag.display('div-gpt-ad-1634535563348-0'); });
#    </script>
#   </div>
#   <style type="text/css">
#    .advertising-both-sides .web-width {background-color: #D2D8DC;}
# 	    .advertising-both-sides-box {width: 100%;height: 100%;position: fixed;margin-top: 89px;}
# 	    .advertising-sides-box {
# 	        display: inline-block;
# 	        width: calc(50% - 590px);
# 	        position: absolute;
# 	        height: auto;
# 	        overflow: hidden;
# 	        background: #fe7200;
# 	    }
# 	    .advertising-sides-box.left {left: 0;}
# 	    .advertising-sides-box.right {right: 0}
# 	    .advertising-sides-box.left img {float:right;}
# 	    .web-contenido #contenido {position:relative}
#
# 	    @media (max-width: 1100px) {
# 	        .advertising-both-sides-box {display: none;}
# 		    .advertising-both-sides .web-contenido {background: #fff;}
# 	    }
#   </style>
#   <div class="advertising-both-sides-box hidden" id="div_publis">
#    <div id="bg_style">
#     <style type="text/css">
#      .advertising-both-sides .web-contenido, .advertising-sides-box {background: ;}
#     </style>
#    </div>
#    <div class="advertising-sides-box left">
#     <a href="" id="link_left" target="_blank">
#      <img alt="Promo izq" class="pull-right" src=""/>
#     </a>
#    </div>
#    <div class="advertising-sides-box right">
#     <a href="" id="link_right" target="_blank">
#      <img alt="Promo der" src=""/>
#     </a>
#    </div>
#   </div>
#   <script type="text/javascript">
#    function show_publi (status) {
# 			if(status){
# 				$('#web').addClass('advertising-both-sides');
# 				$('#div_publis').removeClass('hidden');
# 			}else{
# 				$('#web').removeClass('advertising-both-sides');
# 				$('#div_publis').addClass('hidden');
# 			}
#
# 		}
# 		function show_publi_custom (link,img_left,img_right,bg) {
#
# 				$('#link_left').attr('href',link);
# 				$('#link_right').attr('href',link);
# 				$('#link_right img').attr('src',img_right);
# 				$('#link_left img').attr('src',img_left);
# 				var style = '<style type="text/css">.advertising-both-sides .web-contenido, .advertising-sides-box {background: '+bg+'}</style>';
# 				$("#bg_style").html(style);
#
# 				$('#web').addClass('advertising-both-sides');
# 				$('#div_publis').removeClass('hidden');
# 		}
# 		function resizeImgHeight(margin) {
#                 var winHeight = window.innerHeight;
#                 document.querySelector('.advertising-sides-box.left img').style.height = (winHeight - margin) + "px";
#                 document.querySelector('.advertising-sides-box.right img').style.height = (winHeight - margin) + "px";
#         }
#         function resizeTop(top) {
#         	document.getElementById('div_publis').style.top = top + "px";
#         }
#         resizeImgHeight(170);
#         window.onresize = function() {
#             resizeImgHeight(170);
#         };
#         window.onscroll = function() {
#             if (document.body.scrollTop > 170 || document.documentElement.scrollTop > 170) {
# 			    resizeTop(0);
# 			} else {
# 				resizeTop(170);
# 			}
#         };
#   </script>
#   <!--[if lte IE 6]>
# <div id="alertbrowser">
# <div>
# <span class="el">!</span>
# <span>EstÃ¡s utilizando una versiÃ³n muy antigua de Internet Explorer y es posible que no puedas utilizar algunas funciones de la web.  Para solucionarlo te recomendamos
# que <a href="http://www.microsoft.com/spain/windows/products/winfamily/ie/default.mspx">actualices a la Ãºltima versiÃ³n</a> o pruebes otro navegador como <a href="http://www.mozilla-europe.org/es/" title="Navegador web Firefox | Mozilla Europe">Firefox</a>, <a href="http://www.apple.com/es/safari/download/" title="Apple - Safari - Descarga">Safari</a>, <a href="http://www.opera.com/" title="Opera Browser | Faster &amp; safer Internet | Free Download">Opera</a> o <a href="http://www.google.com/chrome/index.html?hl=es" title="Google Chrome - DescÃ¡rgate un nuevo navegador">Chrome</a>.</span>
# </div>
# </div>
# <![endif]-->
#   <div id="webfnd_">
#    <div id="detected_lang" style="display:none">
#     <div class="detected_lang_inner">
#      <span id="detected_lang_text">
#      </span>
#      <a href="javascript:;" id="detected_lang_close">
#       [x]
#      </a>
#     </div>
#    </div>
#    <div class="web" id="web">
#     <div class="web-width">
#      <div class="user_box" id="user_box" style="display:none; margin-top: 17px;">
#      </div>
#     </div>
#     <div id="fb-root">
#     </div>
#     <script>
#      (function(d, s, id) {
# 	var js, fjs = d.getElementsByTagName(s)[0];
# 	if (d.getElementById(id)) return;
# 	js = d.createElement(s); js.id = id;
# 	js.src = "//connect.facebook.net/es_LA/sdk.js#xfbml=1&version=v2.9&appId=200183103347113";
# 	fjs.parentNode.insertBefore(js, fjs);
# 	}(document, 'script', 'facebook-jssdk'));
#
# 	function checkLoginState() {
# 		FB.api('/me', 'get', { fields: 'id,name,email,first_name,last_name,locale' }, function(response) {
# 		     //console.log(response);
# 		     //alert('Welcome, ' + response.name );
# 			 //alert('Your email id is : '+ response.email);
#
# 			var url = 'https://www.resultados-futbol.com/ajax/facebook_connect/fbnew.php';
#
# 			var parametros = {"id":response.id,"name" : response.name, "email":response.email, "first_name":response.first_name, "last_name":response.last_name, "locale":response.locale};
# 			$.ajax({
# 				type: "POST",
# 				url: url,
# 				data: parametros,
# 				success: function(data) {
# 					location.reload();
# 					FB.logout(function(response) {
# 					 // console.log('usuario deslogueado');
# 					});
# 				}
# 			});
#
#
# 		});
#
# 		// FB.api('/me', function (response) {
# 		// 	alert('Welcome, ' + response.name );
# 		// 	alert('Your email id is : '+ response.email);
# 		// })
# 	};
#     </script>
#     <div id="content_logged_user">
#     </div>
#     <div class="generic_dialog hidden" id="commonbox">
#      <div class="generic_dialog_popup" style="top: 100px;">
#       <table class="pop_dialog_table ufbtable" id="pop_dialog_table">
#        <tbody>
#         <tr>
#          <td class="pop_topleft">
#          </td>
#          <td class="pop_border pop_top">
#          </td>
#          <td class="pop_topright">
#          </td>
#         </tr>
#         <tr>
#          <td class="pop_border pop_side">
#          </td>
#          <td class="pop_content" id="pop_content">
#           <p class="dialog_title">
#            <span id="commonbox_title">
#            </span>
#            <a class="cerrar_corner" href="javascript:void(0);" onclick="jQuery('#commonbox').addClass('hidden');">
#             x
#            </a>
#           </p>
#           <div class="dialog_body" id="commonbox_message">
#           </div>
#           <div style="clear:both;">
#           </div>
#           <div class="dialog_summary">
#            <input class="bottonrl" onclick="jQuery('#commonbox').addClass('hidden');" type="button" value="Aceptar"/>
#           </div>
#          </td>
#          <td class="pop_border pop_side">
#          </td>
#         </tr>
#         <tr>
#          <td class="pop_bottomleft">
#          </td>
#          <td class="pop_border pop_bottom">
#          </td>
#          <td class="pop_bottomright">
#          </td>
#         </tr>
#        </tbody>
#       </table>
#      </div>
#     </div>
#     <div class="generic_dialog hidden" id="bugbox">
#      <div class="generic_dialog_popup" style="top: 100px;">
#       <table class="pop_dialog_table ufbtable" id="pop_dialog_table">
#        <tbody>
#         <tr>
#          <td class="pop_topleft">
#          </td>
#          <td class="pop_border pop_top">
#          </td>
#          <td class="pop_topright">
#          </td>
#         </tr>
#         <tr>
#          <td class="pop_border pop_side">
#          </td>
#          <td class="pop_content" id="pop_content">
#           <p class="dialog_title">
#            <span id="commonbox_title">
#             Â¿Has detectado algÃºn error en la web?
#            </span>
#            <a class="cerrar_corner" href="javascript:void(0);" onclick="jQuery('#bugbox').addClass('hidden');">
#             x
#            </a>
#           </p>
#           <div class="dialog_body" id="commonbox_message">
#            <form action="" class="clearfix formregistro formlogin" id="formBugReport" method="post">
#             <div id="loginDiv">
#              <div class="campoitem">
#               <label for="type_bug">
#                Tipo de incidencia
#               </label>
#               <div class="inputfield">
#                <select id="type_bug" name="type_bug">
#                 <option value="0">
#                  -Tipo de incidencia-
#                 </option>
#                 <option value="1">
#                  Sugerencia o idea
#                 </option>
#                 <option value="2">
#                  Algo se ve mal
#                 </option>
#                 <option value="3">
#                  Algo no funciona del todo
#                 </option>
#                 <option value="4">
#                  Hay un error en la informaciÃ³n mostrada
#                 </option>
#                 <option value="5">
#                  Falta una competiciÃ³n / liga
#                 </option>
#                 <option value="6">
#                  Un error importante
#                 </option>
#                </select>
#               </div>
#              </div>
#              <div class="campoitem">
#               <label for="text_bug">
#                Â¿QuÃ© ocurre?
#               </label>
#               <div class="inputfield">
#                <textarea class="txt" id="text_bug" name="text_bug" placeholder="CuÃ©ntanos brevemente quÃ© ocurre."></textarea>
#               </div>
#              </div>
#              <span class="clearer">
#              </span>
#              <div class="campoitem" id="contact_email_div">
#               <label for="text_bug">
#                Deja tu correo si quieres que te contactemos
#               </label>
#               <div class="inputfield">
#                <input class="txt" id="contact_email" name="contact_email" placeholder="Email de contacto" size="50" type="text"/>
#               </div>
#              </div>
#              <span class="clearer">
#              </span>
#             </div>
#            </form>
#           </div>
#           <div style="clear:both;">
#           </div>
#           <div class="dialog_summary">
#            <input class="bottonrl" onclick="add_bug();" type="button" value="Enviar"/>
#           </div>
#          </td>
#          <td class="pop_border pop_side">
#          </td>
#         </tr>
#         <tr>
#          <td class="pop_bottomleft">
#          </td>
#          <td class="pop_border pop_bottom">
#          </td>
#          <td class="pop_bottomright">
#          </td>
#         </tr>
#        </tbody>
#       </table>
#      </div>
#     </div>
#     <div id="staticTipLayer" style="position: absolute; z-index: 10000; visibility: hidden; left: 0px; top: 0px; width: 10px">
#     </div>
#     <div class="hidden" id="login_rff">
#      <div class="generic_dialog_popup" style="top: 100px;">
#       <table class="pop_dialog_table" id="pop_dialog_table" style="width: 632px;">
#        <tbody>
#         <tr>
#          <td class="pop_topleft">
#          </td>
#          <td class="pop_border pop_top">
#          </td>
#          <td class="pop_topright">
#          </td>
#         </tr>
#         <tr>
#          <td class="pop_border pop_side">
#          </td>
#          <td class="pop_content" id="pop_content">
#           <p class="dialog_title">
#            <span>
#             Creando cuenta de usuario
#            </span>
#            <a class="cerrar_corner" href="javascript:void(0);" onclick="document.getElementById('login_rff').className='hidden';">
#             x
#            </a>
#           </p>
#           <div class="dialog_content" id="form_facebook">
#            <div class="dialog_summary">
#             Introduce los datos para tu nueva cuenta en resultados-futbol.com
#            </div>
#            <div style="width:600px;margin-left:5px;">
#             <p class="hidden" id="inputtextfb1_1">
#              El nombre de usuario debe de tener entre 4 y 16 caracteres
#             </p>
#             <p class="hidden" id="inputtextfb2_1">
#              Ya existe un usuario con ese nombre
#             </p>
#             <p class="hidden" id="inputtextfb1_2">
#              El correo electrÃ³nico no es vÃ¡lido
#             </p>
#             <p class="hidden" id="inputtextfb2_2">
#              Ya existe un usuario con este correo electrÃ³nico
#             </p>
#             <p class="hidden" id="inputtextfb1_3">
#              * La contraseÃ±a debe tener como mÃ­nimo 6 caracteres
#             </p>
#             <p class="hidden" id="inputtextfb1_4">
#              * Las contraseÃ±as no coinciden
#             </p>
#             <p class="hidden" id="inputtexterrorregisterfb">
#             </p>
#            </div>
#            <div class="dialog_body fb1">
#             <table>
#              <tr>
#               <td>
#                <label for="user_usuarioL">
#                 <span>
#                  Usuario:
#                 </span>
#                 <input class="inputtext" id="inputfb1" name="userfb" onkeyup="validatefb(1,this.value);" type="text" value=""/>
#                </label>
#               </td>
#               <td>
#                <label for="user_emailL">
#                 <span>
#                  Email:
#                 </span>
#                 <input class="inputtext" id="inputfb2" name="emailfb" onkeyup="validatefb(2,this.value);" type="text" value=""/>
#                </label>
#               </td>
#              </tr>
#             </table>
#             <div style="width:500px;margin-left:38px;">
#              <label class="checkbox acepta_reglas" for="condiciones">
#               <input class="checkbox" id="condiciones" name="condiciones" type="checkbox"/>
#               Confirmo que he leÃ­do y acepto los
#               <a href="https://www.resultados-futbol.com/legal" target="_blank">
#                tÃ©rminos y condiciones
#               </a>
#              </label>
#             </div>
#            </div>
#            <div style="clear:both;">
#            </div>
#            <div class="dialog_summary">
#             <input class="bottonrl" id="iniciosesionfb" name="iniciosesionfb" onclick="next_step_fb();" type="button" value="Siguiente"/>
#            </div>
#           </div>
#          </td>
#          <td class="pop_border pop_side">
#          </td>
#         </tr>
#         <tr>
#          <td class="pop_bottomleft">
#          </td>
#          <td class="pop_border pop_bottom">
#          </td>
#          <td class="pop_bottomright">
#          </td>
#         </tr>
#        </tbody>
#       </table>
#      </div>
#     </div>
#     <style>
#      #form_message > p {
# 	font-size: 13px;
# 	padding: 20px 20px 20px 10px;
# }
# #form_message > p a {
#     background: none repeat scroll 0 0 #52a331;
#     border-radius: 3px;
#     font-size: 12px;
#     padding: 3px 8px;
#     color: #FFFFFF;
#     margin-top:10px;
#     display: inline-block;
# }
#     </style>
#     <div class="hidden" id="login_rf">
#      <div class="generic_dialog_popup login_redesign" style="top: 100px;">
#       <table class="pop_dialog_table ufbtable" id="pop_dialog_table">
#        <tbody>
#         <tr>
#          <td class="pop_content" id="pop_content">
#           <p class="dialog_title">
#            <span>
#             Iniciar SesiÃ³n
#            </span>
#            <a class="cerrar_corner" href="javascript:void(0);" onclick="document.getElementById('login_rf').className='hidden';">
#             x
#            </a>
#           </p>
#           <div class="dialog_content" id="form_reg">
#            <div class="dialog_summary">
#             <p class="mbottom10">
#              Si lo prefieres, puedes acceder con tu cuenta de facebook:
#             </p>
#             <center class="mbottom10">
#              <div id="fb-root">
#              </div>
#              <!-- <a class="fb_button fb_button_medium" href="https://www.resultados-futbol.com/ajax/facebook_connect/redirect_fb.php"><span class="fb_button_text">Entrar</span></a> -->
#             </center>
#             <p class="small mbottom10">
#              Si ya estÃ¡s registrado, puedes
#              <br/>
#              <a href="javascript:void(0);" onclick="switchbody(1);">
#               Acceder aquÃ­
#              </a>
#             </p>
#             <p class="small">
#              Si ya eres usuario, tambiÃ©n puedes
#              <br/>
#              <a href="javascript:void(0);" onclick="switchbody(3);">
#               Recordar tu contraseÃ±a
#              </a>
#             </p>
#             <!--Inicia sesiÃ³n Ã³ <a href="javascript:void(0);" onclick="switchbody(2);"><strong>registra un usuario</strong></a> si no tienes cuenta.   <a href="https://www.resultados-futbol.com/auth/login">Recordar contraseÃ±a</a>-->
#            </div>
#            <div class="dialog_body">
#             <div class="editor">
#              <p class="noerror" id="input1">
#               <label for="user_name">
#                <span>
#                 Usuario:
#                </span>
#                <input class="inputtext" id="user_name" name="user_name" onkeyup="validate(1,this.value);" type="text" value=""/>
#               </label>
#              </p>
#              <p class="noerror" id="input2">
#               <label for="email">
#                <span>
#                 Correo electrÃ³nico:
#                </span>
#                <input class="inputtext" id="email" name="email" onkeyup="validate(2,this.value);" type="text" value=""/>
#               </label>
#              </p>
#              <p class="noerror" id="input3">
#               <label for="password">
#                <span>
#                 ContraseÃ±a:
#                </span>
#                <input class="inputtext" id="password" name="password" onkeyup="validate(3,this.value);" type="password" value=""/>
#               </label>
#              </p>
#              <p class="noerror" id="input4">
#               <label for="password_confirm">
#                <span>
#                 Repetir contraseÃ±a:
#                </span>
#                <input class="inputtext" id="password_confirm" name="password_confirm" onkeyup="validate(4,this.value);" type="password" value=""/>
#               </label>
#              </p>
#              <p class="hidden" id="inputtext1_1">
#               El nombre de usuario debe de tener entre 4 y 16 caracteres
#              </p>
#              <p class="hidden" id="inputtext2_1">
#               Ya existe un usuario con ese nombre
#              </p>
#              <p class="hidden" id="inputtext1_2">
#               El correo electrÃ³nico no es vÃ¡lido
#              </p>
#              <p class="hidden" id="inputtext2_2">
#               Ya existe un usuario con este correo electrÃ³nico
#              </p>
#              <p class="hidden" id="inputtext1_3">
#               * La contraseÃ±a debe tener como mÃ­nimo 6 caracteres
#              </p>
#              <p class="hidden" id="inputtext1_4">
#               * Las contraseÃ±as no coinciden
#              </p>
#              <p class="hidden" id="inputtexterrorregister">
#              </p>
#             </div>
#            </div>
#            <div style="display:block;clear:both;float:none;">
#            </div>
#            <div style="background-color:#D2D8DC;padding:10px">
#             <div style="margin:5px">
#              <label class="checkbox acepta_reglas" for="condiciones_legales">
#               <input class="checkbox" id="condiciones_legales" name="condiciones_legales" type="checkbox"/>
#               Confirmo que he leÃ­do y acepto los
#               <a href="https://www.resultados-futbol.com/legal" target="_blank">
#                tÃ©rminos y condiciones.
#               </a>
#              </label>
#             </div>
#             <div style="margin:5px">
#              <label class="checkbox acepta_reglas" for="condiciones_mayor14">
#               <input class="checkbox" id="condiciones_mayor14" name="condiciones_mayor14" type="checkbox"/>
#               Reconozco ser mayor de 14 aÃ±os
#              </label>
#             </div>
#             <div class="dialog_actions">
#              <input class="fleft mright10 br3 sbutton sbutton_small sbutton1" id="createuser" name="createuser" onclick="create_user();" type="button" value="Crear usuario"/>
#              <input class="fleft br3 sbutton sbutton_small sbutton3" onclick="document.getElementById('login_rf').className='hidden';" type="button" value="Cancelar"/>
#             </div>
#            </div>
#           </div>
#           <div class="hidden" id="form_login">
#            <div class="dialog_summary">
#             <p class="mbottom10">
#              Si lo prefieres, puedes acceder con tu cuenta de facebook:
#             </p>
#             <center class="mbottom10">
#              <div id="fb-root">
#              </div>
#              <!-- <a class="fb_button fb_button_medium" href="https://www.resultados-futbol.com/ajax/facebook_connect/redirect_fb.php"><span class="fb_button_text">Entrar</span></a> -->
#              <div class="fb-login-button" data-auto-logout-link="false" data-button-type="login_with" data-max-rows="1" data-scope="basic_info, email" data-show-faces="false" data-size="medium" data-use-continue-as="true" onlogin="checkLoginState();">
#               Entrar
#              </div>
#             </center>
#             <p class="small mbottom10">
#              Â¿TodavÃ­a no tienes cuenta de usuario?
#              <br/>
#              <a href="javascript:void(0);" onclick="switchbody(2);">
#               RegÃ­strate aquÃ­
#              </a>
#             </p>
#             <p class="small">
#              Si ya eres usuario, tambiÃ©n puedes
#              <br/>
#              <a href="javascript:void(0);" onclick="switchbody(3);">
#               Recordar tu contraseÃ±a
#              </a>
#             </p>
#            </div>
#            <div class="dialog_body">
#             <div class="editor">
#              <p class="noerror" id="input1">
#               <label for="user_nameL" style="float:none">
#                <span>
#                 Usuario:
#                </span>
#                <input class="inputtext" id="user_nameL" name="user_nameL" type="text" value=""/>
#               </label>
#              </p>
#              <p class="noerror" id="input3">
#               <label for="passwordL" style="float:none">
#                <span>
#                 ContraseÃ±a:
#                </span>
#                <input class="inputtext" id="passwordL" name="passwordL" type="password" value=""/>
#               </label>
#              </p>
#              <p class="hidden" id="inputtexterrorlogin">
#              </p>
#             </div>
#             <div class="dialog_actions">
#              <input class="fleft mright10 br3 sbutton sbutton_small sbutton1" id="iniciosesion" name="iniciosesion" onclick="login_user();" type="button" value="Iniciar SesiÃ³n"/>
#              <input class="fleft br3 sbutton sbutton_small sbutton3" onclick="document.getElementById('login_rf').className='hidden';" type="button" value="Cancelar"/>
#             </div>
#            </div>
#           </div>
#           <div class="hidden" id="form_remember">
#            <div class="dialog_summary">
#             <p class="mbottom10">
#              Si lo prefieres, puedes acceder con tu cuenta de facebook:
#             </p>
#             <center class="mbottom10">
#              <div id="fb-root">
#              </div>
#              <a class="fb_button fb_button_medium" href="https://www.resultados-futbol.com/ajax/facebook_connect/redirect_fb.php">
#               <span class="fb_button_text">
#                Entrar
#               </span>
#              </a>
#             </center>
#             <p class="small mbottom10">
#              Â¿TodavÃ­a no tienes cuenta de usuario?
#              <br/>
#              <a href="javascript:void(0);" onclick="switchbody(2);">
#               RegÃ­strate aquÃ­
#              </a>
#             </p>
#             <p class="small">
#              Si ya eres usuario, tambiÃ©n puedes
#              <br/>
#              <a href="javascript:void(0);" onclick="switchbody(3);">
#               Recordar tu contraseÃ±a
#              </a>
#             </p>
#            </div>
#            <div class="dialog_body">
#             <form action="/auth/login" id="form_remember" method="post" name="form_remember">
#              <div class="editor">
#               <p class="noerror" id="input1">
#                <label for="forgotten_email">
#                 <span>
#                  Correo electrÃ³nico:
#                 </span>
#                 <input class="inputtext" id="forgotten_email" name="email" type="text" value=""/>
#                </label>
#               </p>
#               <p class="hidden" id="inputtexterrorlogin">
#               </p>
#              </div>
#              <div class="dialog_actions">
#               <input class="fleft mright10 br3 sbutton sbutton_small sbutton1" id="forgotten" name="forgotten" type="submit" value="Recordar"/>
#               <input class="fleft br3 sbutton sbutton_small sbutton3" onclick="document.getElementById('login_rf').className='hidden';" type="button" value="Cancelar"/>
#              </div>
#             </form>
#            </div>
#           </div>
#           <div class="hidden" id="form_message">
#            <p id="form_message_text">
#            </p>
#           </div>
#          </td>
#         </tr>
#        </tbody>
#       </table>
#      </div>
#     </div>
#     <div class="web web-cabecera">
#      <div id="cabecera">
#       <div id="bar-top">
#        <b class="izq">
#        </b>
#        <div class="bar-top-text">
#         <ul class="user_link">
#          <li>
#           <a href="/">
#            Inicio
#           </a>
#          </li>
#          <li>
#           <a href="/perfil">
#            Perfil
#           </a>
#          </li>
#          <li class="despi icodes" id="despsitios">
#           <a class="lia liasites" href="javascript:void(0);" onclick="despsitios();">
#            Sitios
#           </a>
#           <ul class="hidden" id="ulsitios">
#            <li>
#             <img alt="quinielas" class="icoquinielas" src="/media/img/1px.gif"/>
#             <a href="/quiniela">
#              Quinielas
#             </a>
#            </li>
#            <li>
#             <img alt="twitter" class="icotwitter" src="/media/img/1px.gif"/>
#             <a href="/twitter">
#              Twitter
#             </a>
#            </li>
#            <li>
#             <img alt="grupos" class="icogrupos" src="/media/img/1px.gif"/>
#             <a href="/misgrupos">
#              Grupos
#             </a>
#            </li>
#            <li>
#             <img alt="blogs" class="icoblogs" src="/media/img/1px.gif"/>
#             <a href="/reader">
#              Blogs
#             </a>
#            </li>
#            <li>
#             <img alt="fantasy" class="icofantasy" src="/media/img/1px.gif"/>
#             <a href="/noticias-fantasy">
#              Canal Fantasy
#             </a>
#            </li>
#            <li>
#             <img alt="api" class="icoapi" src="/media/img/1px.gif"/>
#             <a href="https://es.besoccer.com/api" target="_blank">
#              API
#             </a>
#            </li>
#           </ul>
#          </li>
#          <!-- 			<li class="despi icodes" id="despgame"><a class="lia" onclick="despgames();" href="javascript:void(0);">Juegos</a>
# 				<ul id="ulgames" class="hidden">
# 					<li><img class="icoporra" alt="porra" src="/media/img/1px.gif"><a href="/porra">La Porra</a></li>
# 					<li><img class="icodesa" alt="desa" src="/media/img/1px.gif"><a href="/desafio_manager">Desafio Manager</a></li>
# 					<li><img class="icoonce" alt="once" src="/media/img/1px.gif"><a href="/once_ideal">Once Ideal</a></li>
# 					<li><img class="icocrea" alt="crea" src="/media/img/1px.gif"><a href="/crea-tu-camiseta">Crea tu camiseta</a></li>
# 					<li><img class="icoduelo" alt="duelo" src="/media/img/1px.gif"><a href="/duelo-jugadores">Duelo de jugadores</a></li>
# 					<li><img class="icoduelo" alt="duelo" src="/media/img/1px.gif"><a href="/duelo-equipos">Duelo de equipos</a></li>
# 					<li><img class="icobroker" alt="broker" src="/media/img/1px.gif"><a href="/bebroker">Be Broker jugadores</a></li>
# 					<li><img class="icobroker" alt="broker" src="/media/img/1px.gif"><a href="/bebroker_equipos">Be Broker equipos</a></li>
# 					<li><img class="icofantasy" alt="fantasy" src="/media/img/1px.gif"><a href="http://fantasy.resultados-futbol.com">Fantasy Manager</a></li>
# 					<li><img class="icofutsal" alt="futsal" src="/media/img/1px.gif"><a href="http://futsal.resultados-futbol.com">Futsal Manager</a></li>
# 					<li><img class="icobaloncesto" alt="baloncesto" src="/media/img/1px.gif"><a href="http://baloncesto.resultados-futbol.com">Baloncesto Manager</a></li>
# 					<li><img class="icofantasy" alt="fantasy" src="/media/img/1px.gif"><a href="http://f1.popuz.com">Fantasy F1</a></li>
# 					<li><img class="icofantasy" alt="fantasy" src="/media/img/1px.gif"><a href="http://moto.popuz.com">Fantasy Moto GP</a></li>
# 					<li class="last"><img class="icoreto" alt="reto" src="/media/img/1px.gif"><a href="http://reto.resultados-futbol.com">Reto Manager</a></li>
# 				</ul>
# 			</li> -->
#          <li class="micof mico messages">
#           <a class="mico_link" href="/mensajes" title="Mensajes">
#            Mensajes
#           </a>
#           <span class="hidden" id="msgdiva">
#            <strong>
#             <span id="msgnum">
#              0
#             </span>
#            </strong>
#           </span>
#          </li>
#          <li class="mico notifies">
#           <a class="mico_link" href="/notificaciones" title="Notificaciones">
#            Notificaciones
#           </a>
#           <span class="hidden" id="msgwdiva">
#            <strong>
#             <span id="msgwnum">
#              0
#             </span>
#            </strong>
#           </span>
#          </li>
#          <li class="mico friends">
#           <a class="mico_link" href="/amigos" title="Amigos">
#            Amigos
#           </a>
#           <span class="hidden" id="frienddiva">
#            <strong>
#             <span id="friendsnum">
#              0
#             </span>
#            </strong>
#           </span>
#          </li>
#          <li class="mico notif activity" id="li_status">
#           <a class="mico_link lia" href="javascript:void(0);" id="link_status" onclick="switchStatus();" title="Actividad">
#            Actividad
#           </a>
#           <span class="hidden" id="statusnum_div">
#            <strong>
#             <span id="statusnum">
#             </span>
#            </strong>
#           </span>
#           <div class="despnotif hidden" id="status_container">
#            <b>
#            </b>
#            <div id="status_inner_container">
#             <p class="noactividad">
#              No hay actividad de la comunidad para mostrarte.
#             </p>
#            </div>
#            <input id="status_noviewed_ids" type="hidden" value=""/>
#           </div>
#          </li>
#         </ul>
#         <ul class="hidden" id="registerloading">
#          <li>
#           <a href="javascript:void(0);">
#            cargando
#           </a>
#          </li>
#         </ul>
#         <ul class="sesion_link" id="registerText">
#          <li class="addcontent">
#           <a class="hidden" href="javascript:;" id="swithAddContentBug" onclick="jQuery('#bugbox').toggleClass('hidden');">
#            Reportar error
#           </a>
#          </li>
#          <li>
#           <!-- <a class="fb_button fb_button_small" href="https://www.resultados-futbol.com/ajax/facebook_connect/redirect_fb.php">
# 						<span class="fb_button_text">Entrar</span
# 					></a> -->
#           <div class="fb-login-button" data-auto-logout-link="false" data-button-type="login_with" data-max-rows="1" data-scope="basic_info, email" data-show-faces="false" data-size="medium" data-use-continue-as="true" onlogin="checkLoginState();">
#           </div>
#          </li>
#          <li>
#           <a href="javascript:void(0);" id="login_a" onclick="mklogin();">
#            Login
#           </a>
#          </li>
#          <li>
#           <a class="registro" href="javascript:void(0);" id="registro_a" onclick="mkregister();">
#            RegÃ­strate
#           </a>
#          </li>
#         </ul>
#        </div>
#        <b class="der">
#        </b>
#       </div>
#       <script type="text/javascript">
#        load_login_events0();
# 		load_login_events();
#       </script>
#       <div id="infotop">
#        2.855.770 resultados, 9.127.069 comentarios, 804.045 imÃ¡genes, 79.786 vÃ­deos, 85.880 noticias
#       </div>
#       <div id="logo">
#        <h3>
#         <a href="/">
#          Resultados de FÃºtbol
#         </a>
#        </h3>
#       </div>
#       <div class="buscadortop">
#        <input autocomplete="off" id="searchinput" name="k" onclick="if(startsearch1==0){this.value='';startsearch1=1;this.className='txtinto';}" onkeyup="getKeywords(this.value,1,event,0);" size="60" style="width:297px;" type="text" value="Buscar contenidos..."/>
#        <input id="searchbutton" name="search" onclick="doSearch(document.getElementById('searchinput').value,0);" type="button" value="Buscar"/>
#        <div class="hidden" id="sugerencias1">
#        </div>
#       </div>
#       <div class="cleaner">
#       </div>
#       <div id="menu">
#        <ul class="top">
#         <li class="" id="menua0">
#          <a href="https://www.resultados-futbol.com/" id="a0">
#           <b id="c0">
#            <span id="b0">
#             Inicio
#            </span>
# ...
#               </a>
#              </td>
#              <td class="pts">
#               10
#              </td>
#             </tr>
#             <tr class="impar">
#              <th class="pos3 pos-playsud">
#               3
#              </th>
#              <td class="shield">
#               <a href="https://www.resultados-futbol.com/The-Strongest" title="The Strongest">
#                <img alt="The Strongest" height="20" src="https://t.resfu.com/img_data/escudos/small/11372.jpg?size=40x&amp;5" width="20"/>
#               </a>
#              </td>
#              <td class="equipo">
#               <a href="https://www.resultados-futbol.com/The-Strongest" title="The Strongest">
#                The Strongest
#               </a>
#              </td>
#              <td class="pts">
#               6
#              </td>
#             </tr>
#             <tr class="par act">
#              <th class="pos">
#               4
#              </th>
#              <td class="shield">
#               <a href="https://www.resultados-futbol.com/Caracas-Venezuela" title="Caracas">
#                <img alt="Caracas" height="20" src="https://t.resfu.com/img_data/escudos/small/5602.jpg?size=40x&amp;5" width="20"/>
#               </a>
#              </td>
#              <td class="equipo">
#               <a href="https://www.resultados-futbol.com/Caracas-Venezuela" title="Caracas">
#                Caracas
#               </a>
#              </td>
#              <td class="pts">
#               6
#              </td>
#             </tr>
#            </tbody>
#           </table>
#          </div>
#          <div class="contentitem">
#           <table cellspacing="0" id="tabla2legend" summary="">
#            <tr>
#             <th class="pos2 pos-nextcha">
#             </th>
#             <td style="text-align:left;">
#              <strong>
#               Siguiente Ronda
#              </strong>
#              :
# 														Libertad, Athletico Paranaense
#             </td>
#            </tr>
#            <tr>
#             <th class="pos3 pos-playsud">
#             </th>
#             <td style="text-align:left;">
#              <strong>
#               Liguilla Sudamericana
#              </strong>
#              :
# 														The Strongest
#             </td>
#            </tr>
#           </table>
#          </div>
#         </div>
#         <div class="boxhome" id="teams_box">
#          <div class="boxtop">
#           <div class="linea">
#            <span class="titlebox">
#             RIVALES EN Copa Libertadore.
#            </span>
#            <div class="botonlivs">
#             <span class="titlen">
#              4
#             </span>
#            </div>
#           </div>
#          </div>
#          <div class="contentitem">
#           <ul class="teams_list">
#            <li>
#             <a href="/Atletico-Paranaense">
#              <img height="37" src="https://t.resfu.com/img_data/escudos/small/374.jpg?size=37x&amp;5" width="37"/>
#              <small>
#               Athletico Paranaense
#              </small>
#             </a>
#            </li>
#            <li>
#             <a href="/Caracas-Venezuela">
#              <img height="37" src="https://t.resfu.com/img_data/escudos/small/5602.jpg?size=37x&amp;5" width="37"/>
#              <small>
#               Caracas
#              </small>
#             </a>
#            </li>
#            <li>
#             <a href="/Libertad-Asuncion">
#              <img height="37" src="https://t.resfu.com/img_data/escudos/small/1553.jpg?size=37x&amp;5" width="37"/>
#              <small>
#               Libertad
#              </small>
#             </a>
#            </li>
#            <li>
#             <a href="/The-Strongest">
#              <img height="37" src="https://t.resfu.com/img_data/escudos/small/11372.jpg?size=37x&amp;5" width="37"/>
#              <small>
#               The Strongest
#              </small>
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="boxhome" id="teams_box">
#          <div class="boxtop">
#           <div class="linea">
#            <span class="titlebox">
#             RIVALES EN Primera DivisiÃ³n.
#            </span>
#            <div class="botonlivs">
#             <span class="titlen">
#              16
#             </span>
#            </div>
#           </div>
#          </div>
#          <div class="contentitem">
#           <ul class="teams_list">
#            <li>
#             <a href="/Caracas-Venezuela">
#              <img height="37" src="https://t.resfu.com/img_data/escudos/small/5602.jpg?size=37x&amp;5" width="37"/>
#              <small>
#               Caracas
#              </small>
#             </a>
#            </li>
#            <li>
#             <a href="/Deportivo-Tachira-Fc">
#              <img height="37" src="https://t.resfu.com/img_data/escudos/small/3606.jpg?size=37x&amp;5" width="37"/>
#              <small>
#               Dep. TÃ¡chira
#              </small>
#             </a>
#            </li>
#            <li>
#             <a href="/Mineros-Guayana">
#              <img height="37" src="https://t.resfu.com/img_data/escudos/small/3900.jpg?size=37x&amp;5" width="37"/>
#              <small>
#               Mineros de Guayana
#              </small>
#             </a>
#            </li>
#            <li>
#             <a href="/Estudiantes-Merida-Fc">
#              <img height="37" src="https://t.resfu.com/img_data/escudos/small/3604.jpg?size=37x&amp;5" width="37"/>
#              <small>
#               Estudiantes de MÃ©rida
#              </small>
#             </a>
#            </li>
#            <li>
#             <a href="/Zamora-Cf">
#              <img height="37" src="https://t.resfu.com/img_data/escudos/small/2787.jpg?size=37x&amp;5" width="37"/>
#              <small>
#               Zamora FC
#              </small>
#             </a>
#            </li>
#            <li>
#             <a href="/Monagas-Sc">
#              <img height="37" src="https://t.resfu.com/img_data/escudos/small/3609.jpg?size=37x&amp;5" width="37"/>
#              <small>
#               Monagas
#              </small>
#             </a>
#            </li>
#            <li>
#             <a href="/Carabobo">
#              <img height="37" src="https://t.resfu.com/img_data/escudos/small/11657.jpg?size=37x&amp;5" width="37"/>
#              <small>
#               Carabobo
#              </small>
#             </a>
#            </li>
#            <li>
#             <a href="/Deportivo-Lara">
#              <img height="37" src="https://t.resfu.com/img_data/escudos/small/4379.jpg?size=37x&amp;5" width="37"/>
#              <small>
#               Deportivo Lara
#              </small>
#             </a>
#            </li>
#            <li>
#             <a href="/Aragua-Fc">
#              <img height="37" src="https://t.resfu.com/img_data/escudos/small/3597.jpg?size=37x&amp;5" width="37"/>
#              <small>
#               Aragua FC
#              </small>
#             </a>
#            </li>
#            <li>
#             <a href="/Portuguesa-Fc">
#              <img height="37" src="https://t.resfu.com/img_data/escudos/small/3620.jpg?size=37x&amp;5" width="37"/>
#              <small>
#               Portuguesa de Araure
#              </small>
#             </a>
#            </li>
#            <li>
#             <a href="/Deportivo-La-Guaira">
#              <img height="37" src="https://t.resfu.com/img_data/escudos/small/15169.jpg?size=37x&amp;5" width="37"/>
#              <small>
#               La Guaira
#              </small>
#             </a>
#            </li>
#            <li>
#             <a href="/Zulia-Fc">
#              <img height="37" src="https://t.resfu.com/img_data/escudos/small/3601.jpg?size=37x&amp;5" width="37"/>
#              <small>
#               Zulia FC
#              </small>
#             </a>
#            </li>
#            <li>
#             <a href="/Ucv">
#              <img height="37" src="https://t.resfu.com/img_data/escudos/small/11653.jpg?size=37x&amp;5" width="37"/>
#              <small>
#               UCV
#              </small>
#             </a>
#            </li>
#            <li>
#             <a href="/Metropolitanos">
#              <img height="37" src="https://t.resfu.com/img_data/escudos/small/11646.jpg?size=37x&amp;5" width="37"/>
#              <small>
#               Metropolitanos
#              </small>
#             </a>
#            </li>
#            <li>
#             <a href="/Academia-Puerto-Cabello">
#              <img height="37" src="https://t.resfu.com/img_data/escudos/small/65310.jpg?size=37x&amp;5" width="37"/>
#              <small>
#               Academia Puerto Cabello
#              </small>
#             </a>
#            </li>
#            <li>
#             <a href="/Cd-Hermanos-Colmenarez">
#              <img height="37" src="https://t.resfu.com/img_data/escudos/small/110173.jpg?size=37x&amp;5" width="37"/>
#              <small>
#               CD Hermanos Colmenarez
#              </small>
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#        </div>
#        <div class="cleaner">
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="web web-contenido web-footer-ads">
#    <div class="web-width">
#    </div>
#   </div>
#   <div class="clearfix">
#   </div>
#   <div id="pie-top">
#    <span id="privacyPolicy">
#     <b>
#      Uso de cookies:
#     </b>
#     <span class="policy">
#      Utilizamos "cookies" propias y de terceros para mejorar nuestros servicios, elaborar informaciÃ³n estadÃ­stica, analizar sus hÃ¡bitos de navegaciÃ³n e inferir grupos de interÃ©s. Esto nos permite personalizar el contenido que ofrecemos y mostrarle publicidad relacionada con sus preferencias. Adicionalmente, compartimos los anÃ¡lisis de navegaciÃ³n y los grupos de interÃ©s inferidos con terceros. Si continÃºa navegando acepta su uso.
#      <a class="privacyA" href="https://www.resultados-futbol.com/legal" rel="nofollow" target="_blank">
#       MÃ¡s informaciÃ³n y cambio de configuraciÃ³n.
#      </a>
#     </span>
#     <a class="privacy-btn pb-close privacy-close" href="javascript:;">
#      Aceptar
#     </a>
#    </span>
#    <script type="text/javascript">
#     function getCookie(c_name){if(document.cookie.length>0){c_start=document.cookie.indexOf(c_name + "=");if (c_start!=-1){c_start=c_start + c_name.length+1;c_end=document.cookie.indexOf(";",c_start);if (c_end==-1) c_end=document.cookie.length;return unescape(document.cookie.substring(c_start,c_end));}}return "";}
# function closeCookieMessage() {
# 	document.getElementById('privacyPolicy').style.display = 'none';
# 	setCookie('cookies_closed', 'true', 365);
# }
# if(typeof(setCookie)=='undefined'){
# 	function setCookie(cookieName, cookieValue, nDays) {
# 		var today = new Date();
# 		var expire = new Date();
# 		if (nDays==null || nDays==0)
# 			nDays=1;
# 		expire.setTime(today.getTime() + 3600000*24*nDays);
# 		document.cookie = cookieName+"="+escape(cookieValue) + ";expires="+expire.toGMTString();
# 	}
# }
#
# document.addEventListener("DOMContentLoaded", function(event) {
# 	cookies_closed = getCookie('cookies_closed');
# 	if( !(cookies_closed=="true") ) {
# 		document.getElementById('privacyPolicy').style.display = 'inline';
#
# 		document.getElementById('privacy-close').addEventListener("click", function(){
# 			closeCookieMessage();
# 		});
# 	}
# });
#    </script>
#    <div class="pie-top-container">
#     <div class="padding">
#      <ul class="menu">
#       <li class="first">
#        <a href="https://www.resultados-futbol.com/">
#         Inicio
#        </a>
#       </li>
#       <li>
#        <a href="https://www.resultados-futbol.com/quiniela">
#         Quiniela
#        </a>
#       </li>
#       <li>
#       </li>
#       <li>
#        <a href="https://www.resultados-futbol.com/livescore">
#         Partidos de hoy
#        </a>
#       </li>
#       <!-- <li><a href="https://www.resultados-futbol.com/videos">VÃ­deos</a></li> -->
#       <li>
#        <a href="https://www.resultados-futbol.com/noticias">
#         Noticias
#        </a>
#       </li>
#       <li>
#        <a href="https://www.resultados-futbol.com/grupos">
#         Grupos
#        </a>
#       </li>
#       <li>
#        <a href="https://www.resultados-futbol.com/ligas">
#         Ligas
#        </a>
#       </li>
#       <li>
#        <a href="https://www.resultados-futbol.com/partidos-televisados">
#         Partidos televisados
#        </a>
#       </li>
#       <li>
#        <a href="https://company.besoccer.com/es/trabajos">
#         Trabaja con nosotros
#        </a>
#       </li>
#      </ul>
#     </div>
#    </div>
#    <div class="padding">
#     <div class="bot-pie">
#      <ul class="lef">
#       <li class="logo">
#        <a href="https://www.resultados-futbol.com/">
#         Resultados de fÃºtbol
#        </a>
#       </li>
#       <li class="slogan">
#        La web del fÃºtbol
#       </li>
#       <!-- 				<li class="linklang">- <a href="https://www.popuz.com">Red social de juegos online</a></li> -->
#       <li class="linklang">
#        -
#        <a href="https://es.besoccer.com">
#         Livescore
#        </a>
#        |
#        <a href="https://www.besoccer.com">
#         BeSoccer.com
#        </a>
#       </li>
#      </ul>
#      <ul class="rig">
#       <li>
#        Juega con responsabilidad. 18+
#        <span>
#         |
#        </span>
#       </li>
#       <li>
#        <a href="https://www.resultados-futbol.com/legal">
#         Aviso legal
#        </a>
#       </li>
#      </ul>
#      <ul class="rig ssmm">
#       <li>
#        Siguenos en
#        <a class="ssmmico youtube" href="https://www.youtube.com/channel/UCCbuWKB8KkFrrD7WKiXc9Rg" rel="nofollow" target="_blank">
#         Youtube
#        </a>
#        <a class="ssmmico instagram" href="https://www.instagram.com/besoccer/" rel="nofollow" target="_blank">
#         Instagram
#        </a>
#        <a class="ssmmico twitter" href="https://twitter.com/rfutbol" rel="nofollow" target="_blank">
#         Twitter
#        </a>
#        <a class="ssmmico facebook" href="https://www.facebook.com/rfutbol" rel="nofollow" target="_blank">
#         Facebook
#        </a>
#       </li>
#      </ul>
#      <ul class="lef version">
#       <li>
#        <a class="version" href="https://movil.resultados-futbol.com/" onclick="mobilepage();">
#         VersiÃ³n mÃ³vil
#        </a>
#       </li>
#       <li>
#        <a class="version version-android" href="https://play.google.com/store/apps/details?id=com.resultadosfutbol.mobile&amp;hl=es" target="_blank">
#         App Android
#        </a>
#       </li>
#       <li>
#        <a class="version version-ios" href="https://itunes.apple.com/es/app/id550928207" target="_blank">
#         App iOs
#        </a>
#       </li>
#       <li>
#        <a class="version version-huawei" href="https://appgallery.cloud.huawei.com/ag/n/app/C100094381?channelId=BeSoccer&amp;id=f1211652806445259cf5bd332b012fb6&amp;s=44DB2CA19F77FC080F4A7F833E79FC46D1868D23D297152A3B081152FAD57BFA&amp;detailType=0&amp;v=" target="_blank">
#         App Huawei
#        </a>
#       </li>
#      </ul>
#     </div>
#    </div>
#   </div>
#   <div class="cleaner">
#   </div>
#   <script type="text/javascript">
#    function realpage()
# {
# 	var date = new Date();
#     var days = 7;
#     date.setTime(date.getTime()+(days*24*60*60*1000));
#     var expires = "; expires="+ date.toGMTString();
#
#     document.cookie = "iphone_redirect=true" + expires + ";domain=.resultados-futbol.com;path=/";
#     window.location = "https://www.resultados-futbol.com/";
#
# }
#
# function mobilepage()
# {
#      document.cookie = 'iphone_redirect=;expires=Thu, 01 Jan 1970 00:00:01 GMT;domain=.resultados-futbol.com;path=/';
#     window.location = "https://movil.resultados-futbol.com/";
#
# }
#
# function select_all()
# {
# var text_val=eval("document.opinaform.opinion_text");
# text_val.focus();
# text_val.select();
# }
#
# function select_allM()
# {
# var text_val=eval("document.opinaform.email");
# text_val.focus();
# text_val.select();
# }
# function checkEmail(email) {
#    return (email.indexOf(".") > 2) && (email.indexOf("@") > 0);
# }
#
# function verify() {
# var themessage = "";
# if (document.opinaform.opinion_text.value=="") {
# themessage = '';
# }
# if (document.opinaform.email.value=="") {
# themessage = '';
# }
#
# if(!checkEmail(document.opinaform.email.value))
# 	themessage = '';
#
# if (themessage == "") {
# document.opinaform.submit();
# }
# else {
# alert(themessage);
# return false;
#    }
# }
#   </script>
#   <link href="https://www.resultados-futbol.com/media/css_less/extra.css?ch=6857306471" media="screen" rel="stylesheet" type="text/css"/>
#  </body>
# </html>

# %%
ccs_plantilla_all = ccs_soup.find('table', attrs= {'class':'sdata_table'})
ccs_plantilla_all
# Out:
# <table cellpadding="0" cellspacing="0" class="sdata_table">
# <thead>
# <tr>
# <th class="numd" scope="col"></th>
# <th colspan="2" scope="col">Jugador</th>
# <th class="date" scope="col">Edad</th>
# <th class="bigint" scope="col">Origen</th>
# <th class="bigint" scope="col">Altura</th>
# <th class="bigint" scope="col">Peso</th>
# <th class="smallint" scope="col"><img alt="Goles" class="goles" src="https://t.resfu.com/media/img/1px.gif" title="Goles"/></th>
# <th class="smallint" scope="col"><img alt="Tarjetas rojas" class="rojas" src="https://t.resfu.com/media/img/1px.gif" title="Tarjetas rojas"/></th>
# <th class="smallint" scope="col"><img alt="Tarjetas amarillas" class="amarillas" src="https://t.resfu.com/media/img/1px.gif" title="Tarjetas rojas"/></th>
# </tr>
# </thead>
# <tbody>
# <tr class="first-child">
# <th axis="position" class="axis" colspan="11">Portero</th>
# </tr>
# <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
# <td class="num">1</td>
# <td class="sdata_player_img">
# <a content="https://www.resultados-futbol.com/jugador/A-Baroja-114644" href="https://www.resultados-futbol.com/jugador/A-Baroja-114644" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/114644.jpg?size=60x&amp;5" width="37"/></a>
# </td>
# <th class="sdata_player_name">
# <a content="https://www.resultados-futbol.com/jugador/A-Baroja-114644" href="https://www.resultados-futbol.com/jugador/A-Baroja-114644" itemprop="url"><span itemprop="name">A. Baroja</span></a>
# </th>
# <td class="birthdate" content="1989-10-23T00:00:00+01:00" itemprop="birthDate"><b>32</b></td>
# <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
# <td class="dat">183</td>
# <td class="dat">79</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# </tr>
# <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
# <td class="num">35</td>
# <td class="sdata_player_img">
# <a content="https://www.resultados-futbol.com/jugador/Frankarlos-Benitez-904991" href="https://www.resultados-futbol.com/jugador/Frankarlos-Benitez-904991" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/904991.jpg?size=60x&amp;5" width="37"/></a>
# </td>
# <th class="sdata_player_name">
# <a content="https://www.resultados-futbol.com/jugador/Frankarlos-Benitez-904991" href="https://www.resultados-futbol.com/jugador/Frankarlos-Benitez-904991" itemprop="url"><span itemprop="name">Frankarlos BenÃ­tez</span></a>
# </th>
# <td class="birthdate" content="2004-05-03T00:00:00+02:00" itemprop="birthDate"><b>18</b></td>
# <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
# <td class="dat">184</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# </tr>
# <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
# <td class="num">23</td>
# <td class="sdata_player_img">
# <a content="https://www.resultados-futbol.com/jugador/W-Hernandez-802360" href="https://www.resultados-futbol.com/jugador/W-Hernandez-802360" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/802360.jpg?size=60x&amp;5" width="37"/></a>
# </td>
# <th class="sdata_player_name">
# <a content="https://www.resultados-futbol.com/jugador/W-Hernandez-802360" href="https://www.resultados-futbol.com/jugador/W-Hernandez-802360" itemprop="url"><span itemprop="name">W. HernÃ¡ndez</span></a>
# </th>
# <td class="birthdate" content="2001-03-02T00:00:00+01:00" itemprop="birthDate"><b>21</b></td>
# <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
# <td class="dat">185</td>
# <td class="dat">82</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# </tr>
# <tr class="first-child">
# <th axis="position" class="axis" colspan="11">Defensa</th>
# </tr>
# <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
# <td class="num">13</td>
# <td class="sdata_player_img">
# <a content="https://www.resultados-futbol.com/jugador/Carlos-Rivero-125106" href="https://www.resultados-futbol.com/jugador/Carlos-Rivero-125106" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/125106.jpg?size=60x&amp;5" width="37"/></a>
# </td>
# <th class="sdata_player_name">
# <a content="https://www.resultados-futbol.com/jugador/Carlos-Rivero-125106" href="https://www.resultados-futbol.com/jugador/Carlos-Rivero-125106" itemprop="url"><span itemprop="name">C. Rivero</span></a>
# </th>
# <td class="birthdate" content="1992-11-27T00:00:00+01:00" itemprop="birthDate"><b>29</b></td>
# <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
# <td class="dat">182</td>
# <td class="dat">80</td>
# <td class="dat">1</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# </tr>
# <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
# <td class="num">4</td>
# <td class="sdata_player_img">
# <a content="https://www.resultados-futbol.com/jugador/D-Osio-198157" href="https://www.resultados-futbol.com/jugador/D-Osio-198157" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/198157.jpg?size=60x&amp;5" width="37"/></a>
# </td>
# <th class="sdata_player_name">
# <a content="https://www.resultados-futbol.com/jugador/D-Osio-198157" href="https://www.resultados-futbol.com/jugador/D-Osio-198157" itemprop="url"><span itemprop="name">D. Osio</span></a>
# </th>
# <td class="birthdate" content="1997-01-03T00:00:00+01:00" itemprop="birthDate"><b>25</b></td>
# <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
# <td class="dat">192</td>
# <td class="dat">79</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# </tr>
# <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
# <td class="num">5</td>
# <td class="sdata_player_img">
# <a content="https://www.resultados-futbol.com/jugador/D-Rivillo-349731" href="https://www.resultados-futbol.com/jugador/D-Rivillo-349731" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/349731.jpg?size=60x&amp;5" width="37"/></a>
# </td>
# <th class="sdata_player_name">
# <a content="https://www.resultados-futbol.com/jugador/D-Rivillo-349731" href="https://www.resultados-futbol.com/jugador/D-Rivillo-349731" itemprop="url"><span itemprop="name">D. Rivillo</span></a>
# </th>
# <td class="birthdate" content="1996-12-21T00:00:00+01:00" itemprop="birthDate"><b>25</b></td>
# <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
# <td class="dat">179</td>
# <td class="dat">72</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# </tr>
# <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
# <td class="num">2</td>
# <td class="sdata_player_img">
# <a content="https://www.resultados-futbol.com/jugador/Eduardo-Enriqueferreira-Penaranda-365336" href="https://www.resultados-futbol.com/jugador/Eduardo-Enriqueferreira-Penaranda-365336" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/365336.jpg?size=60x&amp;5" width="37"/></a>
# </td>
# <th class="sdata_player_name">
# <a content="https://www.resultados-futbol.com/jugador/Eduardo-Enriqueferreira-Penaranda-365336" href="https://www.resultados-futbol.com/jugador/Eduardo-Enriqueferreira-Penaranda-365336" itemprop="url"><span itemprop="name">E. Fereira</span></a>
# </th>
# <td class="birthdate" content="2000-09-29T00:00:00+02:00" itemprop="birthDate"><b>21</b></td>
# <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
# <td class="dat">169</td>
# <td class="dat">63</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# <td class="dat">3</td>
# </tr>
# <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
# <td class="num">27</td>
# <td class="sdata_player_img">
# <a content="https://www.resultados-futbol.com/jugador/J-Da-Silva-995626" href="https://www.resultados-futbol.com/jugador/J-Da-Silva-995626" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/995626.jpg?size=60x&amp;5" width="37"/></a>
# </td>
# <th class="sdata_player_name">
# <a content="https://www.resultados-futbol.com/jugador/J-Da-Silva-995626" href="https://www.resultados-futbol.com/jugador/J-Da-Silva-995626" itemprop="url"><span itemprop="name">J. Velasquez</span></a>
# </th>
# <td class="birthdate" content="2001-06-06T00:00:00+02:00" itemprop="birthDate"><b>21</b></td>
# <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
# <td class="dat">185</td>
# <td class="dat">77</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# </tr>
# <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
# <td class="num">26</td>
# <td class="sdata_player_img">
# <a content="https://www.resultados-futbol.com/jugador/M-Rivas-901417" href="https://www.resultados-futbol.com/jugador/M-Rivas-901417" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/901417.jpg?size=60x&amp;5" width="37"/></a>
# </td>
# <th class="sdata_player_name">
# <a content="https://www.resultados-futbol.com/jugador/M-Rivas-901417" href="https://www.resultados-futbol.com/jugador/M-Rivas-901417" itemprop="url"><span itemprop="name">M. Rivas</span></a>
# </th>
# <td class="birthdate" content="1999-05-01T00:00:00+02:00" itemprop="birthDate"><b>23</b></td>
# <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
# <td class="dat">188</td>
# <td class="dat">85</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# </tr>
# <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
# <td class="num">6</td>
# <td class="sdata_player_img">
# <a content="https://www.resultados-futbol.com/jugador/Rubert-Quijada-138647" href="https://www.resultados-futbol.com/jugador/Rubert-Quijada-138647" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/138647.jpg?size=60x&amp;5" width="37"/></a>
# </td>
# <th class="sdata_player_name">
# <a content="https://www.resultados-futbol.com/jugador/Rubert-Quijada-138647" href="https://www.resultados-futbol.com/jugador/Rubert-Quijada-138647" itemprop="url"><span itemprop="name">R. Quijada</span></a>
# </th>
# <td class="birthdate" content="1989-02-10T00:00:00+01:00" itemprop="birthDate"><b>33</b></td>
# <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
# <td class="dat">186</td>
# <td class="dat">73</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# <td class="dat">1</td>
# </tr>
# <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
# <td class="num">3</td>
# <td class="sdata_player_img">
# <a content="https://www.resultados-futbol.com/jugador/R-Villanueva-245226" href="https://www.resultados-futbol.com/jugador/R-Villanueva-245226" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/245226.jpg?size=60x&amp;5" width="37"/></a>
# </td>
# <th class="sdata_player_name">
# <a content="https://www.resultados-futbol.com/jugador/R-Villanueva-245226" href="https://www.resultados-futbol.com/jugador/R-Villanueva-245226" itemprop="url"><span itemprop="name">R. Villanueva</span></a>
# </th>
# <td class="birthdate" content="1992-08-16T00:00:00+02:00" itemprop="birthDate"><b>29</b></td>
# <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
# <td class="dat">175</td>
# <td class="dat">70</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# </tr>
# <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
# <td class="num">14</td>
# <td class="sdata_player_img">
# <a content="https://www.resultados-futbol.com/jugador/Sandronotaroberto-282544" href="https://www.resultados-futbol.com/jugador/Sandronotaroberto-282544" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/282544.jpg?size=60x&amp;5" width="37"/></a>
# </td>
# <th class="sdata_player_name">
# <a content="https://www.resultados-futbol.com/jugador/Sandronotaroberto-282544" href="https://www.resultados-futbol.com/jugador/Sandronotaroberto-282544" itemprop="url"><span itemprop="name">S. Notaroberto</span></a>
# </th>
# <td class="birthdate" content="1998-03-10T00:00:00+01:00" itemprop="birthDate"><b>24</b></td>
# <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
# <td class="dat">175</td>
# <td class="dat">73</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# <td class="dat">2</td>
# </tr>
# <tr class="first-child">
# <th axis="position" class="axis" colspan="11">Centrocampista</th>
# </tr>
# <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
# <td class="num">17</td>
# <td class="sdata_player_img">
# <a content="https://www.resultados-futbol.com/jugador/C-Suarez-243855" href="https://www.resultados-futbol.com/jugador/C-Suarez-243855" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/243855.jpg?size=60x&amp;5" width="37"/></a>
# </td>
# <th class="sdata_player_name">
# <a content="https://www.resultados-futbol.com/jugador/C-Suarez-243855" href="https://www.resultados-futbol.com/jugador/C-Suarez-243855" itemprop="url"><span itemprop="name">C. SuÃ¡rez</span></a>
# </th>
# <td class="birthdate" content="1992-04-26T00:00:00+02:00" itemprop="birthDate"><b>30</b></td>
# <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
# <td class="dat">170</td>
# <td class="dat">68</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# <td class="dat">2</td>
# </tr>
# <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
# <td class="num">8</td>
# <td class="sdata_player_img">
# <a content="https://www.resultados-futbol.com/jugador/E-Castillo-103813" href="https://www.resultados-futbol.com/jugador/E-Castillo-103813" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/103813.jpg?size=60x&amp;5" width="37"/></a>
# </td>
# <th class="sdata_player_name">
# <a content="https://www.resultados-futbol.com/jugador/E-Castillo-103813" href="https://www.resultados-futbol.com/jugador/E-Castillo-103813" itemprop="url"><span itemprop="name">E. Castillo</span></a>
# </th>
# <td class="birthdate" content="1994-05-18T00:00:00+02:00" itemprop="birthDate"><b>28</b></td>
# <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
# <td class="dat">175</td>
# <td class="dat">76</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# <td class="dat">2</td>
# </tr>
# <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
# <td class="num">30</td>
# <td class="sdata_player_img">
# <a content="https://www.resultados-futbol.com/jugador/J-Torres-3168491" href="https://www.resultados-futbol.com/jugador/J-Torres-3168491" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/media/img/avatar-player.jpg?size=60x" width="37"/></a>
# </td>
# <th class="sdata_player_name">
# <a content="https://www.resultados-futbol.com/jugador/J-Torres-3168491" href="https://www.resultados-futbol.com/jugador/J-Torres-3168491" itemprop="url"><span itemprop="name">J. Torres</span></a>
# </th>
# <td class="birthdate" content="2003-03-02T00:00:00+01:00" itemprop="birthDate"><b>19</b></td>
# <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# </tr>
# <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
# <td class="num">24</td>
# <td class="sdata_player_img">
# <a content="https://www.resultados-futbol.com/jugador/L-Gonzalez-751703" href="https://www.resultados-futbol.com/jugador/L-Gonzalez-751703" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/751703.jpg?size=60x&amp;5" width="37"/></a>
# </td>
# <th class="sdata_player_name">
# <a content="https://www.resultados-futbol.com/jugador/L-Gonzalez-751703" href="https://www.resultados-futbol.com/jugador/L-Gonzalez-751703" itemprop="url"><span itemprop="name">L. GonzÃ¡lez</span></a>
# </th>
# <td class="birthdate" content="1998-11-27T00:00:00+01:00" itemprop="birthDate"><b>23</b></td>
# <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
# <td class="dat">174</td>
# <td class="dat">65</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# </tr>
# <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
# <td class="num">11</td>
# <td class="sdata_player_img">
# <a content="https://www.resultados-futbol.com/jugador/Luis-Ramirez-280721" href="https://www.resultados-futbol.com/jugador/Luis-Ramirez-280721" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/280721.jpg?size=60x&amp;5" width="37"/></a>
# </td>
# <th class="sdata_player_name">
# <a content="https://www.resultados-futbol.com/jugador/Luis-Ramirez-280721" href="https://www.resultados-futbol.com/jugador/Luis-Ramirez-280721" itemprop="url"><span itemprop="name">L. RamÃ­rez</span></a>
# </th>
# <td class="birthdate" content="1997-07-02T00:00:00+02:00" itemprop="birthDate"><b>25</b></td>
# <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
# <td class="dat">177</td>
# <td class="dat">66</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# </tr>
# <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
# <td class="num">21</td>
# <td class="sdata_player_img">
# <a content="https://www.resultados-futbol.com/jugador/V-Rodriguez-314353" href="https://www.resultados-futbol.com/jugador/V-Rodriguez-314353" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/314353.jpg?size=60x&amp;5" width="37"/></a>
# </td>
# <th class="sdata_player_name">
# <a content="https://www.resultados-futbol.com/jugador/V-Rodriguez-314353" href="https://www.resultados-futbol.com/jugador/V-Rodriguez-314353" itemprop="url"><span itemprop="name">V. RodrÃ­guez</span></a>
# </th>
# <td class="birthdate" content="1990-04-05T00:00:00+02:00" itemprop="birthDate"><b>32</b></td>
# <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
# <td class="dat">177</td>
# <td class="dat">71</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# <td class="dat">1</td>
# </tr>
# <tr class="first-child">
# <th axis="position" class="axis" colspan="11">Delantero</th>
# </tr>
# <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
# <td class="num">10</td>
# <td class="sdata_player_img">
# <a content="https://www.resultados-futbol.com/jugador/A-Zambrano-280171" href="https://www.resultados-futbol.com/jugador/A-Zambrano-280171" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/280171.jpg?size=60x&amp;5" width="37"/></a>
# </td>
# <th class="sdata_player_name">
# <a content="https://www.resultados-futbol.com/jugador/A-Zambrano-280171" href="https://www.resultados-futbol.com/jugador/A-Zambrano-280171" itemprop="url"><span itemprop="name">A. Zambrano</span></a>
# </th>
# <td class="birthdate" content="1995-10-01T00:00:00+01:00" itemprop="birthDate"><b>26</b></td>
# <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
# <td class="dat">179</td>
# <td class="dat">73</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# </tr>
# <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
# <td class="num">15</td>
# <td class="sdata_player_img">
# <a content="https://www.resultados-futbol.com/jugador/Ade-Oguns-3139548" href="https://www.resultados-futbol.com/jugador/Ade-Oguns-3139548" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/3139548.jpg?size=60x&amp;5" width="37"/></a>
# </td>
# <th class="sdata_player_name">
# <a content="https://www.resultados-futbol.com/jugador/Ade-Oguns-3139548" href="https://www.resultados-futbol.com/jugador/Ade-Oguns-3139548" itemprop="url"><span itemprop="name">Ade Oguns</span></a>
# </th>
# <td class="birthdate" content="2001-04-14T00:00:00+02:00" itemprop="birthDate"><b>21</b></td>
# <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="NG" itemprop="name"></span><img alt="ng" class="flag f_ng" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ng"/></td>
# <td class="dat">176</td>
# <td class="dat">76</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# </tr>
# <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
# <td class="num">33</td>
# <td class="sdata_player_img">
# <a content="https://www.resultados-futbol.com/jugador/B-Albizo-3240392" href="https://www.resultados-futbol.com/jugador/B-Albizo-3240392" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/media/img/avatar-player.jpg?size=60x" width="37"/></a>
# </td>
# <th class="sdata_player_name">
# <a content="https://www.resultados-futbol.com/jugador/B-Albizo-3240392" href="https://www.resultados-futbol.com/jugador/B-Albizo-3240392" itemprop="url"><span itemprop="name">B. Albizo</span></a>
# </th>
# <td class="birthdate" content="2003-05-05T00:00:00+02:00" itemprop="birthDate"><b>19</b></td>
# <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
# <td class="dat">170</td>
# <td class="dat">58</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# </tr>
# <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
# <td class="num">32</td>
# <td class="sdata_player_img">
# <a content="https://www.resultados-futbol.com/jugador/B-Ortega-3178203" href="https://www.resultados-futbol.com/jugador/B-Ortega-3178203" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/3178203.jpg?size=60x&amp;5" width="37"/></a>
# </td>
# <th class="sdata_player_name">
# <a content="https://www.resultados-futbol.com/jugador/B-Ortega-3178203" href="https://www.resultados-futbol.com/jugador/B-Ortega-3178203" itemprop="url"><span itemprop="name">B. Ortega</span></a>
# </th>
# <td class="birthdate" content="2003-02-28T00:00:00+01:00" itemprop="birthDate"><b>19</b></td>
# <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# <td class="dat">1</td>
# </tr>
# <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
# <td class="num">18</td>
# <td class="sdata_player_img">
# <a content="https://www.resultados-futbol.com/jugador/Denilson-Josueovando-Ramirez-364886" href="https://www.resultados-futbol.com/jugador/Denilson-Josueovando-Ramirez-364886" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/364886.jpg?size=60x&amp;5" width="37"/></a>
# </td>
# <th class="sdata_player_name">
# <a content="https://www.resultados-futbol.com/jugador/Denilson-Josueovando-Ramirez-364886" href="https://www.resultados-futbol.com/jugador/Denilson-Josueovando-Ramirez-364886" itemprop="url"><span itemprop="name">D. Ovando</span></a>
# </th>
# <td class="birthdate" content="2001-09-23T00:00:00+02:00" itemprop="birthDate"><b>20</b></td>
# <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="EC" itemprop="name"></span><img alt="ec" class="flag f_ec" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ec"/></td>
# <td class="dat">181</td>
# <td class="dat">68</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# </tr>
# <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
# <td class="num">28</td>
# <td class="sdata_player_img">
# <a content="https://www.resultados-futbol.com/jugador/E-Moreno-848301" href="https://www.resultados-futbol.com/jugador/E-Moreno-848301" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/848301.jpg?size=60x&amp;5" width="37"/></a>
# </td>
# <th class="sdata_player_name">
# <a content="https://www.resultados-futbol.com/jugador/E-Moreno-848301" href="https://www.resultados-futbol.com/jugador/E-Moreno-848301" itemprop="url"><span itemprop="name">E. Moreno</span></a>
# </th>
# <td class="birthdate" content="2000-06-30T00:00:00+02:00" itemprop="birthDate"><b>22</b></td>
# <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
# <td class="dat">78</td>
# <td class="dat">72</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# </tr>
# <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
# <td class="num">37</td>
# <td class="sdata_player_img">
# <a content="https://www.resultados-futbol.com/jugador/F-Guerra-3241845" href="https://www.resultados-futbol.com/jugador/F-Guerra-3241845" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/media/img/avatar-player.jpg?size=60x" width="37"/></a>
# </td>
# <th class="sdata_player_name">
# <a content="https://www.resultados-futbol.com/jugador/F-Guerra-3241845" href="https://www.resultados-futbol.com/jugador/F-Guerra-3241845" itemprop="url"><span itemprop="name">F. Guerra</span></a>
# </th>
# <td class="birthdate" content="2004-04-23T00:00:00+02:00" itemprop="birthDate"><b>18</b></td>
# <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
# <td class="dat">176</td>
# <td class="dat">77</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# </tr>
# <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
# <td class="num">19</td>
# <td class="sdata_player_img">
# <a content="https://www.resultados-futbol.com/jugador/K-Bonsu-836051" href="https://www.resultados-futbol.com/jugador/K-Bonsu-836051" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/836051.jpg?size=60x&amp;5" width="37"/></a>
# </td>
# <th class="sdata_player_name">
# <a content="https://www.resultados-futbol.com/jugador/K-Bonsu-836051" href="https://www.resultados-futbol.com/jugador/K-Bonsu-836051" itemprop="url"><span itemprop="name">K. Bonsu</span></a>
# </th>
# <td class="birthdate" content="2000-08-17T00:00:00+02:00" itemprop="birthDate"><b>21</b></td>
# <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="GH" itemprop="name"></span><img alt="gh" class="flag f_gh" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="gh"/></td>
# <td class="dat">168</td>
# <td class="dat">66</td>
# <td class="dat">1</td>
# <td class="dat">-</td>
# <td class="dat">1</td>
# </tr>
# <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
# <td class="num">7</td>
# <td class="sdata_player_img">
# <a content="https://www.resultados-futbol.com/jugador/M-Celis-321783" href="https://www.resultados-futbol.com/jugador/M-Celis-321783" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/321783.jpg?size=60x&amp;5" width="37"/></a>
# </td>
# <th class="sdata_player_name">
# <a content="https://www.resultados-futbol.com/jugador/M-Celis-321783" href="https://www.resultados-futbol.com/jugador/M-Celis-321783" itemprop="url"><span itemprop="name">M. Celis</span></a>
# </th>
# <td class="birthdate" content="1995-09-09T00:00:00+02:00" itemprop="birthDate"><b>26</b></td>
# <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
# <td class="dat">190</td>
# <td class="dat">79</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# </tr>
# <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
# <td class="num">31</td>
# <td class="sdata_player_img">
# <a content="https://www.resultados-futbol.com/jugador/M-Molina-623699" href="https://www.resultados-futbol.com/jugador/M-Molina-623699" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/623699.jpg?size=60x&amp;5" width="37"/></a>
# </td>
# <th class="sdata_player_name">
# <a content="https://www.resultados-futbol.com/jugador/M-Molina-623699" href="https://www.resultados-futbol.com/jugador/M-Molina-623699" itemprop="url"><span itemprop="name">M. Molina</span></a>
# </th>
# <td class="birthdate" content="1999-06-10T00:00:00+02:00" itemprop="birthDate"><b>23</b></td>
# <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
# <td class="dat">174</td>
# <td class="dat">68</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# </tr>
# <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
# <td class="num">22</td>
# <td class="sdata_player_img">
# <a content="https://www.resultados-futbol.com/jugador/M-Sulbaran-3142178" href="https://www.resultados-futbol.com/jugador/M-Sulbaran-3142178" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/3142178.jpg?size=60x&amp;5" width="37"/></a>
# </td>
# <th class="sdata_player_name">
# <a content="https://www.resultados-futbol.com/jugador/M-Sulbaran-3142178" href="https://www.resultados-futbol.com/jugador/M-Sulbaran-3142178" itemprop="url"><span itemprop="name">M. SulbarÃ¡n</span></a>
# </th>
# <td class="birthdate" content="2002-10-08T00:00:00+02:00" itemprop="birthDate"><b>19</b></td>
# <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
# <td class="dat">165</td>
# <td class="dat">59</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# </tr>
# <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
# <td class="num">9</td>
# <td class="sdata_player_img">
# <a content="https://www.resultados-futbol.com/jugador/A-Samson-877794" href="https://www.resultados-futbol.com/jugador/A-Samson-877794" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/877794.jpg?size=60x&amp;5" width="37"/></a>
# </td>
# <th class="sdata_player_name">
# <a content="https://www.resultados-futbol.com/jugador/A-Samson-877794" href="https://www.resultados-futbol.com/jugador/A-Samson-877794" itemprop="url"><span itemprop="name">S. Akinyoola</span></a>
# </th>
# <td class="birthdate" content="2000-03-03T00:00:00+01:00" itemprop="birthDate"><b>22</b></td>
# <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="BJ" itemprop="name"></span><img alt="bj" class="flag f_bj" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="bj"/></td>
# <td class="dat">170</td>
# <td class="dat">75</td>
# <td class="dat">2</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# </tr>
# <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
# <td class="num">16</td>
# <td class="sdata_player_img">
# <a content="https://www.resultados-futbol.com/jugador/S-Guarirapa-895242" href="https://www.resultados-futbol.com/jugador/S-Guarirapa-895242" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/895242.jpg?size=60x&amp;5" width="37"/></a>
# </td>
# <th class="sdata_player_name">
# <a content="https://www.resultados-futbol.com/jugador/S-Guarirapa-895242" href="https://www.resultados-futbol.com/jugador/S-Guarirapa-895242" itemprop="url"><span itemprop="name">S. Guarirapa</span></a>
# </th>
# <td class="birthdate" content="2002-10-18T00:00:00+02:00" itemprop="birthDate"><b>19</b></td>
# <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
# <td class="dat">188</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# <td class="dat">1</td>
# </tr>
# </tbody>
# </table>

# %%
ccs_plantilla = ccs_soup.find('table', attrs= {'class':'sdata_table'}).find_all('td', attrs = {'class':'num'})
ccs_plantilla
# Out:
# [<td class="num">1</td>,
#  <td class="num">35</td>,
#  <td class="num">23</td>,
#  <td class="num">13</td>,
#  <td class="num">4</td>,
#  <td class="num">5</td>,
#  <td class="num">2</td>,
#  <td class="num">27</td>,
#  <td class="num">26</td>,
#  <td class="num">6</td>,
#  <td class="num">3</td>,
#  <td class="num">14</td>,
#  <td class="num">17</td>,
#  <td class="num">8</td>,
#  <td class="num">30</td>,
#  <td class="num">24</td>,
#  <td class="num">11</td>,
#  <td class="num">21</td>,
#  <td class="num">10</td>,
#  <td class="num">15</td>,
#  <td class="num">33</td>,
#  <td class="num">32</td>,
#  <td class="num">18</td>,
#  <td class="num">28</td>,
#  <td class="num">37</td>,
#  <td class="num">19</td>,
#  <td class="num">7</td>,
#  <td class="num">31</td>,
#  <td class="num">22</td>,
#  <td class="num">9</td>,
#  <td class="num">16</td>]

# %%
len(ccs_plantilla)
# Out:
# 31

# %%
jugador = ccs_plantilla[0]
jugador.text
# Out:
# '1'

# %%
url = 'https://www.resultados-futbol.com/Caracas-Venezuela'
r = requests.get(url)
ccs_soup = BeautifulSoup(r.text, 'lxml')

# %%
print(ccs_soup.prettify())
# Out:
# <html>
#  <body>
#   <p>
#    ï»¿
#    <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 Transitional//EN" "https://www.w3.org/TR/xhtml1/DTD/xhtml1-transitional.dtd">
#    <!-- PRODUCTION | NOT RENEW MEM	| 1657829263 -->
#   </p>
#   <meta description="www.resultados-futbol.com/Caracas-Venezuela-181.130.10.164"/>
#   <title>
#    Caracas - Copa Libertadores  G 2
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="Plantilla Caracas: " name="description"/>
#   <meta content="resultados de futbol, primera division, segunda division, segunda b, tercera division, barcelona, real madrid, futbol, resultados, goles, jugadores, pplantillas" name="keywords"/>
#   <meta content="app-id=550928207" name="apple-itunes-app"/>
#   <meta content="app-id=com.resultadosfutbol.mobile" name="google-play-app"/>
#   <meta content="J7YUFA5i8BiSLSb9d1KxXBpiMo91bb7C44CBsT78920=" name="verify-v1"/>
#   <meta content="text/css" http-equiv="Content-Style-Type"/>
#   <meta content="e5d5f91fdb693e94f895e44542511f08" name="inmobi-site-verification"/>
#   <meta content="index, follow" name="robots"/>
#   <meta content="300" http-equiv="refresh"/>
#   <link href="/media/osearch/osearch_es.xml" rel="search" title="Buscador de resultados-Futbol.com" type="application/opensearchdescription+xml"/>
#   <!-- android -->
#   <link href="https://t.resfu.com/media/images/favicon-152.png" rel="apple-touch-icon-precomposed"/>
#   <!-- internet explorer y metro -->
#   <meta content="#FFFFFF" name="msapplication-TileColor"/>
#   <meta content="https://t.resfu.com/media/images/favicon2-144.png" name="msapplication-TileImage"/>
#   <!-- apple -->
#   <link href="https://t.resfu.com/media/images/favicon-152.png" rel="apple-touch-icon-precomposed" sizes="152x152"/>
#   <link href="https://t.resfu.com/media/images/favicon-144.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>
#   <link href="https://t.resfu.com/media/images/favicon-120.png" rel="apple-touch-icon-precomposed" sizes="120x120"/>
#   <link href="https://t.resfu.com/media/images/favicon-114.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>
#   <link href="https://t.resfu.com/media/images/favicon-72.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>
#   <link href="https://t.resfu.com/media/images/favicon-57.png" rel="apple-touch-icon-precomposed"/>
#   <!-- otros -->
#   <link href="/media/images/favicon.ico?v=2" rel="shortcut icon"/>
#   <link href="/media/images/favicon.ico?v=2" rel="icon" sizes="16x16 32x32"/>
#   <!-- PIXEL BESOCY -->
#   <script>
#    (function(d,s,id,h,t){
#    var js,r,djs = d.getElementsByTagName(s)[0];
#    if (d.getElementById(id)) {return;}
#    js = d.createElement('script');js.id =id;js.async=1;
#    js.h=h;js.t=t;
#    r=encodeURI(btoa(d.referrer));
#    js.src="//"+h+"/pixel/js/"+t+"/"+r;
#    djs.parentNode.insertBefore(js, djs);
#   }(document, 'script', 'dogtrack-pixel','beso.spxl.socy.es', 'BESO_923_842_998'));
#   </script>
#   <!-- * end pixel Besocy * -->
#   <!-- Start Alexa Certify Javascript -->
#   <script type="text/javascript">
#    _atrk_opts = { atrk_acct:"jrzPh1aon800EO", domain:"resultados-futbol.com",dynamic: true};
# (function() { var as = document.createElement('script'); as.type = 'text/javascript'; as.async = true; as.src = "https://certify-js.alexametrics.com/atrk.js"; var s = document.getElementsByTagName('script')[0];s.parentNode.insertBefore(as, s); })();
#   </script>
#   <noscript>
#    <img alt="" height="1" src="https://certify.alexametrics.com/atrk.gif?account=jrzPh1aon800EO" style="display:none" width="1"/>
#   </noscript>
#   <!-- End Alexa Certify Javascript -->
#   <!-- Quantcast Choice. Consent Manager Tag v2.0 (for TCF 2.0) -->
#   <script async="true" type="text/javascript">
#    (function() {
#   var host = window.location.hostname;
#   var element = document.createElement('script');
#   var firstScript = document.getElementsByTagName('script')[0];
#   var url = 'https://cmp.quantcast.com'
#     .concat('/choice/', 'PM1PaqFTUH-yn', '/', host, '/choice.js');
#   var uspTries = 0;
#   var uspTriesLimit = 3;
#   element.async = true;
#   element.type = 'text/javascript';
#   element.src = url;
#
#   firstScript.parentNode.insertBefore(element, firstScript);
#
#   function makeStub() {
#     var TCF_LOCATOR_NAME = '__tcfapiLocator';
#     var queue = [];
#     var win = window;
#     var cmpFrame;
#
#     function addFrame() {
#       var doc = win.document;
#       var otherCMP = !!(win.frames[TCF_LOCATOR_NAME]);
#
#       if (!otherCMP) {
#         if (doc.body) {
#           var iframe = doc.createElement('iframe');
#
#           iframe.style.cssText = 'display:none';
#           iframe.name = TCF_LOCATOR_NAME;
#           doc.body.appendChild(iframe);
#         } else {
#           setTimeout(addFrame, 5);
#         }
#       }
#       return !otherCMP;
#     }
#
#     function tcfAPIHandler() {
#       var gdprApplies;
#       var args = arguments;
#
#       if (!args.length) {
#         return queue;
#       } else if (args[0] === 'setGdprApplies') {
#         if (
#           args.length > 3 &&
#           args[2] === 2 &&
#           typeof args[3] === 'boolean'
#         ) {
#           gdprApplies = args[3];
#           if (typeof args[2] === 'function') {
#             args[2]('set', true);
#           }
#         }
#       } else if (args[0] === 'ping') {
#         var retr = {
#           gdprApplies: gdprApplies,
#           cmpLoaded: false,
#           cmpStatus: 'stub'
#         };
#
#         if (typeof args[2] === 'function') {
#           args[2](retr);
#         }
#       } else {
#         if(args[0] === 'init' && typeof args[3] === 'object') {
#           args[3] = { ...args[3], tag_version: 'V2' };
#         }
#         queue.push(args);
#       }
#     }
#
#     function postMessageEventHandler(event) {
#       var msgIsString = typeof event.data === 'string';
#       var json = {};
#
#       try {
#         if (msgIsString) {
#           json = JSON.parse(event.data);
#         } else {
#           json = event.data;
#         }
#       } catch (ignore) {}
#
#       var payload = json.__tcfapiCall;
#
#       if (payload) {
#         window.__tcfapi(
#           payload.command,
#           payload.version,
#           function(retValue, success) {
#             var returnMsg = {
#               __tcfapiReturn: {
#                 returnValue: retValue,
#                 success: success,
#                 callId: payload.callId
#               }
#             };
#             if (msgIsString) {
#               returnMsg = JSON.stringify(returnMsg);
#             }
#             if (event && event.source && event.source.postMessage) {
#               event.source.postMessage(returnMsg, '*');
#             }
#           },
#           payload.parameter
#         );
#       }
#     }
#
#     while (win) {
#       try {
#         if (win.frames[TCF_LOCATOR_NAME]) {
#           cmpFrame = win;
#           break;
#         }
#       } catch (ignore) {}
#
#       if (win === window.top) {
#         break;
#       }
#       win = win.parent;
#     }
#     if (!cmpFrame) {
#       addFrame();
#       win.__tcfapi = tcfAPIHandler;
#       win.addEventListener('message', postMessageEventHandler, false);
#     }
#   };
#
#   makeStub();
#
#   var uspStubFunction = function() {
#     var arg = arguments;
#     if (typeof window.__uspapi !== uspStubFunction) {
#       setTimeout(function() {
#         if (typeof window.__uspapi !== 'undefined') {
#           window.__uspapi.apply(window.__uspapi, arg);
#         }
#       }, 500);
#     }
#   };
#
#   var checkIfUspIsReady = function() {
#     uspTries++;
#     if (window.__uspapi === uspStubFunction && uspTries < uspTriesLimit) {
#       console.warn('USP is not accessible');
#     } else {
#       clearInterval(uspInterval);
#     }
#   };
#
#   if (typeof window.__uspapi === 'undefined') {
#     window.__uspapi = uspStubFunction;
#     var uspInterval = setInterval(checkIfUspIsReady, 6000);
#   }
# })();
#   </script>
#   <!-- End Quantcast Choice. Consent Manager Tag v2.0 (for TCF 2.0) -->
#   <script async="" src="https://ssm.codes/smart-tag/resultados-futbolcom.js">
#   </script>
#   <script type="text/javascript">
#    _atrk_opts = { atrk_acct:"jrzPh1aon800EO", domain:"resultados-futbol.com",dynamic: true};
# (function() { var as = document.createElement('script'); as.type = 'text/javascript'; as.async = true; as.src = "https://d31qbv1cthcecs.cloudfront.net/atrk.js"; var s = document.getElementsByTagName('script')[0];s.parentNode.insertBefore(as, s); })();
#   </script>
#   <noscript>
#    <img alt="" height="1" src="https://d5nxst8fruw4z.cloudfront.net/atrk.gif?account=jrzPh1aon800EO" style="display:none" width="1"/>
#   </noscript>
#   <!-- Begin comScore Tag old:16785528-->
#   <script>
#    var _comscore = _comscore || [];
# 	_comscore.push({ c1: "2", c2: "20105429" });
# 	(function() {
# 	var s = document.createElement("script"), el =
# 	document.getElementsByTagName("script")[0]; s.async = true;
# 	s.src = (document.location.protocol == "https:" ? "https://sb" :
# 	"http://b") + ".scorecardresearch.com/beacon.js";
# 	el.parentNode.insertBefore(s, el);
# 	})();
#   </script>
#   <noscript>
#    <img src="https://b.scorecardresearch.com/p?c1=2&amp;c2=20105429&amp;cv=2.0&amp;cj=1"/>
#   </noscript>
#   <!-- End comScore Tag -->
#   <!-- Begin comScore Tag -->
#   <!--<script>
#   var _comscore = _comscore || [];
#   _comscore.push({ c1: "2", c2: "20113989" });
#   (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#     el.parentNode.insertBefore(s, el);
#   })();
# </script>
# <noscript>
#   <img src="http://b.scorecardresearch.com/p?c1=2&c2=20113989&cv=2.0&cj=1" />
# </noscript>-->
#   <!-- End comScore Tag -->
#   <link href="https://www.resultados-futbol.com/media/css_less/resultados-futbol/resultados-futbol.css?ch=401260121" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="https://www.resultados-futbol.com/media/css_less/resultados-futbol/secciones/team.css?ch=401260121" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="https://www.resultados-futbol.com/media/css_less/resultados-futbol/secciones/home_news.css?ch=401260121" media="screen" rel="stylesheet" type="text/css"/>
#   <!--[if IE]>
# 		<link href="https://st9.resfu.com/media/css/ie.css" rel="stylesheet" type="text/css" />
# 	<![endif]-->
#   <!--[if IE 6]>
# 	<link href="https://st9.resfu.com/media/css/menuie6.css" rel="stylesheet" type="text/css" />
# 	<link href="https://st9.resfu.com/media/css/ie6.css" rel="stylesheet" type="text/css" />
# 	<![endif]-->
#   <!--[if IE 7]>
# 		<link href="https://st9.resfu.com/media/css/menuie7.css" rel="stylesheet" type="text/css" />
# 	<![endif]-->
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 		(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 		m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 		})(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
# 		ga('create', 'UA-26865821-7', 'auto');
#
# 		ga('send', 'pageview');
#   </script>
#   <!-- Default Statcounter code for Resultados-Futbol -->
#   <script type="text/javascript">
#    var sc_project=1954957;
# 		var sc_invisible=1;
# 		var sc_security="f32d450e";
# 		var sc_https=1;
#   </script>
#   <script async="" src="https://www.statcounter.com/counter/counter.js" type="text/javascript">
#   </script>
#   <noscript>
#    <div class="statcounter">
#     <a href="https://statcounter.com/" target="_blank" title="Web Analytics">
#      <img alt="Web
# 			Analytics" class="statcounter" src="//c.statcounter.com/1954957/0/f32d450e/1/"/>
#     </a>
#    </div>
#   </noscript>
#   <!-- End of Statcounter Code -->
#   <script>
#    var APP_DIR = 'https://www.resultados-futbol.com/';
# 				APP_DIR = (document.location.protocol == "https:" ? APP_DIR.replace("http://", "https://") : 'https://www.resultados-futbol.com/');
#
# 				var COOKIE_NAME = 'rf_data';
# 				var APP_NAME = 'Resultados de FÃºtbol';
# 				var CATEGORIES = '2401-2434-1902-1903-1904-1905-1909-2440-2435';
# 				var IMG_DIR = APP_DIR + 'media/img/';
#   </script>
#   <script src="https://cdn2.resfu.com/media/js_basics/jquery-2.0.3.min.js?ch=401260121111" type="text/javascript">
#   </script>
#   <script src="https://cdn2.resfu.com/media/min/b=media/js_basics&amp;f=common.js?ch=401260121111" type="text/javascript">
#   </script>
#   <script src="https://cdn2.resfu.com/media/min/b=media/js_basics&amp;f=team.js?ch=401260121111" type="text/javascript">
#   </script>
#   <script src="https://cdn2.resfu.com/media/js_basics/jquery.smartbanner.js" type="text/javascript">
#   </script>
#   <script async="async" src="//widgets.outbrain.com/outbrain.js" type="text/javascript">
#   </script>
#   <!-- Facebook Pixel Code -->
#   <script>
#    !function(f,b,e,v,n,t,s)
# 	  {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# 	  n.callMethod.apply(n,arguments):n.queue.push(arguments)};
# 	  if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
# 	  n.queue=[];t=b.createElement(e);t.async=!0;
# 	  t.src=v;s=b.getElementsByTagName(e)[0];
# 	  s.parentNode.insertBefore(t,s)}(window, document,'script',
# 	  'https://connect.facebook.net/en_US/fbevents.js');
# 	  fbq('init', '1918202381837292');
# 	  fbq('track', 'PageView');
#   </script>
#   <noscript>
#    <img alt="noscript image" height="1" src="https://www.facebook.com/tr?id=1918202381837292&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
#   </noscript>
#   <!-- End Facebook Pixel Code -->
#   <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js">
#   </script>
#   <script>
#    window.googletag = window.googletag || {cmd: []};
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/12539845/RF_DESKTOP_1X1', [1, 1], 'div-gpt-ad-1634535563348-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
#   </script>
#   <script>
#    console.log('READYY2Â¡Â¡');
#   </script>
#   <meta content="aHR0cHM6Ly93d3cucmVzdWx0YWRvcy1mdXRib2wuY29tLw==" name="unancor-verify-code"/>
#   <!--TEST-->
#   <!--Array
# (
#     [type] => team
#     [slots] => Array
#         (
#             [0] => Array
#                 (
#                     [alias] => caracas-venezuela
#                     [id] => 5602
#                     [name] => Caracas Venezuela
#                     [id_slot] => 6508781
#                 )
#
#             [1] => Array
#                 (
#                     [alias] => copa_libertadores
#                     [id] => 204
#                     [name] => Copa Libertadores
#                     [id_slot] => 6508781
#                 )
#
#             [2] => Array
#                 (
#                     [alias] => torneo_transicion_venezuela
#                     [id] => 1807
#                     [name] => Primera DivisiÃ³n Venezuela
#                     [id_slot] => 6508781
#                 )
#
#         )
#
# )
# -->
#   <!-- -->
#   <script type="text/javascript">
#    window.ssmCustomTargetings = { alias: "caracas-venezuela", name: "Caracas Venezuela", idau: 5602, team: 6508781 };
#   </script>
#   <script type="text/javascript">
#    window.ssmCustomTargetings = { alias: "copa_libertadores", name: "Copa Libertadores", idau: 204, team: 6508781 };
#   </script>
#   <script type="text/javascript">
#    window.ssmCustomTargetings = { alias: "torneo_transicion_venezuela", name: "Primera DivisiÃ³n Venezuela", idau: 1807, team: 6508781 };
#   </script>
#   <meta content="da2a335f8282b3af76de22fac48b35dd9c63ebab" name="wearecontent-verify-code"/>
#   <!-- /12539845/RF_DESKTOP_1X1 -->
#   <div id="div-gpt-ad-1634535563348-0">
#    <script>
#     googletag.cmd.push(function() { googletag.display('div-gpt-ad-1634535563348-0'); });
#    </script>
#   </div>
#   <style type="text/css">
#    .advertising-both-sides .web-width {background-color: #D2D8DC;}
# 	    .advertising-both-sides-box {width: 100%;height: 100%;position: fixed;margin-top: 89px;}
# 	    .advertising-sides-box {
# 	        display: inline-block;
# 	        width: calc(50% - 590px);
# 	        position: absolute;
# 	        height: auto;
# 	        overflow: hidden;
# 	        background: #fe7200;
# 	    }
# 	    .advertising-sides-box.left {left: 0;}
# 	    .advertising-sides-box.right {right: 0}
# 	    .advertising-sides-box.left img {float:right;}
# 	    .web-contenido #contenido {position:relative}
#
# 	    @media (max-width: 1100px) {
# 	        .advertising-both-sides-box {display: none;}
# 		    .advertising-both-sides .web-contenido {background: #fff;}
# 	    }
#   </style>
#   <div class="advertising-both-sides-box hidden" id="div_publis">
#    <div id="bg_style">
#     <style type="text/css">
#      .advertising-both-sides .web-contenido, .advertising-sides-box {background: ;}
#     </style>
#    </div>
#    <div class="advertising-sides-box left">
#     <a href="" id="link_left" target="_blank">
#      <img alt="Promo izq" class="pull-right" src=""/>
#     </a>
#    </div>
#    <div class="advertising-sides-box right">
#     <a href="" id="link_right" target="_blank">
#      <img alt="Promo der" src=""/>
#     </a>
#    </div>
#   </div>
#   <script type="text/javascript">
#    function show_publi (status) {
# 			if(status){
# 				$('#web').addClass('advertising-both-sides');
# 				$('#div_publis').removeClass('hidden');
# 			}else{
# 				$('#web').removeClass('advertising-both-sides');
# 				$('#div_publis').addClass('hidden');
# 			}
#
# 		}
# 		function show_publi_custom (link,img_left,img_right,bg) {
#
# 				$('#link_left').attr('href',link);
# 				$('#link_right').attr('href',link);
# 				$('#link_right img').attr('src',img_right);
# 				$('#link_left img').attr('src',img_left);
# 				var style = '<style type="text/css">.advertising-both-sides .web-contenido, .advertising-sides-box {background: '+bg+'}</style>';
# 				$("#bg_style").html(style);
#
# 				$('#web').addClass('advertising-both-sides');
# 				$('#div_publis').removeClass('hidden');
# 		}
# 		function resizeImgHeight(margin) {
#                 var winHeight = window.innerHeight;
#                 document.querySelector('.advertising-sides-box.left img').style.height = (winHeight - margin) + "px";
#                 document.querySelector('.advertising-sides-box.right img').style.height = (winHeight - margin) + "px";
#         }
#         function resizeTop(top) {
#         	document.getElementById('div_publis').style.top = top + "px";
#         }
#         resizeImgHeight(170);
#         window.onresize = function() {
#             resizeImgHeight(170);
#         };
#         window.onscroll = function() {
#             if (document.body.scrollTop > 170 || document.documentElement.scrollTop > 170) {
# 			    resizeTop(0);
# 			} else {
# 				resizeTop(170);
# 			}
#         };
#   </script>
#   <!--[if lte IE 6]>
# <div id="alertbrowser">
# <div>
# <span class="el">!</span>
# <span>EstÃ¡s utilizando una versiÃ³n muy antigua de Internet Explorer y es posible que no puedas utilizar algunas funciones de la web.  Para solucionarlo te recomendamos
# que <a href="http://www.microsoft.com/spain/windows/products/winfamily/ie/default.mspx">actualices a la Ãºltima versiÃ³n</a> o pruebes otro navegador como <a href="http://www.mozilla-europe.org/es/" title="Navegador web Firefox | Mozilla Europe">Firefox</a>, <a href="http://www.apple.com/es/safari/download/" title="Apple - Safari - Descarga">Safari</a>, <a href="http://www.opera.com/" title="Opera Browser | Faster &amp; safer Internet | Free Download">Opera</a> o <a href="http://www.google.com/chrome/index.html?hl=es" title="Google Chrome - DescÃ¡rgate un nuevo navegador">Chrome</a>.</span>
# </div>
# </div>
# <![endif]-->
#   <div id="webfnd_">
#    <div id="detected_lang" style="display:none">
#     <div class="detected_lang_inner">
#      <span id="detected_lang_text">
#      </span>
#      <a href="javascript:;" id="detected_lang_close">
#       [x]
#      </a>
#     </div>
#    </div>
#    <div class="web" id="web">
#     <div class="web-width">
#      <div class="user_box" id="user_box" style="display:none; margin-top: 17px;">
#      </div>
#     </div>
#     <div id="fb-root">
#     </div>
#     <script>
#      (function(d, s, id) {
# 	var js, fjs = d.getElementsByTagName(s)[0];
# 	if (d.getElementById(id)) return;
# 	js = d.createElement(s); js.id = id;
# 	js.src = "//connect.facebook.net/es_LA/sdk.js#xfbml=1&version=v2.9&appId=200183103347113";
# 	fjs.parentNode.insertBefore(js, fjs);
# 	}(document, 'script', 'facebook-jssdk'));
#
# 	function checkLoginState() {
# 		FB.api('/me', 'get', { fields: 'id,name,email,first_name,last_name,locale' }, function(response) {
# 		     //console.log(response);
# 		     //alert('Welcome, ' + response.name );
# 			 //alert('Your email id is : '+ response.email);
#
# 			var url = 'https://www.resultados-futbol.com/ajax/facebook_connect/fbnew.php';
#
# 			var parametros = {"id":response.id,"name" : response.name, "email":response.email, "first_name":response.first_name, "last_name":response.last_name, "locale":response.locale};
# 			$.ajax({
# 				type: "POST",
# 				url: url,
# 				data: parametros,
# 				success: function(data) {
# 					location.reload();
# 					FB.logout(function(response) {
# 					 // console.log('usuario deslogueado');
# 					});
# 				}
# 			});
#
#
# 		});
#
# 		// FB.api('/me', function (response) {
# 		// 	alert('Welcome, ' + response.name );
# 		// 	alert('Your email id is : '+ response.email);
# 		// })
# 	};
#     </script>
#     <div id="content_logged_user">
#     </div>
#     <div class="generic_dialog hidden" id="commonbox">
#      <div class="generic_dialog_popup" style="top: 100px;">
#       <table class="pop_dialog_table ufbtable" id="pop_dialog_table">
#        <tbody>
#         <tr>
#          <td class="pop_topleft">
#          </td>
#          <td class="pop_border pop_top">
#          </td>
#          <td class="pop_topright">
#          </td>
#         </tr>
#         <tr>
#          <td class="pop_border pop_side">
#          </td>
#          <td class="pop_content" id="pop_content">
#           <p class="dialog_title">
#            <span id="commonbox_title">
#            </span>
#            <a class="cerrar_corner" href="javascript:void(0);" onclick="jQuery('#commonbox').addClass('hidden');">
#             x
#            </a>
#           </p>
#           <div class="dialog_body" id="commonbox_message">
#           </div>
#           <div style="clear:both;">
#           </div>
#           <div class="dialog_summary">
#            <input class="bottonrl" onclick="jQuery('#commonbox').addClass('hidden');" type="button" value="Aceptar"/>
#           </div>
#          </td>
#          <td class="pop_border pop_side">
#          </td>
#         </tr>
#         <tr>
#          <td class="pop_bottomleft">
#          </td>
#          <td class="pop_border pop_bottom">
#          </td>
#          <td class="pop_bottomright">
#          </td>
#         </tr>
#        </tbody>
#       </table>
#      </div>
#     </div>
#     <div class="generic_dialog hidden" id="bugbox">
#      <div class="generic_dialog_popup" style="top: 100px;">
#       <table class="pop_dialog_table ufbtable" id="pop_dialog_table">
#        <tbody>
#         <tr>
#          <td class="pop_topleft">
#          </td>
#          <td class="pop_border pop_top">
#          </td>
#          <td class="pop_topright">
#          </td>
#         </tr>
#         <tr>
#          <td class="pop_border pop_side">
#          </td>
#          <td class="pop_content" id="pop_content">
#           <p class="dialog_title">
#            <span id="commonbox_title">
#             Â¿Has detectado algÃºn error en la web?
#            </span>
#            <a class="cerrar_corner" href="javascript:void(0);" onclick="jQuery('#bugbox').addClass('hidden');">
#             x
#            </a>
#           </p>
#           <div class="dialog_body" id="commonbox_message">
#            <form action="" class="clearfix formregistro formlogin" id="formBugReport" method="post">
#             <div id="loginDiv">
#              <div class="campoitem">
#               <label for="type_bug">
#                Tipo de incidencia
#               </label>
#               <div class="inputfield">
#                <select id="type_bug" name="type_bug">
#                 <option value="0">
#                  -Tipo de incidencia-
#                 </option>
#                 <option value="1">
#                  Sugerencia o idea
#                 </option>
#                 <option value="2">
#                  Algo se ve mal
#                 </option>
#                 <option value="3">
#                  Algo no funciona del todo
#                 </option>
#                 <option value="4">
#                  Hay un error en la informaciÃ³n mostrada
#                 </option>
#                 <option value="5">
#                  Falta una competiciÃ³n / liga
#                 </option>
#                 <option value="6">
#                  Un error importante
#                 </option>
#                </select>
#               </div>
#              </div>
#              <div class="campoitem">
#               <label for="text_bug">
#                Â¿QuÃ© ocurre?
#               </label>
#               <div class="inputfield">
#                <textarea class="txt" id="text_bug" name="text_bug" placeholder="CuÃ©ntanos brevemente quÃ© ocurre."></textarea>
#               </div>
#              </div>
#              <span class="clearer">
#              </span>
#              <div class="campoitem" id="contact_email_div">
#               <label for="text_bug">
#                Deja tu correo si quieres que te contactemos
#               </label>
#               <div class="inputfield">
#                <input class="txt" id="contact_email" name="contact_email" placeholder="Email de contacto" size="50" type="text"/>
#               </div>
#              </div>
#              <span class="clearer">
#              </span>
#             </div>
#            </form>
#           </div>
#           <div style="clear:both;">
#           </div>
#           <div class="dialog_summary">
#            <input class="bottonrl" onclick="add_bug();" type="button" value="Enviar"/>
#           </div>
#          </td>
#          <td class="pop_border pop_side">
#          </td>
#         </tr>
#         <tr>
#          <td class="pop_bottomleft">
#          </td>
#          <td class="pop_border pop_bottom">
#          </td>
#          <td class="pop_bottomright">
#          </td>
#         </tr>
#        </tbody>
#       </table>
#      </div>
#     </div>
#     <div id="staticTipLayer" style="position: absolute; z-index: 10000; visibility: hidden; left: 0px; top: 0px; width: 10px">
#     </div>
#     <div class="hidden" id="login_rff">
#      <div class="generic_dialog_popup" style="top: 100px;">
#       <table class="pop_dialog_table" id="pop_dialog_table" style="width: 632px;">
#        <tbody>
#         <tr>
#          <td class="pop_topleft">
#          </td>
#          <td class="pop_border pop_top">
#          </td>
#          <td class="pop_topright">
#          </td>
#         </tr>
#         <tr>
#          <td class="pop_border pop_side">
#          </td>
#          <td class="pop_content" id="pop_content">
#           <p class="dialog_title">
#            <span>
#             Creando cuenta de usuario
#            </span>
#            <a class="cerrar_corner" href="javascript:void(0);" onclick="document.getElementById('login_rff').className='hidden';">
#             x
#            </a>
#           </p>
#           <div class="dialog_content" id="form_facebook">
#            <div class="dialog_summary">
#             Introduce los datos para tu nueva cuenta en resultados-futbol.com
#            </div>
#            <div style="width:600px;margin-left:5px;">
#             <p class="hidden" id="inputtextfb1_1">
#              El nombre de usuario debe de tener entre 4 y 16 caracteres
#             </p>
#             <p class="hidden" id="inputtextfb2_1">
#              Ya existe un usuario con ese nombre
#             </p>
#             <p class="hidden" id="inputtextfb1_2">
#              El correo electrÃ³nico no es vÃ¡lido
#             </p>
#             <p class="hidden" id="inputtextfb2_2">
#              Ya existe un usuario con este correo electrÃ³nico
#             </p>
#             <p class="hidden" id="inputtextfb1_3">
#              * La contraseÃ±a debe tener como mÃ­nimo 6 caracteres
#             </p>
#             <p class="hidden" id="inputtextfb1_4">
#              * Las contraseÃ±as no coinciden
#             </p>
#             <p class="hidden" id="inputtexterrorregisterfb">
#             </p>
#            </div>
#            <div class="dialog_body fb1">
#             <table>
#              <tr>
#               <td>
#                <label for="user_usuarioL">
#                 <span>
#                  Usuario:
#                 </span>
#                 <input class="inputtext" id="inputfb1" name="userfb" onkeyup="validatefb(1,this.value);" type="text" value=""/>
#                </label>
#               </td>
#               <td>
#                <label for="user_emailL">
#                 <span>
#                  Email:
#                 </span>
#                 <input class="inputtext" id="inputfb2" name="emailfb" onkeyup="validatefb(2,this.value);" type="text" value=""/>
#                </label>
#               </td>
#              </tr>
#             </table>
#             <div style="width:500px;margin-left:38px;">
#              <label class="checkbox acepta_reglas" for="condiciones">
#               <input class="checkbox" id="condiciones" name="condiciones" type="checkbox"/>
#               Confirmo que he leÃ­do y acepto los
#               <a href="https://www.resultados-futbol.com/legal" target="_blank">
#                tÃ©rminos y condiciones
#               </a>
#              </label>
#             </div>
#            </div>
#            <div style="clear:both;">
#            </div>
#            <div class="dialog_summary">
#             <input class="bottonrl" id="iniciosesionfb" name="iniciosesionfb" onclick="next_step_fb();" type="button" value="Siguiente"/>
#            </div>
#           </div>
#          </td>
#          <td class="pop_border pop_side">
#          </td>
#         </tr>
#         <tr>
#          <td class="pop_bottomleft">
#          </td>
#          <td class="pop_border pop_bottom">
#          </td>
#          <td class="pop_bottomright">
#          </td>
#         </tr>
#        </tbody>
#       </table>
#      </div>
#     </div>
#     <style>
#      #form_message > p {
# 	font-size: 13px;
# 	padding: 20px 20px 20px 10px;
# }
# #form_message > p a {
#     background: none repeat scroll 0 0 #52a331;
#     border-radius: 3px;
#     font-size: 12px;
#     padding: 3px 8px;
#     color: #FFFFFF;
#     margin-top:10px;
#     display: inline-block;
# }
#     </style>
#     <div class="hidden" id="login_rf">
#      <div class="generic_dialog_popup login_redesign" style="top: 100px;">
#       <table class="pop_dialog_table ufbtable" id="pop_dialog_table">
#        <tbody>
#         <tr>
#          <td class="pop_content" id="pop_content">
#           <p class="dialog_title">
#            <span>
#             Iniciar SesiÃ³n
#            </span>
#            <a class="cerrar_corner" href="javascript:void(0);" onclick="document.getElementById('login_rf').className='hidden';">
#             x
#            </a>
#           </p>
#           <div class="dialog_content" id="form_reg">
#            <div class="dialog_summary">
#             <p class="mbottom10">
#              Si lo prefieres, puedes acceder con tu cuenta de facebook:
#             </p>
#             <center class="mbottom10">
#              <div id="fb-root">
#              </div>
#              <!-- <a class="fb_button fb_button_medium" href="https://www.resultados-futbol.com/ajax/facebook_connect/redirect_fb.php"><span class="fb_button_text">Entrar</span></a> -->
#             </center>
#             <p class="small mbottom10">
#              Si ya estÃ¡s registrado, puedes
#              <br/>
#              <a href="javascript:void(0);" onclick="switchbody(1);">
#               Acceder aquÃ­
#              </a>
#             </p>
#             <p class="small">
#              Si ya eres usuario, tambiÃ©n puedes
#              <br/>
#              <a href="javascript:void(0);" onclick="switchbody(3);">
#               Recordar tu contraseÃ±a
#              </a>
#             </p>
#             <!--Inicia sesiÃ³n Ã³ <a href="javascript:void(0);" onclick="switchbody(2);"><strong>registra un usuario</strong></a> si no tienes cuenta.   <a href="https://www.resultados-futbol.com/auth/login">Recordar contraseÃ±a</a>-->
#            </div>
#            <div class="dialog_body">
#             <div class="editor">
#              <p class="noerror" id="input1">
#               <label for="user_name">
#                <span>
#                 Usuario:
#                </span>
#                <input class="inputtext" id="user_name" name="user_name" onkeyup="validate(1,this.value);" type="text" value=""/>
#               </label>
#              </p>
#              <p class="noerror" id="input2">
#               <label for="email">
#                <span>
#                 Correo electrÃ³nico:
#                </span>
#                <input class="inputtext" id="email" name="email" onkeyup="validate(2,this.value);" type="text" value=""/>
#               </label>
#              </p>
#              <p class="noerror" id="input3">
#               <label for="password">
#                <span>
#                 ContraseÃ±a:
#                </span>
#                <input class="inputtext" id="password" name="password" onkeyup="validate(3,this.value);" type="password" value=""/>
#               </label>
#              </p>
#              <p class="noerror" id="input4">
#               <label for="password_confirm">
#                <span>
#                 Repetir contraseÃ±a:
#                </span>
#                <input class="inputtext" id="password_confirm" name="password_confirm" onkeyup="validate(4,this.value);" type="password" value=""/>
#               </label>
#              </p>
#              <p class="hidden" id="inputtext1_1">
#               El nombre de usuario debe de tener entre 4 y 16 caracteres
#              </p>
#              <p class="hidden" id="inputtext2_1">
#               Ya existe un usuario con ese nombre
#              </p>
#              <p class="hidden" id="inputtext1_2">
#               El correo electrÃ³nico no es vÃ¡lido
#              </p>
#              <p class="hidden" id="inputtext2_2">
#               Ya existe un usuario con este correo electrÃ³nico
#              </p>
#              <p class="hidden" id="inputtext1_3">
#               * La contraseÃ±a debe tener como mÃ­nimo 6 caracteres
#              </p>
#              <p class="hidden" id="inputtext1_4">
#               * Las contraseÃ±as no coinciden
#              </p>
#              <p class="hidden" id="inputtexterrorregister">
#              </p>
#             </div>
#            </div>
#            <div style="display:block;clear:both;float:none;">
#            </div>
#            <div style="background-color:#D2D8DC;padding:10px">
#             <div style="margin:5px">
#              <label class="checkbox acepta_reglas" for="condiciones_legales">
#               <input class="checkbox" id="condiciones_legales" name="condiciones_legales" type="checkbox"/>
#               Confirmo que he leÃ­do y acepto los
#               <a href="https://www.resultados-futbol.com/legal" target="_blank">
#                tÃ©rminos y condiciones.
#               </a>
#              </label>
#             </div>
#             <div style="margin:5px">
#              <label class="checkbox acepta_reglas" for="condiciones_mayor14">
#               <input class="checkbox" id="condiciones_mayor14" name="condiciones_mayor14" type="checkbox"/>
#               Reconozco ser mayor de 14 aÃ±os
#              </label>
#             </div>
#             <div class="dialog_actions">
#              <input class="fleft mright10 br3 sbutton sbutton_small sbutton1" id="createuser" name="createuser" onclick="create_user();" type="button" value="Crear usuario"/>
#              <input class="fleft br3 sbutton sbutton_small sbutton3" onclick="document.getElementById('login_rf').className='hidden';" type="button" value="Cancelar"/>
#             </div>
#            </div>
#           </div>
#           <div class="hidden" id="form_login">
#            <div class="dialog_summary">
#             <p class="mbottom10">
#              Si lo prefieres, puedes acceder con tu cuenta de facebook:
#             </p>
#             <center class="mbottom10">
#              <div id="fb-root">
#              </div>
#              <!-- <a class="fb_button fb_button_medium" href="https://www.resultados-futbol.com/ajax/facebook_connect/redirect_fb.php"><span class="fb_button_text">Entrar</span></a> -->
#              <div class="fb-login-button" data-auto-logout-link="false" data-button-type="login_with" data-max-rows="1" data-scope="basic_info, email" data-show-faces="false" data-size="medium" data-use-continue-as="true" onlogin="checkLoginState();">
#               Entrar
#              </div>
#             </center>
#             <p class="small mbottom10">
#              Â¿TodavÃ­a no tienes cuenta de usuario?
#              <br/>
#              <a href="javascript:void(0);" onclick="switchbody(2);">
#               RegÃ­strate aquÃ­
#              </a>
#             </p>
#             <p class="small">
#              Si ya eres usuario, tambiÃ©n puedes
#              <br/>
#              <a href="javascript:void(0);" onclick="switchbody(3);">
#               Recordar tu contraseÃ±a
#              </a>
#             </p>
#            </div>
#            <div class="dialog_body">
#             <div class="editor">
#              <p class="noerror" id="input1">
#               <label for="user_nameL" style="float:none">
#                <span>
#                 Usuario:
#                </span>
#                <input class="inputtext" id="user_nameL" name="user_nameL" type="text" value=""/>
#               </label>
#              </p>
#              <p class="noerror" id="input3">
#               <label for="passwordL" style="float:none">
#                <span>
#                 ContraseÃ±a:
#                </span>
#                <input class="inputtext" id="passwordL" name="passwordL" type="password" value=""/>
#               </label>
#              </p>
#              <p class="hidden" id="inputtexterrorlogin">
#              </p>
#             </div>
#             <div class="dialog_actions">
#              <input class="fleft mright10 br3 sbutton sbutton_small sbutton1" id="iniciosesion" name="iniciosesion" onclick="login_user();" type="button" value="Iniciar SesiÃ³n"/>
#              <input class="fleft br3 sbutton sbutton_small sbutton3" onclick="document.getElementById('login_rf').className='hidden';" type="button" value="Cancelar"/>
#             </div>
#            </div>
#           </div>
#           <div class="hidden" id="form_remember">
#            <div class="dialog_summary">
#             <p class="mbottom10">
#              Si lo prefieres, puedes acceder con tu cuenta de facebook:
#             </p>
#             <center class="mbottom10">
#              <div id="fb-root">
#              </div>
#              <a class="fb_button fb_button_medium" href="https://www.resultados-futbol.com/ajax/facebook_connect/redirect_fb.php">
#               <span class="fb_button_text">
#                Entrar
#               </span>
#              </a>
#             </center>
#             <p class="small mbottom10">
#              Â¿TodavÃ­a no tienes cuenta de usuario?
#              <br/>
#              <a href="javascript:void(0);" onclick="switchbody(2);">
#               RegÃ­strate aquÃ­
#              </a>
#             </p>
#             <p class="small">
#              Si ya eres usuario, tambiÃ©n puedes
#              <br/>
#              <a href="javascript:void(0);" onclick="switchbody(3);">
#               Recordar tu contraseÃ±a
#              </a>
#             </p>
#            </div>
#            <div class="dialog_body">
#             <form action="/auth/login" id="form_remember" method="post" name="form_remember">
#              <div class="editor">
#               <p class="noerror" id="input1">
#                <label for="forgotten_email">
#                 <span>
#                  Correo electrÃ³nico:
#                 </span>
#                 <input class="inputtext" id="forgotten_email" name="email" type="text" value=""/>
#                </label>
#               </p>
#               <p class="hidden" id="inputtexterrorlogin">
#               </p>
#              </div>
#              <div class="dialog_actions">
#               <input class="fleft mright10 br3 sbutton sbutton_small sbutton1" id="forgotten" name="forgotten" type="submit" value="Recordar"/>
#               <input class="fleft br3 sbutton sbutton_small sbutton3" onclick="document.getElementById('login_rf').className='hidden';" type="button" value="Cancelar"/>
#              </div>
#             </form>
#            </div>
#           </div>
#           <div class="hidden" id="form_message">
#            <p id="form_message_text">
#            </p>
#           </div>
#          </td>
#         </tr>
#        </tbody>
#       </table>
#      </div>
#     </div>
#     <div class="web web-cabecera">
#      <div id="cabecera">
#       <div id="bar-top">
#        <b class="izq">
#        </b>
#        <div class="bar-top-text">
#         <ul class="user_link">
#          <li>
#           <a href="/">
#            Inicio
#           </a>
#          </li>
#          <li>
#           <a href="/perfil">
#            Perfil
#           </a>
#          </li>
#          <li class="despi icodes" id="despsitios">
#           <a class="lia liasites" href="javascript:void(0);" onclick="despsitios();">
#            Sitios
#           </a>
#           <ul class="hidden" id="ulsitios">
#            <li>
#             <img alt="quinielas" class="icoquinielas" src="/media/img/1px.gif"/>
#             <a href="/quiniela">
#              Quinielas
#             </a>
#            </li>
#            <li>
#             <img alt="twitter" class="icotwitter" src="/media/img/1px.gif"/>
#             <a href="/twitter">
#              Twitter
#             </a>
#            </li>
#            <li>
#             <img alt="grupos" class="icogrupos" src="/media/img/1px.gif"/>
#             <a href="/misgrupos">
#              Grupos
#             </a>
#            </li>
#            <li>
#             <img alt="blogs" class="icoblogs" src="/media/img/1px.gif"/>
#             <a href="/reader">
#              Blogs
#             </a>
#            </li>
#            <li>
#             <img alt="fantasy" class="icofantasy" src="/media/img/1px.gif"/>
#             <a href="/noticias-fantasy">
#              Canal Fantasy
#             </a>
#            </li>
#            <li>
#             <img alt="api" class="icoapi" src="/media/img/1px.gif"/>
#             <a href="https://es.besoccer.com/api" target="_blank">
#              API
#             </a>
#            </li>
#           </ul>
#          </li>
#          <!-- 			<li class="despi icodes" id="despgame"><a class="lia" onclick="despgames();" href="javascript:void(0);">Juegos</a>
# 				<ul id="ulgames" class="hidden">
# 					<li><img class="icoporra" alt="porra" src="/media/img/1px.gif"><a href="/porra">La Porra</a></li>
# 					<li><img class="icodesa" alt="desa" src="/media/img/1px.gif"><a href="/desafio_manager">Desafio Manager</a></li>
# 					<li><img class="icoonce" alt="once" src="/media/img/1px.gif"><a href="/once_ideal">Once Ideal</a></li>
# 					<li><img class="icocrea" alt="crea" src="/media/img/1px.gif"><a href="/crea-tu-camiseta">Crea tu camiseta</a></li>
# 					<li><img class="icoduelo" alt="duelo" src="/media/img/1px.gif"><a href="/duelo-jugadores">Duelo de jugadores</a></li>
# 					<li><img class="icoduelo" alt="duelo" src="/media/img/1px.gif"><a href="/duelo-equipos">Duelo de equipos</a></li>
# 					<li><img class="icobroker" alt="broker" src="/media/img/1px.gif"><a href="/bebroker">Be Broker jugadores</a></li>
# 					<li><img class="icobroker" alt="broker" src="/media/img/1px.gif"><a href="/bebroker_equipos">Be Broker equipos</a></li>
# 					<li><img class="icofantasy" alt="fantasy" src="/media/img/1px.gif"><a href="http://fantasy.resultados-futbol.com">Fantasy Manager</a></li>
# 					<li><img class="icofutsal" alt="futsal" src="/media/img/1px.gif"><a href="http://futsal.resultados-futbol.com">Futsal Manager</a></li>
# 					<li><img class="icobaloncesto" alt="baloncesto" src="/media/img/1px.gif"><a href="http://baloncesto.resultados-futbol.com">Baloncesto Manager</a></li>
# 					<li><img class="icofantasy" alt="fantasy" src="/media/img/1px.gif"><a href="http://f1.popuz.com">Fantasy F1</a></li>
# 					<li><img class="icofantasy" alt="fantasy" src="/media/img/1px.gif"><a href="http://moto.popuz.com">Fantasy Moto GP</a></li>
# 					<li class="last"><img class="icoreto" alt="reto" src="/media/img/1px.gif"><a href="http://reto.resultados-futbol.com">Reto Manager</a></li>
# 				</ul>
# 			</li> -->
#          <li class="micof mico messages">
#           <a class="mico_link" href="/mensajes" title="Mensajes">
#            Mensajes
#           </a>
#           <span class="hidden" id="msgdiva">
#            <strong>
#             <span id="msgnum">
#              0
#             </span>
#            </strong>
#           </span>
#          </li>
#          <li class="mico notifies">
#           <a class="mico_link" href="/notificaciones" title="Notificaciones">
#            Notificaciones
#           </a>
#           <span class="hidden" id="msgwdiva">
#            <strong>
#             <span id="msgwnum">
#              0
#             </span>
#            </strong>
#           </span>
#          </li>
#          <li class="mico friends">
#           <a class="mico_link" href="/amigos" title="Amigos">
#            Amigos
#           </a>
#           <span class="hidden" id="frienddiva">
#            <strong>
#             <span id="friendsnum">
#              0
#             </span>
#            </strong>
#           </span>
#          </li>
#          <li class="mico notif activity" id="li_status">
#           <a class="mico_link lia" href="javascript:void(0);" id="link_status" onclick="switchStatus();" title="Actividad">
#            Actividad
#           </a>
#           <span class="hidden" id="statusnum_div">
#            <strong>
#             <span id="statusnum">
#             </span>
#            </strong>
#           </span>
#           <div class="despnotif hidden" id="status_container">
#            <b>
#            </b>
#            <div id="status_inner_container">
#             <p class="noactividad">
#              No hay actividad de la comunidad para mostrarte.
#             </p>
#            </div>
#            <input id="status_noviewed_ids" type="hidden" value=""/>
#           </div>
#          </li>
#         </ul>
#         <ul class="hidden" id="registerloading">
#          <li>
#           <a href="javascript:void(0);">
#            cargando
#           </a>
#          </li>
#         </ul>
#         <ul class="sesion_link" id="registerText">
#          <li class="addcontent">
#           <a class="hidden" href="javascript:;" id="swithAddContentBug" onclick="jQuery('#bugbox').toggleClass('hidden');">
#            Reportar error
#           </a>
#          </li>
#          <li>
#           <!-- <a class="fb_button fb_button_small" href="https://www.resultados-futbol.com/ajax/facebook_connect/redirect_fb.php">
# 						<span class="fb_button_text">Entrar</span
# 					></a> -->
#           <div class="fb-login-button" data-auto-logout-link="false" data-button-type="login_with" data-max-rows="1" data-scope="basic_info, email" data-show-faces="false" data-size="medium" data-use-continue-as="true" onlogin="checkLoginState();">
#           </div>
#          </li>
#          <li>
#           <a href="javascript:void(0);" id="login_a" onclick="mklogin();">
#            Login
#           </a>
#          </li>
#          <li>
#           <a class="registro" href="javascript:void(0);" id="registro_a" onclick="mkregister();">
#            RegÃ­strate
#           </a>
#          </li>
#         </ul>
#        </div>
#        <b class="der">
#        </b>
#       </div>
#       <script type="text/javascript">
#        load_login_events0();
# 		load_login_events();
#       </script>
#       <div id="infotop">
#        2.855.770 resultados, 9.127.069 comentarios, 804.045 imÃ¡genes, 79.786 vÃ­deos, 85.880 noticias
#       </div>
#       <div id="logo">
#        <h3>
#         <a href="/">
#          Resultados de FÃºtbol
#         </a>
#        </h3>
#       </div>
#       <div class="buscadortop">
#        <input autocomplete="off" id="searchinput" name="k" onclick="if(startsearch1==0){this.value='';startsearch1=1;this.className='txtinto';}" onkeyup="getKeywords(this.value,1,event,0);" size="60" style="width:297px;" type="text" value="Buscar contenidos..."/>
#        <input id="searchbutton" name="search" onclick="doSearch(document.getElementById('searchinput').value,0);" type="button" value="Buscar"/>
#        <div class="hidden" id="sugerencias1">
#        </div>
#       </div>
#       <div class="cleaner">
#       </div>
#       <div id="menu">
#        <ul class="top">
#         <li class="" id="menua0">
#          <a href="https://www.resultados-futbol.com/" id="a0">
#           <b id="c0">
#            <span id="b0">
#             Inicio
#            </span>
# ...
#               </a>
#              </td>
#              <td class="pts">
#               10
#              </td>
#             </tr>
#             <tr class="impar">
#              <th class="pos3 pos-playsud">
#               3
#              </th>
#              <td class="shield">
#               <a href="https://www.resultados-futbol.com/The-Strongest" title="The Strongest">
#                <img alt="The Strongest" height="20" src="https://t.resfu.com/img_data/escudos/small/11372.jpg?size=40x&amp;5" width="20"/>
#               </a>
#              </td>
#              <td class="equipo">
#               <a href="https://www.resultados-futbol.com/The-Strongest" title="The Strongest">
#                The Strongest
#               </a>
#              </td>
#              <td class="pts">
#               6
#              </td>
#             </tr>
#             <tr class="par act">
#              <th class="pos">
#               4
#              </th>
#              <td class="shield">
#               <a href="https://www.resultados-futbol.com/Caracas-Venezuela" title="Caracas">
#                <img alt="Caracas" height="20" src="https://t.resfu.com/img_data/escudos/small/5602.jpg?size=40x&amp;5" width="20"/>
#               </a>
#              </td>
#              <td class="equipo">
#               <a href="https://www.resultados-futbol.com/Caracas-Venezuela" title="Caracas">
#                Caracas
#               </a>
#              </td>
#              <td class="pts">
#               6
#              </td>
#             </tr>
#            </tbody>
#           </table>
#          </div>
#          <div class="contentitem">
#           <table cellspacing="0" id="tabla2legend" summary="">
#            <tr>
#             <th class="pos2 pos-nextcha">
#             </th>
#             <td style="text-align:left;">
#              <strong>
#               Siguiente Ronda
#              </strong>
#              :
# 														Libertad, Athletico Paranaense
#             </td>
#            </tr>
#            <tr>
#             <th class="pos3 pos-playsud">
#             </th>
#             <td style="text-align:left;">
#              <strong>
#               Liguilla Sudamericana
#              </strong>
#              :
# 														The Strongest
#             </td>
#            </tr>
#           </table>
#          </div>
#         </div>
#         <div class="boxhome" id="teams_box">
#          <div class="boxtop">
#           <div class="linea">
#            <span class="titlebox">
#             RIVALES EN Copa Libertadore.
#            </span>
#            <div class="botonlivs">
#             <span class="titlen">
#              4
#             </span>
#            </div>
#           </div>
#          </div>
#          <div class="contentitem">
#           <ul class="teams_list">
#            <li>
#             <a href="/Atletico-Paranaense">
#              <img height="37" src="https://t.resfu.com/img_data/escudos/small/374.jpg?size=37x&amp;5" width="37"/>
#              <small>
#               Athletico Paranaense
#              </small>
#             </a>
#            </li>
#            <li>
#             <a href="/Caracas-Venezuela">
#              <img height="37" src="https://t.resfu.com/img_data/escudos/small/5602.jpg?size=37x&amp;5" width="37"/>
#              <small>
#               Caracas
#              </small>
#             </a>
#            </li>
#            <li>
#             <a href="/Libertad-Asuncion">
#              <img height="37" src="https://t.resfu.com/img_data/escudos/small/1553.jpg?size=37x&amp;5" width="37"/>
#              <small>
#               Libertad
#              </small>
#             </a>
#            </li>
#            <li>
#             <a href="/The-Strongest">
#              <img height="37" src="https://t.resfu.com/img_data/escudos/small/11372.jpg?size=37x&amp;5" width="37"/>
#              <small>
#               The Strongest
#              </small>
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="boxhome" id="teams_box">
#          <div class="boxtop">
#           <div class="linea">
#            <span class="titlebox">
#             RIVALES EN Primera DivisiÃ³n.
#            </span>
#            <div class="botonlivs">
#             <span class="titlen">
#              16
#             </span>
#            </div>
#           </div>
#          </div>
#          <div class="contentitem">
#           <ul class="teams_list">
#            <li>
#             <a href="/Caracas-Venezuela">
#              <img height="37" src="https://t.resfu.com/img_data/escudos/small/5602.jpg?size=37x&amp;5" width="37"/>
#              <small>
#               Caracas
#              </small>
#             </a>
#            </li>
#            <li>
#             <a href="/Deportivo-Tachira-Fc">
#              <img height="37" src="https://t.resfu.com/img_data/escudos/small/3606.jpg?size=37x&amp;5" width="37"/>
#              <small>
#               Dep. TÃ¡chira
#              </small>
#             </a>
#            </li>
#            <li>
#             <a href="/Mineros-Guayana">
#              <img height="37" src="https://t.resfu.com/img_data/escudos/small/3900.jpg?size=37x&amp;5" width="37"/>
#              <small>
#               Mineros de Guayana
#              </small>
#             </a>
#            </li>
#            <li>
#             <a href="/Estudiantes-Merida-Fc">
#              <img height="37" src="https://t.resfu.com/img_data/escudos/small/3604.jpg?size=37x&amp;5" width="37"/>
#              <small>
#               Estudiantes de MÃ©rida
#              </small>
#             </a>
#            </li>
#            <li>
#             <a href="/Zamora-Cf">
#              <img height="37" src="https://t.resfu.com/img_data/escudos/small/2787.jpg?size=37x&amp;5" width="37"/>
#              <small>
#               Zamora FC
#              </small>
#             </a>
#            </li>
#            <li>
#             <a href="/Monagas-Sc">
#              <img height="37" src="https://t.resfu.com/img_data/escudos/small/3609.jpg?size=37x&amp;5" width="37"/>
#              <small>
#               Monagas
#              </small>
#             </a>
#            </li>
#            <li>
#             <a href="/Carabobo">
#              <img height="37" src="https://t.resfu.com/img_data/escudos/small/11657.jpg?size=37x&amp;5" width="37"/>
#              <small>
#               Carabobo
#              </small>
#             </a>
#            </li>
#            <li>
#             <a href="/Deportivo-Lara">
#              <img height="37" src="https://t.resfu.com/img_data/escudos/small/4379.jpg?size=37x&amp;5" width="37"/>
#              <small>
#               Deportivo Lara
#              </small>
#             </a>
#            </li>
#            <li>
#             <a href="/Aragua-Fc">
#              <img height="37" src="https://t.resfu.com/img_data/escudos/small/3597.jpg?size=37x&amp;5" width="37"/>
#              <small>
#               Aragua FC
#              </small>
#             </a>
#            </li>
#            <li>
#             <a href="/Portuguesa-Fc">
#              <img height="37" src="https://t.resfu.com/img_data/escudos/small/3620.jpg?size=37x&amp;5" width="37"/>
#              <small>
#               Portuguesa de Araure
#              </small>
#             </a>
#            </li>
#            <li>
#             <a href="/Deportivo-La-Guaira">
#              <img height="37" src="https://t.resfu.com/img_data/escudos/small/15169.jpg?size=37x&amp;5" width="37"/>
#              <small>
#               La Guaira
#              </small>
#             </a>
#            </li>
#            <li>
#             <a href="/Zulia-Fc">
#              <img height="37" src="https://t.resfu.com/img_data/escudos/small/3601.jpg?size=37x&amp;5" width="37"/>
#              <small>
#               Zulia FC
#              </small>
#             </a>
#            </li>
#            <li>
#             <a href="/Ucv">
#              <img height="37" src="https://t.resfu.com/img_data/escudos/small/11653.jpg?size=37x&amp;5" width="37"/>
#              <small>
#               UCV
#              </small>
#             </a>
#            </li>
#            <li>
#             <a href="/Metropolitanos">
#              <img height="37" src="https://t.resfu.com/img_data/escudos/small/11646.jpg?size=37x&amp;5" width="37"/>
#              <small>
#               Metropolitanos
#              </small>
#             </a>
#            </li>
#            <li>
#             <a href="/Academia-Puerto-Cabello">
#              <img height="37" src="https://t.resfu.com/img_data/escudos/small/65310.jpg?size=37x&amp;5" width="37"/>
#              <small>
#               Academia Puerto Cabello
#              </small>
#             </a>
#            </li>
#            <li>
#             <a href="/Cd-Hermanos-Colmenarez">
#              <img height="37" src="https://t.resfu.com/img_data/escudos/small/110173.jpg?size=37x&amp;5" width="37"/>
#              <small>
#               CD Hermanos Colmenarez
#              </small>
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#        </div>
#        <div class="cleaner">
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="web web-contenido web-footer-ads">
#    <div class="web-width">
#    </div>
#   </div>
#   <div class="clearfix">
#   </div>
#   <div id="pie-top">
#    <span id="privacyPolicy">
#     <b>
#      Uso de cookies:
#     </b>
#     <span class="policy">
#      Utilizamos "cookies" propias y de terceros para mejorar nuestros servicios, elaborar informaciÃ³n estadÃ­stica, analizar sus hÃ¡bitos de navegaciÃ³n e inferir grupos de interÃ©s. Esto nos permite personalizar el contenido que ofrecemos y mostrarle publicidad relacionada con sus preferencias. Adicionalmente, compartimos los anÃ¡lisis de navegaciÃ³n y los grupos de interÃ©s inferidos con terceros. Si continÃºa navegando acepta su uso.
#      <a class="privacyA" href="https://www.resultados-futbol.com/legal" rel="nofollow" target="_blank">
#       MÃ¡s informaciÃ³n y cambio de configuraciÃ³n.
#      </a>
#     </span>
#     <a class="privacy-btn pb-close privacy-close" href="javascript:;">
#      Aceptar
#     </a>
#    </span>
#    <script type="text/javascript">
#     function getCookie(c_name){if(document.cookie.length>0){c_start=document.cookie.indexOf(c_name + "=");if (c_start!=-1){c_start=c_start + c_name.length+1;c_end=document.cookie.indexOf(";",c_start);if (c_end==-1) c_end=document.cookie.length;return unescape(document.cookie.substring(c_start,c_end));}}return "";}
# function closeCookieMessage() {
# 	document.getElementById('privacyPolicy').style.display = 'none';
# 	setCookie('cookies_closed', 'true', 365);
# }
# if(typeof(setCookie)=='undefined'){
# 	function setCookie(cookieName, cookieValue, nDays) {
# 		var today = new Date();
# 		var expire = new Date();
# 		if (nDays==null || nDays==0)
# 			nDays=1;
# 		expire.setTime(today.getTime() + 3600000*24*nDays);
# 		document.cookie = cookieName+"="+escape(cookieValue) + ";expires="+expire.toGMTString();
# 	}
# }
#
# document.addEventListener("DOMContentLoaded", function(event) {
# 	cookies_closed = getCookie('cookies_closed');
# 	if( !(cookies_closed=="true") ) {
# 		document.getElementById('privacyPolicy').style.display = 'inline';
#
# 		document.getElementById('privacy-close').addEventListener("click", function(){
# 			closeCookieMessage();
# 		});
# 	}
# });
#    </script>
#    <div class="pie-top-container">
#     <div class="padding">
#      <ul class="menu">
#       <li class="first">
#        <a href="https://www.resultados-futbol.com/">
#         Inicio
#        </a>
#       </li>
#       <li>
#        <a href="https://www.resultados-futbol.com/quiniela">
#         Quiniela
#        </a>
#       </li>
#       <li>
#       </li>
#       <li>
#        <a href="https://www.resultados-futbol.com/livescore">
#         Partidos de hoy
#        </a>
#       </li>
#       <!-- <li><a href="https://www.resultados-futbol.com/videos">VÃ­deos</a></li> -->
#       <li>
#        <a href="https://www.resultados-futbol.com/noticias">
#         Noticias
#        </a>
#       </li>
#       <li>
#        <a href="https://www.resultados-futbol.com/grupos">
#         Grupos
#        </a>
#       </li>
#       <li>
#        <a href="https://www.resultados-futbol.com/ligas">
#         Ligas
#        </a>
#       </li>
#       <li>
#        <a href="https://www.resultados-futbol.com/partidos-televisados">
#         Partidos televisados
#        </a>
#       </li>
#       <li>
#        <a href="https://company.besoccer.com/es/trabajos">
#         Trabaja con nosotros
#        </a>
#       </li>
#      </ul>
#     </div>
#    </div>
#    <div class="padding">
#     <div class="bot-pie">
#      <ul class="lef">
#       <li class="logo">
#        <a href="https://www.resultados-futbol.com/">
#         Resultados de fÃºtbol
#        </a>
#       </li>
#       <li class="slogan">
#        La web del fÃºtbol
#       </li>
#       <!-- 				<li class="linklang">- <a href="https://www.popuz.com">Red social de juegos online</a></li> -->
#       <li class="linklang">
#        -
#        <a href="https://es.besoccer.com">
#         Livescore
#        </a>
#        |
#        <a href="https://www.besoccer.com">
#         BeSoccer.com
#        </a>
#       </li>
#      </ul>
#      <ul class="rig">
#       <li>
#        Juega con responsabilidad. 18+
#        <span>
#         |
#        </span>
#       </li>
#       <li>
#        <a href="https://www.resultados-futbol.com/legal">
#         Aviso legal
#        </a>
#       </li>
#      </ul>
#      <ul class="rig ssmm">
#       <li>
#        Siguenos en
#        <a class="ssmmico youtube" href="https://www.youtube.com/channel/UCCbuWKB8KkFrrD7WKiXc9Rg" rel="nofollow" target="_blank">
#         Youtube
#        </a>
#        <a class="ssmmico instagram" href="https://www.instagram.com/besoccer/" rel="nofollow" target="_blank">
#         Instagram
#        </a>
#        <a class="ssmmico twitter" href="https://twitter.com/rfutbol" rel="nofollow" target="_blank">
#         Twitter
#        </a>
#        <a class="ssmmico facebook" href="https://www.facebook.com/rfutbol" rel="nofollow" target="_blank">
#         Facebook
#        </a>
#       </li>
#      </ul>
#      <ul class="lef version">
#       <li>
#        <a class="version" href="https://movil.resultados-futbol.com/" onclick="mobilepage();">
#         VersiÃ³n mÃ³vil
#        </a>
#       </li>
#       <li>
#        <a class="version version-android" href="https://play.google.com/store/apps/details?id=com.resultadosfutbol.mobile&amp;hl=es" target="_blank">
#         App Android
#        </a>
#       </li>
#       <li>
#        <a class="version version-ios" href="https://itunes.apple.com/es/app/id550928207" target="_blank">
#         App iOs
#        </a>
#       </li>
#       <li>
#        <a class="version version-huawei" href="https://appgallery.cloud.huawei.com/ag/n/app/C100094381?channelId=BeSoccer&amp;id=f1211652806445259cf5bd332b012fb6&amp;s=44DB2CA19F77FC080F4A7F833E79FC46D1868D23D297152A3B081152FAD57BFA&amp;detailType=0&amp;v=" target="_blank">
#         App Huawei
#        </a>
#       </li>
#      </ul>
#     </div>
#    </div>
#   </div>
#   <div class="cleaner">
#   </div>
#   <script type="text/javascript">
#    function realpage()
# {
# 	var date = new Date();
#     var days = 7;
#     date.setTime(date.getTime()+(days*24*60*60*1000));
#     var expires = "; expires="+ date.toGMTString();
#
#     document.cookie = "iphone_redirect=true" + expires + ";domain=.resultados-futbol.com;path=/";
#     window.location = "https://www.resultados-futbol.com/";
#
# }
#
# function mobilepage()
# {
#      document.cookie = 'iphone_redirect=;expires=Thu, 01 Jan 1970 00:00:01 GMT;domain=.resultados-futbol.com;path=/';
#     window.location = "https://movil.resultados-futbol.com/";
#
# }
#
# function select_all()
# {
# var text_val=eval("document.opinaform.opinion_text");
# text_val.focus();
# text_val.select();
# }
#
# function select_allM()
# {
# var text_val=eval("document.opinaform.email");
# text_val.focus();
# text_val.select();
# }
# function checkEmail(email) {
#    return (email.indexOf(".") > 2) && (email.indexOf("@") > 0);
# }
#
# function verify() {
# var themessage = "";
# if (document.opinaform.opinion_text.value=="") {
# themessage = '';
# }
# if (document.opinaform.email.value=="") {
# themessage = '';
# }
#
# if(!checkEmail(document.opinaform.email.value))
# 	themessage = '';
#
# if (themessage == "") {
# document.opinaform.submit();
# }
# else {
# alert(themessage);
# return false;
#    }
# }
#   </script>
#   <link href="https://www.resultados-futbol.com/media/css_less/extra.css?ch=6857306471" media="screen" rel="stylesheet" type="text/css"/>
#  </body>
# </html>

# %%
lista_cruda_plantilla = ccs_soup.find_all('tr', attrs= {'itemprop':'employee'})
lista_cruda_plantilla
# Out:
# [<tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
#  <td class="num">1</td>
#  <td class="sdata_player_img">
#  <a content="https://www.resultados-futbol.com/jugador/A-Baroja-114644" href="https://www.resultados-futbol.com/jugador/A-Baroja-114644" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/114644.jpg?size=60x&amp;5" width="37"/></a>
#  </td>
#  <th class="sdata_player_name">
#  <a content="https://www.resultados-futbol.com/jugador/A-Baroja-114644" href="https://www.resultados-futbol.com/jugador/A-Baroja-114644" itemprop="url"><span itemprop="name">A. Baroja</span></a>
#  </th>
#  <td class="birthdate" content="1989-10-23T00:00:00+01:00" itemprop="birthDate"><b>32</b></td>
#  <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
#  <td class="dat">183</td>
#  <td class="dat">79</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  </tr>,
#  <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
#  <td class="num">35</td>
#  <td class="sdata_player_img">
#  <a content="https://www.resultados-futbol.com/jugador/Frankarlos-Benitez-904991" href="https://www.resultados-futbol.com/jugador/Frankarlos-Benitez-904991" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/904991.jpg?size=60x&amp;5" width="37"/></a>
#  </td>
#  <th class="sdata_player_name">
#  <a content="https://www.resultados-futbol.com/jugador/Frankarlos-Benitez-904991" href="https://www.resultados-futbol.com/jugador/Frankarlos-Benitez-904991" itemprop="url"><span itemprop="name">Frankarlos BenÃ­tez</span></a>
#  </th>
#  <td class="birthdate" content="2004-05-03T00:00:00+02:00" itemprop="birthDate"><b>18</b></td>
#  <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
#  <td class="dat">184</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  </tr>,
#  <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
#  <td class="num">23</td>
#  <td class="sdata_player_img">
#  <a content="https://www.resultados-futbol.com/jugador/W-Hernandez-802360" href="https://www.resultados-futbol.com/jugador/W-Hernandez-802360" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/802360.jpg?size=60x&amp;5" width="37"/></a>
#  </td>
#  <th class="sdata_player_name">
#  <a content="https://www.resultados-futbol.com/jugador/W-Hernandez-802360" href="https://www.resultados-futbol.com/jugador/W-Hernandez-802360" itemprop="url"><span itemprop="name">W. HernÃ¡ndez</span></a>
#  </th>
#  <td class="birthdate" content="2001-03-02T00:00:00+01:00" itemprop="birthDate"><b>21</b></td>
#  <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
#  <td class="dat">185</td>
#  <td class="dat">82</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  </tr>,
#  <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
#  <td class="num">13</td>
#  <td class="sdata_player_img">
#  <a content="https://www.resultados-futbol.com/jugador/Carlos-Rivero-125106" href="https://www.resultados-futbol.com/jugador/Carlos-Rivero-125106" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/125106.jpg?size=60x&amp;5" width="37"/></a>
#  </td>
#  <th class="sdata_player_name">
#  <a content="https://www.resultados-futbol.com/jugador/Carlos-Rivero-125106" href="https://www.resultados-futbol.com/jugador/Carlos-Rivero-125106" itemprop="url"><span itemprop="name">C. Rivero</span></a>
#  </th>
#  <td class="birthdate" content="1992-11-27T00:00:00+01:00" itemprop="birthDate"><b>29</b></td>
#  <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
#  <td class="dat">182</td>
#  <td class="dat">80</td>
#  <td class="dat">1</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  </tr>,
#  <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
#  <td class="num">4</td>
#  <td class="sdata_player_img">
#  <a content="https://www.resultados-futbol.com/jugador/D-Osio-198157" href="https://www.resultados-futbol.com/jugador/D-Osio-198157" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/198157.jpg?size=60x&amp;5" width="37"/></a>
#  </td>
#  <th class="sdata_player_name">
#  <a content="https://www.resultados-futbol.com/jugador/D-Osio-198157" href="https://www.resultados-futbol.com/jugador/D-Osio-198157" itemprop="url"><span itemprop="name">D. Osio</span></a>
#  </th>
#  <td class="birthdate" content="1997-01-03T00:00:00+01:00" itemprop="birthDate"><b>25</b></td>
#  <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
#  <td class="dat">192</td>
#  <td class="dat">79</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  </tr>,
#  <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
#  <td class="num">5</td>
#  <td class="sdata_player_img">
#  <a content="https://www.resultados-futbol.com/jugador/D-Rivillo-349731" href="https://www.resultados-futbol.com/jugador/D-Rivillo-349731" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/349731.jpg?size=60x&amp;5" width="37"/></a>
#  </td>
#  <th class="sdata_player_name">
#  <a content="https://www.resultados-futbol.com/jugador/D-Rivillo-349731" href="https://www.resultados-futbol.com/jugador/D-Rivillo-349731" itemprop="url"><span itemprop="name">D. Rivillo</span></a>
#  </th>
#  <td class="birthdate" content="1996-12-21T00:00:00+01:00" itemprop="birthDate"><b>25</b></td>
#  <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
#  <td class="dat">179</td>
#  <td class="dat">72</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  </tr>,
#  <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
#  <td class="num">2</td>
#  <td class="sdata_player_img">
#  <a content="https://www.resultados-futbol.com/jugador/Eduardo-Enriqueferreira-Penaranda-365336" href="https://www.resultados-futbol.com/jugador/Eduardo-Enriqueferreira-Penaranda-365336" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/365336.jpg?size=60x&amp;5" width="37"/></a>
#  </td>
#  <th class="sdata_player_name">
#  <a content="https://www.resultados-futbol.com/jugador/Eduardo-Enriqueferreira-Penaranda-365336" href="https://www.resultados-futbol.com/jugador/Eduardo-Enriqueferreira-Penaranda-365336" itemprop="url"><span itemprop="name">E. Fereira</span></a>
#  </th>
#  <td class="birthdate" content="2000-09-29T00:00:00+02:00" itemprop="birthDate"><b>21</b></td>
#  <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
#  <td class="dat">169</td>
#  <td class="dat">63</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  <td class="dat">3</td>
#  </tr>,
#  <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
#  <td class="num">27</td>
#  <td class="sdata_player_img">
#  <a content="https://www.resultados-futbol.com/jugador/J-Da-Silva-995626" href="https://www.resultados-futbol.com/jugador/J-Da-Silva-995626" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/995626.jpg?size=60x&amp;5" width="37"/></a>
#  </td>
#  <th class="sdata_player_name">
#  <a content="https://www.resultados-futbol.com/jugador/J-Da-Silva-995626" href="https://www.resultados-futbol.com/jugador/J-Da-Silva-995626" itemprop="url"><span itemprop="name">J. Velasquez</span></a>
#  </th>
#  <td class="birthdate" content="2001-06-06T00:00:00+02:00" itemprop="birthDate"><b>21</b></td>
#  <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
#  <td class="dat">185</td>
#  <td class="dat">77</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  </tr>,
#  <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
#  <td class="num">26</td>
#  <td class="sdata_player_img">
#  <a content="https://www.resultados-futbol.com/jugador/M-Rivas-901417" href="https://www.resultados-futbol.com/jugador/M-Rivas-901417" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/901417.jpg?size=60x&amp;5" width="37"/></a>
#  </td>
#  <th class="sdata_player_name">
#  <a content="https://www.resultados-futbol.com/jugador/M-Rivas-901417" href="https://www.resultados-futbol.com/jugador/M-Rivas-901417" itemprop="url"><span itemprop="name">M. Rivas</span></a>
#  </th>
#  <td class="birthdate" content="1999-05-01T00:00:00+02:00" itemprop="birthDate"><b>23</b></td>
#  <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
#  <td class="dat">188</td>
#  <td class="dat">85</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  </tr>,
#  <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
#  <td class="num">6</td>
#  <td class="sdata_player_img">
#  <a content="https://www.resultados-futbol.com/jugador/Rubert-Quijada-138647" href="https://www.resultados-futbol.com/jugador/Rubert-Quijada-138647" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/138647.jpg?size=60x&amp;5" width="37"/></a>
#  </td>
#  <th class="sdata_player_name">
#  <a content="https://www.resultados-futbol.com/jugador/Rubert-Quijada-138647" href="https://www.resultados-futbol.com/jugador/Rubert-Quijada-138647" itemprop="url"><span itemprop="name">R. Quijada</span></a>
#  </th>
#  <td class="birthdate" content="1989-02-10T00:00:00+01:00" itemprop="birthDate"><b>33</b></td>
#  <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
#  <td class="dat">186</td>
#  <td class="dat">73</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  <td class="dat">1</td>
#  </tr>,
#  <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
#  <td class="num">3</td>
#  <td class="sdata_player_img">
#  <a content="https://www.resultados-futbol.com/jugador/R-Villanueva-245226" href="https://www.resultados-futbol.com/jugador/R-Villanueva-245226" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/245226.jpg?size=60x&amp;5" width="37"/></a>
#  </td>
#  <th class="sdata_player_name">
#  <a content="https://www.resultados-futbol.com/jugador/R-Villanueva-245226" href="https://www.resultados-futbol.com/jugador/R-Villanueva-245226" itemprop="url"><span itemprop="name">R. Villanueva</span></a>
#  </th>
#  <td class="birthdate" content="1992-08-16T00:00:00+02:00" itemprop="birthDate"><b>29</b></td>
#  <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
#  <td class="dat">175</td>
#  <td class="dat">70</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  </tr>,
#  <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
#  <td class="num">14</td>
#  <td class="sdata_player_img">
#  <a content="https://www.resultados-futbol.com/jugador/Sandronotaroberto-282544" href="https://www.resultados-futbol.com/jugador/Sandronotaroberto-282544" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/282544.jpg?size=60x&amp;5" width="37"/></a>
#  </td>
#  <th class="sdata_player_name">
#  <a content="https://www.resultados-futbol.com/jugador/Sandronotaroberto-282544" href="https://www.resultados-futbol.com/jugador/Sandronotaroberto-282544" itemprop="url"><span itemprop="name">S. Notaroberto</span></a>
#  </th>
#  <td class="birthdate" content="1998-03-10T00:00:00+01:00" itemprop="birthDate"><b>24</b></td>
#  <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
#  <td class="dat">175</td>
#  <td class="dat">73</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  <td class="dat">2</td>
#  </tr>,
#  <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
#  <td class="num">17</td>
#  <td class="sdata_player_img">
#  <a content="https://www.resultados-futbol.com/jugador/C-Suarez-243855" href="https://www.resultados-futbol.com/jugador/C-Suarez-243855" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/243855.jpg?size=60x&amp;5" width="37"/></a>
#  </td>
#  <th class="sdata_player_name">
#  <a content="https://www.resultados-futbol.com/jugador/C-Suarez-243855" href="https://www.resultados-futbol.com/jugador/C-Suarez-243855" itemprop="url"><span itemprop="name">C. SuÃ¡rez</span></a>
#  </th>
#  <td class="birthdate" content="1992-04-26T00:00:00+02:00" itemprop="birthDate"><b>30</b></td>
#  <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
#  <td class="dat">170</td>
#  <td class="dat">68</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  <td class="dat">2</td>
#  </tr>,
#  <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
#  <td class="num">8</td>
#  <td class="sdata_player_img">
#  <a content="https://www.resultados-futbol.com/jugador/E-Castillo-103813" href="https://www.resultados-futbol.com/jugador/E-Castillo-103813" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/103813.jpg?size=60x&amp;5" width="37"/></a>
#  </td>
#  <th class="sdata_player_name">
#  <a content="https://www.resultados-futbol.com/jugador/E-Castillo-103813" href="https://www.resultados-futbol.com/jugador/E-Castillo-103813" itemprop="url"><span itemprop="name">E. Castillo</span></a>
#  </th>
#  <td class="birthdate" content="1994-05-18T00:00:00+02:00" itemprop="birthDate"><b>28</b></td>
#  <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
#  <td class="dat">175</td>
#  <td class="dat">76</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  <td class="dat">2</td>
#  </tr>,
#  <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
#  <td class="num">30</td>
#  <td class="sdata_player_img">
#  <a content="https://www.resultados-futbol.com/jugador/J-Torres-3168491" href="https://www.resultados-futbol.com/jugador/J-Torres-3168491" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/media/img/avatar-player.jpg?size=60x" width="37"/></a>
#  </td>
#  <th class="sdata_player_name">
#  <a content="https://www.resultados-futbol.com/jugador/J-Torres-3168491" href="https://www.resultados-futbol.com/jugador/J-Torres-3168491" itemprop="url"><span itemprop="name">J. Torres</span></a>
#  </th>
#  <td class="birthdate" content="2003-03-02T00:00:00+01:00" itemprop="birthDate"><b>19</b></td>
#  <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  </tr>,
#  <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
#  <td class="num">24</td>
#  <td class="sdata_player_img">
#  <a content="https://www.resultados-futbol.com/jugador/L-Gonzalez-751703" href="https://www.resultados-futbol.com/jugador/L-Gonzalez-751703" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/751703.jpg?size=60x&amp;5" width="37"/></a>
#  </td>
#  <th class="sdata_player_name">
#  <a content="https://www.resultados-futbol.com/jugador/L-Gonzalez-751703" href="https://www.resultados-futbol.com/jugador/L-Gonzalez-751703" itemprop="url"><span itemprop="name">L. GonzÃ¡lez</span></a>
#  </th>
#  <td class="birthdate" content="1998-11-27T00:00:00+01:00" itemprop="birthDate"><b>23</b></td>
#  <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
#  <td class="dat">174</td>
#  <td class="dat">65</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  </tr>,
#  <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
#  <td class="num">11</td>
#  <td class="sdata_player_img">
#  <a content="https://www.resultados-futbol.com/jugador/Luis-Ramirez-280721" href="https://www.resultados-futbol.com/jugador/Luis-Ramirez-280721" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/280721.jpg?size=60x&amp;5" width="37"/></a>
#  </td>
#  <th class="sdata_player_name">
#  <a content="https://www.resultados-futbol.com/jugador/Luis-Ramirez-280721" href="https://www.resultados-futbol.com/jugador/Luis-Ramirez-280721" itemprop="url"><span itemprop="name">L. RamÃ­rez</span></a>
#  </th>
#  <td class="birthdate" content="1997-07-02T00:00:00+02:00" itemprop="birthDate"><b>25</b></td>
#  <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
#  <td class="dat">177</td>
#  <td class="dat">66</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  </tr>,
#  <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
#  <td class="num">21</td>
#  <td class="sdata_player_img">
#  <a content="https://www.resultados-futbol.com/jugador/V-Rodriguez-314353" href="https://www.resultados-futbol.com/jugador/V-Rodriguez-314353" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/314353.jpg?size=60x&amp;5" width="37"/></a>
#  </td>
#  <th class="sdata_player_name">
#  <a content="https://www.resultados-futbol.com/jugador/V-Rodriguez-314353" href="https://www.resultados-futbol.com/jugador/V-Rodriguez-314353" itemprop="url"><span itemprop="name">V. RodrÃ­guez</span></a>
#  </th>
#  <td class="birthdate" content="1990-04-05T00:00:00+02:00" itemprop="birthDate"><b>32</b></td>
#  <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
#  <td class="dat">177</td>
#  <td class="dat">71</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  <td class="dat">1</td>
#  </tr>,
#  <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
#  <td class="num">10</td>
#  <td class="sdata_player_img">
#  <a content="https://www.resultados-futbol.com/jugador/A-Zambrano-280171" href="https://www.resultados-futbol.com/jugador/A-Zambrano-280171" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/280171.jpg?size=60x&amp;5" width="37"/></a>
#  </td>
#  <th class="sdata_player_name">
#  <a content="https://www.resultados-futbol.com/jugador/A-Zambrano-280171" href="https://www.resultados-futbol.com/jugador/A-Zambrano-280171" itemprop="url"><span itemprop="name">A. Zambrano</span></a>
#  </th>
#  <td class="birthdate" content="1995-10-01T00:00:00+01:00" itemprop="birthDate"><b>26</b></td>
#  <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
#  <td class="dat">179</td>
#  <td class="dat">73</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  </tr>,
#  <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
#  <td class="num">15</td>
#  <td class="sdata_player_img">
#  <a content="https://www.resultados-futbol.com/jugador/Ade-Oguns-3139548" href="https://www.resultados-futbol.com/jugador/Ade-Oguns-3139548" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/3139548.jpg?size=60x&amp;5" width="37"/></a>
#  </td>
#  <th class="sdata_player_name">
#  <a content="https://www.resultados-futbol.com/jugador/Ade-Oguns-3139548" href="https://www.resultados-futbol.com/jugador/Ade-Oguns-3139548" itemprop="url"><span itemprop="name">Ade Oguns</span></a>
#  </th>
#  <td class="birthdate" content="2001-04-14T00:00:00+02:00" itemprop="birthDate"><b>21</b></td>
#  <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="NG" itemprop="name"></span><img alt="ng" class="flag f_ng" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ng"/></td>
#  <td class="dat">176</td>
#  <td class="dat">76</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  </tr>,
#  <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
#  <td class="num">33</td>
#  <td class="sdata_player_img">
#  <a content="https://www.resultados-futbol.com/jugador/B-Albizo-3240392" href="https://www.resultados-futbol.com/jugador/B-Albizo-3240392" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/media/img/avatar-player.jpg?size=60x" width="37"/></a>
#  </td>
#  <th class="sdata_player_name">
#  <a content="https://www.resultados-futbol.com/jugador/B-Albizo-3240392" href="https://www.resultados-futbol.com/jugador/B-Albizo-3240392" itemprop="url"><span itemprop="name">B. Albizo</span></a>
#  </th>
#  <td class="birthdate" content="2003-05-05T00:00:00+02:00" itemprop="birthDate"><b>19</b></td>
#  <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
#  <td class="dat">170</td>
#  <td class="dat">58</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  </tr>,
#  <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
#  <td class="num">32</td>
#  <td class="sdata_player_img">
#  <a content="https://www.resultados-futbol.com/jugador/B-Ortega-3178203" href="https://www.resultados-futbol.com/jugador/B-Ortega-3178203" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/3178203.jpg?size=60x&amp;5" width="37"/></a>
#  </td>
#  <th class="sdata_player_name">
#  <a content="https://www.resultados-futbol.com/jugador/B-Ortega-3178203" href="https://www.resultados-futbol.com/jugador/B-Ortega-3178203" itemprop="url"><span itemprop="name">B. Ortega</span></a>
#  </th>
#  <td class="birthdate" content="2003-02-28T00:00:00+01:00" itemprop="birthDate"><b>19</b></td>
#  <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  <td class="dat">1</td>
#  </tr>,
#  <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
#  <td class="num">18</td>
#  <td class="sdata_player_img">
#  <a content="https://www.resultados-futbol.com/jugador/Denilson-Josueovando-Ramirez-364886" href="https://www.resultados-futbol.com/jugador/Denilson-Josueovando-Ramirez-364886" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/364886.jpg?size=60x&amp;5" width="37"/></a>
#  </td>
#  <th class="sdata_player_name">
#  <a content="https://www.resultados-futbol.com/jugador/Denilson-Josueovando-Ramirez-364886" href="https://www.resultados-futbol.com/jugador/Denilson-Josueovando-Ramirez-364886" itemprop="url"><span itemprop="name">D. Ovando</span></a>
#  </th>
#  <td class="birthdate" content="2001-09-23T00:00:00+02:00" itemprop="birthDate"><b>20</b></td>
#  <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="EC" itemprop="name"></span><img alt="ec" class="flag f_ec" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ec"/></td>
#  <td class="dat">181</td>
#  <td class="dat">68</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  </tr>,
#  <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
#  <td class="num">28</td>
#  <td class="sdata_player_img">
#  <a content="https://www.resultados-futbol.com/jugador/E-Moreno-848301" href="https://www.resultados-futbol.com/jugador/E-Moreno-848301" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/848301.jpg?size=60x&amp;5" width="37"/></a>
#  </td>
#  <th class="sdata_player_name">
#  <a content="https://www.resultados-futbol.com/jugador/E-Moreno-848301" href="https://www.resultados-futbol.com/jugador/E-Moreno-848301" itemprop="url"><span itemprop="name">E. Moreno</span></a>
#  </th>
#  <td class="birthdate" content="2000-06-30T00:00:00+02:00" itemprop="birthDate"><b>22</b></td>
#  <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
#  <td class="dat">78</td>
#  <td class="dat">72</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  </tr>,
#  <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
#  <td class="num">37</td>
#  <td class="sdata_player_img">
#  <a content="https://www.resultados-futbol.com/jugador/F-Guerra-3241845" href="https://www.resultados-futbol.com/jugador/F-Guerra-3241845" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/media/img/avatar-player.jpg?size=60x" width="37"/></a>
#  </td>
#  <th class="sdata_player_name">
#  <a content="https://www.resultados-futbol.com/jugador/F-Guerra-3241845" href="https://www.resultados-futbol.com/jugador/F-Guerra-3241845" itemprop="url"><span itemprop="name">F. Guerra</span></a>
#  </th>
#  <td class="birthdate" content="2004-04-23T00:00:00+02:00" itemprop="birthDate"><b>18</b></td>
#  <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
#  <td class="dat">176</td>
#  <td class="dat">77</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  </tr>,
#  <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
#  <td class="num">19</td>
#  <td class="sdata_player_img">
#  <a content="https://www.resultados-futbol.com/jugador/K-Bonsu-836051" href="https://www.resultados-futbol.com/jugador/K-Bonsu-836051" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/836051.jpg?size=60x&amp;5" width="37"/></a>
#  </td>
#  <th class="sdata_player_name">
#  <a content="https://www.resultados-futbol.com/jugador/K-Bonsu-836051" href="https://www.resultados-futbol.com/jugador/K-Bonsu-836051" itemprop="url"><span itemprop="name">K. Bonsu</span></a>
#  </th>
#  <td class="birthdate" content="2000-08-17T00:00:00+02:00" itemprop="birthDate"><b>21</b></td>
#  <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="GH" itemprop="name"></span><img alt="gh" class="flag f_gh" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="gh"/></td>
#  <td class="dat">168</td>
#  <td class="dat">66</td>
#  <td class="dat">1</td>
#  <td class="dat">-</td>
#  <td class="dat">1</td>
#  </tr>,
#  <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
#  <td class="num">7</td>
#  <td class="sdata_player_img">
#  <a content="https://www.resultados-futbol.com/jugador/M-Celis-321783" href="https://www.resultados-futbol.com/jugador/M-Celis-321783" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/321783.jpg?size=60x&amp;5" width="37"/></a>
#  </td>
#  <th class="sdata_player_name">
#  <a content="https://www.resultados-futbol.com/jugador/M-Celis-321783" href="https://www.resultados-futbol.com/jugador/M-Celis-321783" itemprop="url"><span itemprop="name">M. Celis</span></a>
#  </th>
#  <td class="birthdate" content="1995-09-09T00:00:00+02:00" itemprop="birthDate"><b>26</b></td>
#  <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
#  <td class="dat">190</td>
#  <td class="dat">79</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  </tr>,
#  <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
#  <td class="num">31</td>
#  <td class="sdata_player_img">
#  <a content="https://www.resultados-futbol.com/jugador/M-Molina-623699" href="https://www.resultados-futbol.com/jugador/M-Molina-623699" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/623699.jpg?size=60x&amp;5" width="37"/></a>
#  </td>
#  <th class="sdata_player_name">
#  <a content="https://www.resultados-futbol.com/jugador/M-Molina-623699" href="https://www.resultados-futbol.com/jugador/M-Molina-623699" itemprop="url"><span itemprop="name">M. Molina</span></a>
#  </th>
#  <td class="birthdate" content="1999-06-10T00:00:00+02:00" itemprop="birthDate"><b>23</b></td>
#  <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
#  <td class="dat">174</td>
#  <td class="dat">68</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  </tr>,
#  <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
#  <td class="num">22</td>
#  <td class="sdata_player_img">
#  <a content="https://www.resultados-futbol.com/jugador/M-Sulbaran-3142178" href="https://www.resultados-futbol.com/jugador/M-Sulbaran-3142178" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/3142178.jpg?size=60x&amp;5" width="37"/></a>
#  </td>
#  <th class="sdata_player_name">
#  <a content="https://www.resultados-futbol.com/jugador/M-Sulbaran-3142178" href="https://www.resultados-futbol.com/jugador/M-Sulbaran-3142178" itemprop="url"><span itemprop="name">M. SulbarÃ¡n</span></a>
#  </th>
#  <td class="birthdate" content="2002-10-08T00:00:00+02:00" itemprop="birthDate"><b>19</b></td>
#  <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
#  <td class="dat">165</td>
#  <td class="dat">59</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  </tr>,
#  <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
#  <td class="num">9</td>
#  <td class="sdata_player_img">
#  <a content="https://www.resultados-futbol.com/jugador/A-Samson-877794" href="https://www.resultados-futbol.com/jugador/A-Samson-877794" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/877794.jpg?size=60x&amp;5" width="37"/></a>
#  </td>
#  <th class="sdata_player_name">
#  <a content="https://www.resultados-futbol.com/jugador/A-Samson-877794" href="https://www.resultados-futbol.com/jugador/A-Samson-877794" itemprop="url"><span itemprop="name">S. Akinyoola</span></a>
#  </th>
#  <td class="birthdate" content="2000-03-03T00:00:00+01:00" itemprop="birthDate"><b>22</b></td>
#  <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="BJ" itemprop="name"></span><img alt="bj" class="flag f_bj" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="bj"/></td>
#  <td class="dat">170</td>
#  <td class="dat">75</td>
#  <td class="dat">2</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  </tr>,
#  <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
#  <td class="num">16</td>
#  <td class="sdata_player_img">
#  <a content="https://www.resultados-futbol.com/jugador/S-Guarirapa-895242" href="https://www.resultados-futbol.com/jugador/S-Guarirapa-895242" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/895242.jpg?size=60x&amp;5" width="37"/></a>
#  </td>
#  <th class="sdata_player_name">
#  <a content="https://www.resultados-futbol.com/jugador/S-Guarirapa-895242" href="https://www.resultados-futbol.com/jugador/S-Guarirapa-895242" itemprop="url"><span itemprop="name">S. Guarirapa</span></a>
#  </th>
#  <td class="birthdate" content="2002-10-18T00:00:00+02:00" itemprop="birthDate"><b>19</b></td>
#  <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
#  <td class="dat">188</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  <td class="dat">-</td>
#  <td class="dat">1</td>
#  </tr>]

# %%
type(lista_cruda_plantilla)
# Out:
# bs4.element.ResultSet

# %%
len(lista_cruda_plantilla)
# Out:
# 31

# %%
lista_cruda_plantilla[0]
# Out:
# <tr itemprop="employee" itemscope="" itemtype="http://schema.org/Person">
# <td class="num">1</td>
# <td class="sdata_player_img">
# <a content="https://www.resultados-futbol.com/jugador/A-Baroja-114644" href="https://www.resultados-futbol.com/jugador/A-Baroja-114644" itemprop="url"><img alt="" class="" height="37" src="https://t.resfu.com/img_data/players/medium/114644.jpg?size=60x&amp;5" width="37"/></a>
# </td>
# <th class="sdata_player_name">
# <a content="https://www.resultados-futbol.com/jugador/A-Baroja-114644" href="https://www.resultados-futbol.com/jugador/A-Baroja-114644" itemprop="url"><span itemprop="name">A. Baroja</span></a>
# </th>
# <td class="birthdate" content="1989-10-23T00:00:00+01:00" itemprop="birthDate"><b>32</b></td>
# <td class="ori" itemprop="nationality" itemscope="" itemtype="http://schema.org/Country"><span content="VE" itemprop="name"></span><img alt="ve" class="flag f_ve" itemprop="image" src="https://t.resfu.com/media/img/1px.gif" title="ve"/></td>
# <td class="dat">183</td>
# <td class="dat">79</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# <td class="dat">-</td>
# </tr>

# %%
#NOMBRE
nombre = lista_cruda_plantilla[19].find('span').text

nombre
# Out:
# 'Ade Oguns'

# %%
#numero en el equipo

numero_jugador = lista_cruda_plantilla[0].find('td', attrs= {"class":"num"}).text
numero_jugador
# Out:
# '1'

# %%
# edad

edad_jugador = lista_cruda_plantilla[0].find('td', attrs={'itemprop':"birthDate"}).text
edad_jugador
# Out:
# '32'

# %%
#procedencia(pais)

tag_nacionalidad = lista_cruda_plantilla[19].find('td', attrs= {'itemprop':'nationality'})
str_nacionalidad = str(tag_nacionalidad)

nacionalidad = str_nacionalidad[104:106]
nacionalidad
# Out:
# 'NG'

# %%
altura_peso = lista_cruda_plantilla[0].find_all('td', attrs= {'class':'dat'}, limit=2)
altura_peso
# Out:
# [<td class="dat">183</td>, <td class="dat">79</td>]

# %%
altura= altura_peso[0].text
altura
# Out:
# '183'

# %%
peso= altura_peso[1].text
peso
# Out:
# '79'

# %%
datos_jugador = [nombre, edad_jugador, nacionalidad, altura, peso]
datos_jugador
# Out:
# ['Ade Oguns', '32', 'NG', '183', '79']

# %%
    
plantilla = []

contador = 0
while contador  < 31:
    nombre = lista_cruda_plantilla[contador].find('span').text
    plantilla.append(nombre)
        
    contador = contador + 1

# %%
plantilla
# Out:
# ['A. Baroja',
#  'Frankarlos BenÃ\xadtez',
#  'W. HernÃ¡ndez',
#  'C. Rivero',
#  'D. Osio',
#  'D. Rivillo',
#  'E. Fereira',
#  'J. Velasquez',
#  'M. Rivas',
#  'R. Quijada',
#  'R. Villanueva',
#  'S. Notaroberto',
#  'C. SuÃ¡rez',
#  'E. Castillo',
#  'J. Torres',
#  'L. GonzÃ¡lez',
#  'L. RamÃ\xadrez',
#  'V. RodrÃ\xadguez',
#  'A. Zambrano',
#  'Ade Oguns',
#  'B. Albizo',
#  'B. Ortega',
#  'D. Ovando',
#  'E. Moreno',
#  'F. Guerra',
#  'K. Bonsu',
#  'M. Celis',
#  'M. Molina',
#  'M. SulbarÃ¡n',
#  'S. Akinyoola',
#  'S. Guarirapa']

# %%
plantilla = []

contador = 0
for item in lista_cruda_plantilla:
    
    nombre = lista_cruda_plantilla[contador].find('span').text
    numero_jugador = lista_cruda_plantilla[contador].find('td', attrs= {"class":"num"}).text
    edad_jugador = lista_cruda_plantilla[contador].find('td', attrs={'itemprop':"birthDate"}).text
    #nacionalidad
    tag_nacionalidad = lista_cruda_plantilla[contador].find('td', attrs= {'itemprop':'nationality'})
    str_nacionalidad = str(tag_nacionalidad)
    nacionalidad = str_nacionalidad[104:106]
    #Altura y peso
    altura_peso = lista_cruda_plantilla[contador].find_all('td', attrs= {'class':'dat'}, limit=2)
    altura= altura_peso[0].text
    peso= altura_peso[1].text
    
    
    plantilla.append(nombre)
    plantilla.append(numero_jugador)
    plantilla.append(edad_jugador)
    plantilla.append(nacionalidad)
    plantilla.append(altura)
    plantilla.append(peso)
    
    contador = contador +1

# %%
plantilla
# Out:
# ['A. Baroja',
#  '1',
#  '32',
#  'VE',
#  '183',
#  '79',
#  'Frankarlos BenÃ\xadtez',
#  '35',
#  '18',
#  'VE',
#  '184',
#  '-',
#  'W. HernÃ¡ndez',
#  '23',
#  '21',
#  'VE',
#  '185',
#  '82',
#  'C. Rivero',
#  '13',
#  '29',
#  'VE',
#  '182',
#  '80',
#  'D. Osio',
#  '4',
#  '25',
#  'VE',
#  '192',
#  '79',
#  'D. Rivillo',
#  '5',
#  '25',
#  'VE',
#  '179',
#  '72',
#  'E. Fereira',
#  '2',
#  '21',
#  'VE',
#  '169',
#  '63',
#  'J. Velasquez',
#  '27',
#  '21',
#  'VE',
#  '185',
#  '77',
#  'M. Rivas',
#  '26',
#  '23',
#  'VE',
#  '188',
#  '85',
#  'R. Quijada',
#  '6',
#  '33',
#  'VE',
#  '186',
#  '73',
#  'R. Villanueva',
#  '3',
#  '29',
#  'VE',
#  '175',
#  '70',
#  'S. Notaroberto',
#  '14',
#  '24',
#  'VE',
#  '175',
#  '73',
#  'C. SuÃ¡rez',
#  '17',
#  '30',
#  'VE',
#  '170',
#  '68',
#  'E. Castillo',
#  '8',
#  '28',
#  'VE',
#  '175',
#  '76',
#  'J. Torres',
#  '30',
#  '19',
#  'VE',
#  '-',
#  '-',
#  'L. GonzÃ¡lez',
#  '24',
#  '23',
#  'VE',
#  '174',
#  '65',
#  'L. RamÃ\xadrez',
#  '11',
#  '25',
#  'VE',
#  '177',
#  '66',
#  'V. RodrÃ\xadguez',
#  '21',
#  '32',
#  'VE',
#  '177',
#  '71',
#  'A. Zambrano',
#  '10',
#  '26',
#  'VE',
#  '179',
#  '73',
#  'Ade Oguns',
#  '15',
#  '21',
#  'NG',
#  '176',
#  '76',
#  'B. Albizo',
#  '33',
#  '19',
#  'VE',
#  '170',
#  '58',
#  'B. Ortega',
#  '32',
#  '19',
#  'VE',
#  '-',
#  '-',
#  'D. Ovando',
#  '18',
#  '20',
#  'EC',
#  '181',
#  '68',
#  'E. Moreno',
#  '28',
#  '22',
#  'VE',
#  '78',
#  '72',
#  'F. Guerra',
#  '37',
#  '18',
#  'VE',
#  '176',
#  '77',
#  'K. Bonsu',
#  '19',
#  '21',
#  'GH',
#  '168',
#  '66',
#  'M. Celis',
#  '7',
#  '26',
#  'VE',
#  '190',
#  '79',
#  'M. Molina',
#  '31',
#  '23',
#  'VE',
#  '174',
#  '68',
#  'M. SulbarÃ¡n',
#  '22',
#  '19',
#  'VE',
#  '165',
#  '59',
#  'S. Akinyoola',
#  '9',
#  '22',
#  'BJ',
#  '170',
#  '75',
#  'S. Guarirapa',
#  '16',
#  '19',
#  'VE',
#  '188',
#  '-']

# %%
n=6

plantilla_final =[plantilla[i:i + n] for i in range(0, len(plantilla), 
                                                    n)]
plantilla_final
# Out:
# [['A. Baroja', '1', '32', 'VE', '183', '79'],
#  ['Frankarlos BenÃ\xadtez', '35', '18', 'VE', '184', '-'],
#  ['W. HernÃ¡ndez', '23', '21', 'VE', '185', '82'],
#  ['C. Rivero', '13', '29', 'VE', '182', '80'],
#  ['D. Osio', '4', '25', 'VE', '192', '79'],
#  ['D. Rivillo', '5', '25', 'VE', '179', '72'],
#  ['E. Fereira', '2', '21', 'VE', '169', '63'],
#  ['J. Velasquez', '27', '21', 'VE', '185', '77'],
#  ['M. Rivas', '26', '23', 'VE', '188', '85'],
#  ['R. Quijada', '6', '33', 'VE', '186', '73'],
#  ['R. Villanueva', '3', '29', 'VE', '175', '70'],
#  ['S. Notaroberto', '14', '24', 'VE', '175', '73'],
#  ['C. SuÃ¡rez', '17', '30', 'VE', '170', '68'],
#  ['E. Castillo', '8', '28', 'VE', '175', '76'],
#  ['J. Torres', '30', '19', 'VE', '-', '-'],
#  ['L. GonzÃ¡lez', '24', '23', 'VE', '174', '65'],
#  ['L. RamÃ\xadrez', '11', '25', 'VE', '177', '66'],
#  ['V. RodrÃ\xadguez', '21', '32', 'VE', '177', '71'],
#  ['A. Zambrano', '10', '26', 'VE', '179', '73'],
#  ['Ade Oguns', '15', '21', 'NG', '176', '76'],
#  ['B. Albizo', '33', '19', 'VE', '170', '58'],
#  ['B. Ortega', '32', '19', 'VE', '-', '-'],
#  ['D. Ovando', '18', '20', 'EC', '181', '68'],
#  ['E. Moreno', '28', '22', 'VE', '78', '72'],
#  ['F. Guerra', '37', '18', 'VE', '176', '77'],
#  ['K. Bonsu', '19', '21', 'GH', '168', '66'],
#  ['M. Celis', '7', '26', 'VE', '190', '79'],
#  ['M. Molina', '31', '23', 'VE', '174', '68'],
#  ['M. SulbarÃ¡n', '22', '19', 'VE', '165', '59'],
#  ['S. Akinyoola', '9', '22', 'BJ', '170', '75'],
#  ['S. Guarirapa', '16', '19', 'VE', '188', '-']]

# %%
import pandas as pd

plantilla_df = pd.DataFrame(plantilla_final)
plantilla_df
# Out:
#                       0   1   2   3    4   5
# 0             A. Baroja   1  32  VE  183  79
# 1   Frankarlos BenÃ­tez  35  18  VE  184   -
# 2         W. HernÃ¡ndez  23  21  VE  185  82
# 3             C. Rivero  13  29  VE  182  80
# 4               D. Osio   4  25  VE  192  79
# 5            D. Rivillo   5  25  VE  179  72
# 6            E. Fereira   2  21  VE  169  63
# 7          J. Velasquez  27  21  VE  185  77
# 8              M. Rivas  26  23  VE  188  85
# 9            R. Quijada   6  33  VE  186  73
# 10        R. Villanueva   3  29  VE  175  70
# 11       S. Notaroberto  14  24  VE  175  73
# 12           C. SuÃ¡rez  17  30  VE  170  68
# 13          E. Castillo   8  28  VE  175  76
# 14            J. Torres  30  19  VE    -   -
# 15         L. GonzÃ¡lez  24  23  VE  174  65
# 16          L. RamÃ­rez  11  25  VE  177  66
# 17        V. RodrÃ­guez  21  32  VE  177  71
# 18          A. Zambrano  10  26  VE  179  73
# 19            Ade Oguns  15  21  NG  176  76
# 20            B. Albizo  33  19  VE  170  58
# 21            B. Ortega  32  19  VE    -   -
# 22            D. Ovando  18  20  EC  181  68
# 23            E. Moreno  28  22  VE   78  72
# 24            F. Guerra  37  18  VE  176  77
# 25             K. Bonsu  19  21  GH  168  66
# 26             M. Celis   7  26  VE  190  79
# 27            M. Molina  31  23  VE  174  68
# 28         M. SulbarÃ¡n  22  19  VE  165  59
# 29         S. Akinyoola   9  22  BJ  170  75
# 30         S. Guarirapa  16  19  VE  188   -

# %%
plantilla_df.columns= ['nombre','numero','edad','nacionalidad','altura','peso']
plantilla_df
# Out:
#                  nombre numero edad nacionalidad altura peso
# 0             A. Baroja      1   32           VE    183   79
# 1   Frankarlos BenÃ­tez     35   18           VE    184    -
# 2         W. HernÃ¡ndez     23   21           VE    185   82
# 3             C. Rivero     13   29           VE    182   80
# 4               D. Osio      4   25           VE    192   79
# 5            D. Rivillo      5   25           VE    179   72
# 6            E. Fereira      2   21           VE    169   63
# 7          J. Velasquez     27   21           VE    185   77
# 8              M. Rivas     26   23           VE    188   85
# 9            R. Quijada      6   33           VE    186   73
# 10        R. Villanueva      3   29           VE    175   70
# 11       S. Notaroberto     14   24           VE    175   73
# 12           C. SuÃ¡rez     17   30           VE    170   68
# 13          E. Castillo      8   28           VE    175   76
# 14            J. Torres     30   19           VE      -    -
# 15         L. GonzÃ¡lez     24   23           VE    174   65
# 16          L. RamÃ­rez     11   25           VE    177   66
# 17        V. RodrÃ­guez     21   32           VE    177   71
# 18          A. Zambrano     10   26           VE    179   73
# 19            Ade Oguns     15   21           NG    176   76
# 20            B. Albizo     33   19           VE    170   58
# 21            B. Ortega     32   19           VE      -    -
# 22            D. Ovando     18   20           EC    181   68
# 23            E. Moreno     28   22           VE     78   72
# 24            F. Guerra     37   18           VE    176   77
# 25             K. Bonsu     19   21           GH    168   66
# 26             M. Celis      7   26           VE    190   79
# 27            M. Molina     31   23           VE    174   68
# 28         M. SulbarÃ¡n     22   19           VE    165   59
# 29         S. Akinyoola      9   22           BJ    170   75
# 30         S. Guarirapa     16   19           VE    188    -

# %%
plantilla_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   nombre        31 non-null     object
#  1   numero        31 non-null     object
#  2   edad          31 non-null     object
#  3   nacionalidad  31 non-null     object
#  4   altura        31 non-null     object
#  5   peso          31 non-null     object
# dtypes: object(6)
# memory usage: 1.6+ KB

# %%
plantilla_df['altura'] = pd.to_numeric(plantilla_df['altura'], errors= 'coerce')

# %%
plantilla_df['edad'] = pd.to_numeric(plantilla_df['edad'], errors= 'coerce')

# %%
plantilla_df['peso'] = pd.to_numeric(plantilla_df['peso'], errors= 'coerce')

# %%
plantilla_df
# Out:
#                  nombre numero  edad nacionalidad  altura  peso
# 0             A. Baroja      1    32           VE   183.0  79.0
# 1   Frankarlos BenÃ­tez     35    18           VE   184.0   NaN
# 2         W. HernÃ¡ndez     23    21           VE   185.0  82.0
# 3             C. Rivero     13    29           VE   182.0  80.0
# 4               D. Osio      4    25           VE   192.0  79.0
# 5            D. Rivillo      5    25           VE   179.0  72.0
# 6            E. Fereira      2    21           VE   169.0  63.0
# 7          J. Velasquez     27    21           VE   185.0  77.0
# 8              M. Rivas     26    23           VE   188.0  85.0
# 9            R. Quijada      6    33           VE   186.0  73.0
# 10        R. Villanueva      3    29           VE   175.0  70.0
# 11       S. Notaroberto     14    24           VE   175.0  73.0
# 12           C. SuÃ¡rez     17    30           VE   170.0  68.0
# 13          E. Castillo      8    28           VE   175.0  76.0
# 14            J. Torres     30    19           VE     NaN   NaN
# 15         L. GonzÃ¡lez     24    23           VE   174.0  65.0
# 16          L. RamÃ­rez     11    25           VE   177.0  66.0
# 17        V. RodrÃ­guez     21    32           VE   177.0  71.0
# 18          A. Zambrano     10    26           VE   179.0  73.0
# 19            Ade Oguns     15    21           NG   176.0  76.0
# 20            B. Albizo     33    19           VE   170.0  58.0
# 21            B. Ortega     32    19           VE     NaN   NaN
# 22            D. Ovando     18    20           EC   181.0  68.0
# 23            E. Moreno     28    22           VE    78.0  72.0
# 24            F. Guerra     37    18           VE   176.0  77.0
# 25             K. Bonsu     19    21           GH   168.0  66.0
# 26             M. Celis      7    26           VE   190.0  79.0
# 27            M. Molina     31    23           VE   174.0  68.0
# 28         M. SulbarÃ¡n     22    19           VE   165.0  59.0
# 29         S. Akinyoola      9    22           BJ   170.0  75.0
# 30         S. Guarirapa     16    19           VE   188.0   NaN

# %%
plantilla_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   nombre        31 non-null     object
#  1   numero        31 non-null     object
#  2   edad          31 non-null     int64
#  3   nacionalidad  31 non-null     object
#  4   altura        29 non-null     float64
#  5   peso          27 non-null     float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 1.6+ KB

# %%
cambio1 = plantilla_df.loc[plantilla_df['altura'] == 78, 'altura'] == 178
cambio1
# Out:
# 23    False
# Name: altura, dtype: bool

# %%
plantilla_df
# Out:
#                  nombre numero  edad nacionalidad  altura  peso
# 0             A. Baroja      1    32           VE   183.0  79.0
# 1   Frankarlos BenÃ­tez     35    18           VE   184.0   NaN
# 2         W. HernÃ¡ndez     23    21           VE   185.0  82.0
# 3             C. Rivero     13    29           VE   182.0  80.0
# 4               D. Osio      4    25           VE   192.0  79.0
# 5            D. Rivillo      5    25           VE   179.0  72.0
# 6            E. Fereira      2    21           VE   169.0  63.0
# 7          J. Velasquez     27    21           VE   185.0  77.0
# 8              M. Rivas     26    23           VE   188.0  85.0
# 9            R. Quijada      6    33           VE   186.0  73.0
# 10        R. Villanueva      3    29           VE   175.0  70.0
# 11       S. Notaroberto     14    24           VE   175.0  73.0
# 12           C. SuÃ¡rez     17    30           VE   170.0  68.0
# 13          E. Castillo      8    28           VE   175.0  76.0
# 14            J. Torres     30    19           VE     NaN   NaN
# 15         L. GonzÃ¡lez     24    23           VE   174.0  65.0
# 16          L. RamÃ­rez     11    25           VE   177.0  66.0
# 17        V. RodrÃ­guez     21    32           VE   177.0  71.0
# 18          A. Zambrano     10    26           VE   179.0  73.0
# 19            Ade Oguns     15    21           NG   176.0  76.0
# 20            B. Albizo     33    19           VE   170.0  58.0
# 21            B. Ortega     32    19           VE     NaN   NaN
# 22            D. Ovando     18    20           EC   181.0  68.0
# 23            E. Moreno     28    22           VE    78.0  72.0
# 24            F. Guerra     37    18           VE   176.0  77.0
# 25             K. Bonsu     19    21           GH   168.0  66.0
# 26             M. Celis      7    26           VE   190.0  79.0
# 27            M. Molina     31    23           VE   174.0  68.0
# 28         M. SulbarÃ¡n     22    19           VE   165.0  59.0
# 29         S. Akinyoola      9    22           BJ   170.0  75.0
# 30         S. Guarirapa     16    19           VE   188.0   NaN

# %%
cambio1 = plantilla_df.altura.replace({78: 178}, inplace = True)
cambio1

# %%
plantilla_df
# Out:
#                  nombre numero  edad nacionalidad  altura  peso
# 0             A. Baroja      1    32           VE   183.0  79.0
# 1   Frankarlos BenÃ­tez     35    18           VE   184.0   NaN
# 2         W. HernÃ¡ndez     23    21           VE   185.0  82.0
# 3             C. Rivero     13    29           VE   182.0  80.0
# 4               D. Osio      4    25           VE   192.0  79.0
# 5            D. Rivillo      5    25           VE   179.0  72.0
# 6            E. Fereira      2    21           VE   169.0  63.0
# 7          J. Velasquez     27    21           VE   185.0  77.0
# 8              M. Rivas     26    23           VE   188.0  85.0
# 9            R. Quijada      6    33           VE   186.0  73.0
# 10        R. Villanueva      3    29           VE   175.0  70.0
# 11       S. Notaroberto     14    24           VE   175.0  73.0
# 12           C. SuÃ¡rez     17    30           VE   170.0  68.0
# 13          E. Castillo      8    28           VE   175.0  76.0
# 14            J. Torres     30    19           VE     NaN   NaN
# 15         L. GonzÃ¡lez     24    23           VE   174.0  65.0
# 16          L. RamÃ­rez     11    25           VE   177.0  66.0
# 17        V. RodrÃ­guez     21    32           VE   177.0  71.0
# 18          A. Zambrano     10    26           VE   179.0  73.0
# 19            Ade Oguns     15    21           NG   176.0  76.0
# 20            B. Albizo     33    19           VE   170.0  58.0
# 21            B. Ortega     32    19           VE     NaN   NaN
# 22            D. Ovando     18    20           EC   181.0  68.0
# 23            E. Moreno     28    22           VE   178.0  72.0
# 24            F. Guerra     37    18           VE   176.0  77.0
# 25             K. Bonsu     19    21           GH   168.0  66.0
# 26             M. Celis      7    26           VE   190.0  79.0
# 27            M. Molina     31    23           VE   174.0  68.0
# 28         M. SulbarÃ¡n     22    19           VE   165.0  59.0
# 29         S. Akinyoola      9    22           BJ   170.0  75.0
# 30         S. Guarirapa     16    19           VE   188.0   NaN

# %%
plantilla_df.to_csv('plantilla_ccsfc_2021-2022.csv')

# %% [markdown]
# #### analisis agregados

# %%
plantilla_df.boxplot()

# %%
print(plantilla_df.altura.min(), '  ',  plantilla_df.peso.min())
print(plantilla_df.altura.max(),   '  ',plantilla_df.peso.max())
print(plantilla_df.altura.mean(),  '  ',plantilla_df.peso.mean())
# Out:
# 165.0    58.0
# 192.0    85.0
# 178.31034482758622    72.22222222222223

# %%
menos_alto = round(plantilla_df['altura'].min(),2)
altura_promedio = round(plantilla_df[['altura']].mean(),2)
mas_alto = round(plantilla_df[['altura']].max(),2)

# %%
extranjeros = plantilla_df.loc[plantilla_df['nacionalidad'] != 'VE']
len(extranjeros)
# Out:
# 4

# %%
venezolanos = plantilla_df.loc[plantilla_df['nacionalidad'] == 'VE']
len(venezolanos)
# Out:
# 27

# %% [markdown]
# ### Visualizacion

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.style.use('fast')
