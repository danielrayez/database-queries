# %% [markdown]
# En este proyecto voy a extraer, desde la página web resultadosfutbol.com algunos datos básicos de los equipos de futbol de las ligas de Venezuela, Colombia, Argentina y Brasil. Estos datos serán exportados a dos destinos: una hoja de excel y una base de datos en postresql.
#
# En este proyecto trabajaré con las librerias de python: requests, bs4, pandas, sqlachemy y psycopg2.

# %%
url = 'https://www.resultados-futbol.com/primera_division_argentina'

# %%
import requests

# %%
pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\danie\anaconda3\lib\site-packages (4.8.2)
# Requirement already satisfied: soupsieve>=1.2 in c:\users\danie\anaconda3\lib\site-packages (from beautifulsoup4) (1.9.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup

# %%
# función para extaer los datos de interés de dado un link de equipo dado
def datos_equipo(link):
    r = requests.get(link)
    s = BeautifulSoup(r.text, 'lxml')
    e_soup = s.find('div', attrs= {'class':'contentitem bi-info'}).find_all('ul')
    
    e_soup_span = e_soup[0].find_all_next('span')
    
    equipo = []
    
    nombre_equipo = e_soup_span[3].get_text()
        
    pais_p = e_soup_span[7].text
    pais_d = pais_p[1:]
        
    ciudad = e_soup_span[9].text
        
    entrenador = e_soup_span[13].text
        
#     estadio = e_soup_span[35].text 
        
#     capacidad_estadio = e_soup_span[37].text
        
    equipo.append(nombre_equipo)
    equipo.append(pais_d)
    equipo.append(ciudad)
    equipo.append(entrenador)
    #equipo.append(estadio)
    #equipo.append(capacidad_estadio)
    
    return equipo

# %%
# esta funcion es para obtener los links de cada una de las ligas de futbol de interés
def obtener_websites_equipos(link_ppal):
    re = requests.get(link_ppal)
    sopa = BeautifulSoup(re.text, 'lxml')
    sopa_equipos_liga = sopa.find('table', attrs= {'id':'tabla2'}).find_all('tr')
    sopa_equipos_liga.pop(0)
    links1 = [url.a.get('href') for url in sopa_equipos_liga]
    links2 = ["https://www.resultados-futbol.com"+url for url in links1]
    return links2

# %%
liga = str(url[34:])
liga
# Out:
# 'primera_division_argentina'

# %%
#Obtengo todos los links de los equipos de la liga
links = obtener_websites_equipos(url)

# %%
links
# Out:
# ['https://www.resultados-futbol.com/Atletico-Tucuman/2022',
#  'https://www.resultados-futbol.com/Gimnasia-Plata/2022',
#  'https://www.resultados-futbol.com/Ca-Huracan/2022',
#  'https://www.resultados-futbol.com/Ca-River-Plate/2022',
#  'https://www.resultados-futbol.com/Patronato/2022',
#  'https://www.resultados-futbol.com/Godoy-Cruz-Antonio-Tomba/2022',
#  'https://www.resultados-futbol.com/Platense/2022',
#  'https://www.resultados-futbol.com/Union-Santa-Fe/2022',
#  'https://www.resultados-futbol.com/Racing-Club-Avellaneda/2022',
#  'https://www.resultados-futbol.com/Argentinos-Juniors/2022',
#  'https://www.resultados-futbol.com/Ca-Boca-Juniors/2022',
#  'https://www.resultados-futbol.com/Ca-Tigre/2022',
#  'https://www.resultados-futbol.com/San-Lorenzo/2022',
#  'https://www.resultados-futbol.com/Arsenal-Sarandi-Fc/2022',
#  'https://www.resultados-futbol.com/Newells-Old-Boys/2022',
#  'https://www.resultados-futbol.com/Sarmiento/2022',
#  'https://www.resultados-futbol.com/Ca-Rosario-Central/2022',
#  'https://www.resultados-futbol.com/Ca-Banfield/2022',
#  'https://www.resultados-futbol.com/Colon-Santa-Fe/2022',
#  'https://www.resultados-futbol.com/Defensa-Justicia/2022',
#  'https://www.resultados-futbol.com/Central-Cordob/2022',
#  'https://www.resultados-futbol.com/Barracas-Central/2022',
#  'https://www.resultados-futbol.com/Estudiantes-Plata/2022',
#  'https://www.resultados-futbol.com/Talleres-Cordoba/2022',
#  'https://www.resultados-futbol.com/Independiente/2022',
#  'https://www.resultados-futbol.com/Ca-Velez-Sarsfield/2022',
#  'https://www.resultados-futbol.com/Aldosivi/2022',
#  'https://www.resultados-futbol.com/Ca-Lanus/2022']

# %%
# ingreso a cada link obtenido y extraigo los datos de cada equipo
lista_equipos = []
for i in links:
    lista_equipos.append(datos_equipo(i))
    print(f'voy por el equipo {i}')
# Out:
# voy por el equipo https://www.resultados-futbol.com/Atletico-Tucuman/2022
# voy por el equipo https://www.resultados-futbol.com/Gimnasia-Plata/2022
# voy por el equipo https://www.resultados-futbol.com/Ca-Huracan/2022
# voy por el equipo https://www.resultados-futbol.com/Ca-River-Plate/2022
# voy por el equipo https://www.resultados-futbol.com/Patronato/2022
# voy por el equipo https://www.resultados-futbol.com/Godoy-Cruz-Antonio-Tomba/2022
# voy por el equipo https://www.resultados-futbol.com/Platense/2022
# voy por el equipo https://www.resultados-futbol.com/Union-Santa-Fe/2022
# voy por el equipo https://www.resultados-futbol.com/Racing-Club-Avellaneda/2022
# voy por el equipo https://www.resultados-futbol.com/Argentinos-Juniors/2022
# voy por el equipo https://www.resultados-futbol.com/Ca-Boca-Juniors/2022
# voy por el equipo https://www.resultados-futbol.com/Ca-Tigre/2022
# voy por el equipo https://www.resultados-futbol.com/San-Lorenzo/2022
# voy por el equipo https://www.resultados-futbol.com/Arsenal-Sarandi-Fc/2022
# voy por el equipo https://www.resultados-futbol.com/Newells-Old-Boys/2022
# voy por el equipo https://www.resultados-futbol.com/Sarmiento/2022
# voy por el equipo https://www.resultados-futbol.com/Ca-Rosario-Central/2022
# voy por el equipo https://www.resultados-futbol.com/Ca-Banfield/2022
# voy por el equipo https://www.resultados-futbol.com/Colon-Santa-Fe/2022
# voy por el equipo https://www.resultados-futbol.com/Defensa-Justicia/2022
# voy por el equipo https://www.resultados-futbol.com/Central-Cordob/2022
# voy por el equipo https://www.resultados-futbol.com/Barracas-Central/2022
# voy por el equipo https://www.resultados-futbol.com/Estudiantes-Plata/2022
# voy por el equipo https://www.resultados-futbol.com/Talleres-Cordoba/2022
# voy por el equipo https://www.resultados-futbol.com/Independiente/2022
# voy por el equipo https://www.resultados-futbol.com/Ca-Velez-Sarsfield/2022
# voy por el equipo https://www.resultados-futbol.com/Aldosivi/2022
# voy por el equipo https://www.resultados-futbol.com/Ca-Lanus/2022

# %%
lista_equipos
# Out:
# [['Club AtlÃ©tico TucumÃ¡n',
#   'Argentina',
#   'San Miguel de TucumÃ¡n, Provincia de Tucu',
#   'Lucas Pusineri'],
#  ['Club de Gimnasia y Esgrima La Plata',
#   'Argentina',
#   'La Plata, Provincia de Buenos Aires',
#   'NÃ©stor Gorosito'],
#  ['Club AtlÃ©tico HuracÃ¡n',
#   'Argentina',
#   'Capital Federal, Ciudad de Buenos Aires',
#   'Diego Dabove'],
#  ['Club Atletico River Plate',
#   'Argentina',
#   'Capital Federal, Ciudad de Buenos Aires',
#   'Marcelo Gallardo'],
#  ['Club Atl. Patronato de la Juv. Catolica',
#   'Argentina',
#   'ParanÃ¡, Provincia de Entre RÃ\xados',
#   'Facundo Sava'],
#  ['Club Deportivo Godoy Cruz Antonio Tomba',
#   'Argentina',
#   'Mendoza, Provincia de Mendoza',
#   'Sergio GÃ³mez'],
#  ['Club Atletico Platense', 'Argentina', 'Buenos Aires', 'Omar De Felippe'],
#  ['Club AtlÃ©tico UniÃ³n de Santa Fe',
#   'Argentina',
#   'Ciudad de Santa Fe, Provincia de Santa F',
#   'Gustavo MunÃºa'],
#  ['Racing Club',
#   'Argentina',
#   'Avellaneda, Provincia de Buenos Aires',
#   'Fernando Gago'],
#  ['AsociaciÃ³n AtlÃ©tica Argentinos Juniors',
#   'Argentina',
#   'Capital Federal, Ciudad de Buenos Aires',
#   'Gabriel Milito'],
#  ['Club AtlÃ©tico Boca Juniors',
#   'Argentina',
#   'Ciudad de Buenos Aires',
#   'Hugo Ibarra'],
#  ['Club AtlÃ©tico Tigre',
#   'Argentina',
#   'San Fernando, Provincia de Buenos Aires',
#   'Diego MartÃ\xadnez'],
#  ['Club AtlÃ©tico San Lorenzo de Almagro',
#   'Argentina',
#   'Capital Federal, Ciudad de Buenos Aires',
#   'RubÃ©n DarÃ\xado InsÃºa'],
#  ['Arsenal (SarandÃ\xad) Futbol Club',
#   'Argentina',
#   'Avellaneda, Provincia de Buenos Aires',
#   'Sergio Rondina'],
#  ["Club AtlÃ©tico Newell's Old Boys",
#   'Argentina',
#   'Rosario, Provincia de Santa Fe',
#   'Javier Sanguinetti'],
#  ['Club Atletico Sarmiento',
#   'Argentina',
#   'JunÃ\xadn, Provincia de Buenos Aires',
#   'Israel Damonte'],
#  ['Club AtlÃ©tico Rosario Central',
#   'Argentina',
#   'Rosario, Provincia de Santa Fe',
#   'Carlos TÃ©vez'],
#  ['Club AtlÃ©tico Banfield', 'Argentina', 'Banfield', 'Claudio Vivas'],
#  ['Club Atletico ColÃ³n',
#   'Argentina',
#   'Ciudad de Santa Fe, Provincia de Santa F',
#   'Sergio Rondina'],
#  ['Club Social y Dep. Defensa y Justicia',
#   'Argentina',
#   'Florencio Varela, Provincia de Buenos Ai',
#   'SebastiÃ¡n Beccacece'],
#  ['Club AtlÃ©tico Central CÃ³rdoba de Santiag',
#   'Argentina',
#   'Santiago del Estero, Provincia de Santia',
#   'Abel Balbo'],
#  ['Club Atletico Barracas Central',
#   'Argentina',
#   'Ciudad AutÃ³noma de Buenos Aires',
#   'Alfredo Berti'],
#  ['Club Estudiantes de la Plata',
#   'Argentina',
#   'La Plata, Provincia de Buenos Aires',
#   'Gabriel Milito'],
#  ['Club AtlÃ©tico Talleres (CÃ³rdoba)',
#   'Argentina',
#   'CÃ³rdoba',
#   'Pedro Caixinha'],
#  ['Club Atletico Independiente',
#   'Argentina',
#   'Avellaneda, Provincia de Buenos Aires',
#   'Julio Falcioni'],
#  ['Club AtlÃ©tico Velez Sarsfield',
#   'Argentina',
#   'Capital Federal, Ciudad de Buenos Aires',
#   'Alexander Medina'],
#  ['Club AtlÃ©tico Aldosivi',
#   'Argentina',
#   'Mar del Plata, Provincia de Buenos Aires',
#   'Leandro Somoza'],
#  ['Club AtlÃ©tico LanÃºs',
#   'Argentina',
#   'LanÃºs, Provincia de Buenos Aires',
#   'Luis ZubeldÃ\xada']]

# %%
import pandas as pd

# %%
#paso lista a dataframe
equipos_df = pd.DataFrame(lista_equipos)
equipos_df
# Out:
#                                              0          1  \
# 0                      Club AtlÃ©tico TucumÃ¡n  Argentina
# 1          Club de Gimnasia y Esgrima La Plata  Argentina
# 2                      Club AtlÃ©tico HuracÃ¡n  Argentina
# 3                    Club Atletico River Plate  Argentina
# 4      Club Atl. Patronato de la Juv. Catolica  Argentina
# 5      Club Deportivo Godoy Cruz Antonio Tomba  Argentina
# 6                       Club Atletico Platense  Argentina
# 7            Club AtlÃ©tico UniÃ³n de Santa Fe  Argentina
# 8                                  Racing Club  Argentina
# 9     AsociaciÃ³n AtlÃ©tica Argentinos Juniors  Argentina
# 10                 Club AtlÃ©tico Boca Juniors  Argentina
# 11                        Club AtlÃ©tico Tigre  Argentina
# 12       Club AtlÃ©tico San Lorenzo de Almagro  Argentina
# 13              Arsenal (SarandÃ­) Futbol Club  Argentina
# 14            Club AtlÃ©tico Newell's Old Boys  Argentina
# 15                     Club Atletico Sarmiento  Argentina
# 16              Club AtlÃ©tico Rosario Central  Argentina
# 17                     Club AtlÃ©tico Banfield  Argentina
# 18                        Club Atletico ColÃ³n  Argentina
# 19       Club Social y Dep. Defensa y Justicia  Argentina
# 20  Club AtlÃ©tico Central CÃ³rdoba de Santiag  Argentina
# 21              Club Atletico Barracas Central  Argentina
# 22                Club Estudiantes de la Plata  Argentina
# 23          Club AtlÃ©tico Talleres (CÃ³rdoba)  Argentina
# 24                 Club Atletico Independiente  Argentina
# 25              Club AtlÃ©tico Velez Sarsfield  Argentina
# 26                     Club AtlÃ©tico Aldosivi  Argentina
# 27                       Club AtlÃ©tico LanÃºs  Argentina
#
#                                             2                     3
# 0   San Miguel de TucumÃ¡n, Provincia de Tucu        Lucas Pusineri
# 1         La Plata, Provincia de Buenos Aires      NÃ©stor Gorosito
# 2     Capital Federal, Ciudad de Buenos Aires          Diego Dabove
# 3     Capital Federal, Ciudad de Buenos Aires      Marcelo Gallardo
# 4           ParanÃ¡, Provincia de Entre RÃ­os          Facundo Sava
# 5               Mendoza, Provincia de Mendoza         Sergio GÃ³mez
# 6                                Buenos Aires       Omar De Felippe
# 7    Ciudad de Santa Fe, Provincia de Santa F        Gustavo MunÃºa
# 8       Avellaneda, Provincia de Buenos Aires         Fernando Gago
# 9     Capital Federal, Ciudad de Buenos Aires        Gabriel Milito
# 10                     Ciudad de Buenos Aires           Hugo Ibarra
# 11    San Fernando, Provincia de Buenos Aires       Diego MartÃ­nez
# 12    Capital Federal, Ciudad de Buenos Aires  RubÃ©n DarÃ­o InsÃºa
# 13      Avellaneda, Provincia de Buenos Aires        Sergio Rondina
# 14             Rosario, Provincia de Santa Fe    Javier Sanguinetti
# 15          JunÃ­n, Provincia de Buenos Aires        Israel Damonte
# 16             Rosario, Provincia de Santa Fe         Carlos TÃ©vez
# 17                                   Banfield         Claudio Vivas
# 18   Ciudad de Santa Fe, Provincia de Santa F        Sergio Rondina
# 19   Florencio Varela, Provincia de Buenos Ai  SebastiÃ¡n Beccacece
# 20   Santiago del Estero, Provincia de Santia            Abel Balbo
# 21           Ciudad AutÃ³noma de Buenos Aires         Alfredo Berti
# 22        La Plata, Provincia de Buenos Aires        Gabriel Milito
# 23                                   CÃ³rdoba        Pedro Caixinha
# 24      Avellaneda, Provincia de Buenos Aires        Julio Falcioni
# 25    Capital Federal, Ciudad de Buenos Aires      Alexander Medina
# 26   Mar del Plata, Provincia de Buenos Aires        Leandro Somoza
# 27          LanÃºs, Provincia de Buenos Aires        Luis ZubeldÃ­a

# %%
#renombro columnas
equipos_df.columns=['nombre equipo','país','ciudad', 'entrenador']
equipos_df
# Out:
#                                  nombre equipo       país  \
# 0                      Club AtlÃ©tico TucumÃ¡n  Argentina
# 1          Club de Gimnasia y Esgrima La Plata  Argentina
# 2                      Club AtlÃ©tico HuracÃ¡n  Argentina
# 3                    Club Atletico River Plate  Argentina
# 4      Club Atl. Patronato de la Juv. Catolica  Argentina
# 5      Club Deportivo Godoy Cruz Antonio Tomba  Argentina
# 6                       Club Atletico Platense  Argentina
# 7            Club AtlÃ©tico UniÃ³n de Santa Fe  Argentina
# 8                                  Racing Club  Argentina
# 9     AsociaciÃ³n AtlÃ©tica Argentinos Juniors  Argentina
# 10                 Club AtlÃ©tico Boca Juniors  Argentina
# 11                        Club AtlÃ©tico Tigre  Argentina
# 12       Club AtlÃ©tico San Lorenzo de Almagro  Argentina
# 13              Arsenal (SarandÃ­) Futbol Club  Argentina
# 14            Club AtlÃ©tico Newell's Old Boys  Argentina
# 15                     Club Atletico Sarmiento  Argentina
# 16              Club AtlÃ©tico Rosario Central  Argentina
# 17                     Club AtlÃ©tico Banfield  Argentina
# 18                        Club Atletico ColÃ³n  Argentina
# 19       Club Social y Dep. Defensa y Justicia  Argentina
# 20  Club AtlÃ©tico Central CÃ³rdoba de Santiag  Argentina
# 21              Club Atletico Barracas Central  Argentina
# 22                Club Estudiantes de la Plata  Argentina
# 23          Club AtlÃ©tico Talleres (CÃ³rdoba)  Argentina
# 24                 Club Atletico Independiente  Argentina
# 25              Club AtlÃ©tico Velez Sarsfield  Argentina
# 26                     Club AtlÃ©tico Aldosivi  Argentina
# 27                       Club AtlÃ©tico LanÃºs  Argentina
#
#                                        ciudad            entrenador
# 0   San Miguel de TucumÃ¡n, Provincia de Tucu        Lucas Pusineri
# 1         La Plata, Provincia de Buenos Aires      NÃ©stor Gorosito
# 2     Capital Federal, Ciudad de Buenos Aires          Diego Dabove
# 3     Capital Federal, Ciudad de Buenos Aires      Marcelo Gallardo
# 4           ParanÃ¡, Provincia de Entre RÃ­os          Facundo Sava
# 5               Mendoza, Provincia de Mendoza         Sergio GÃ³mez
# 6                                Buenos Aires       Omar De Felippe
# 7    Ciudad de Santa Fe, Provincia de Santa F        Gustavo MunÃºa
# 8       Avellaneda, Provincia de Buenos Aires         Fernando Gago
# 9     Capital Federal, Ciudad de Buenos Aires        Gabriel Milito
# 10                     Ciudad de Buenos Aires           Hugo Ibarra
# 11    San Fernando, Provincia de Buenos Aires       Diego MartÃ­nez
# 12    Capital Federal, Ciudad de Buenos Aires  RubÃ©n DarÃ­o InsÃºa
# 13      Avellaneda, Provincia de Buenos Aires        Sergio Rondina
# 14             Rosario, Provincia de Santa Fe    Javier Sanguinetti
# 15          JunÃ­n, Provincia de Buenos Aires        Israel Damonte
# 16             Rosario, Provincia de Santa Fe         Carlos TÃ©vez
# 17                                   Banfield         Claudio Vivas
# 18   Ciudad de Santa Fe, Provincia de Santa F        Sergio Rondina
# 19   Florencio Varela, Provincia de Buenos Ai  SebastiÃ¡n Beccacece
# 20   Santiago del Estero, Provincia de Santia            Abel Balbo
# 21           Ciudad AutÃ³noma de Buenos Aires         Alfredo Berti
# 22        La Plata, Provincia de Buenos Aires        Gabriel Milito
# 23                                   CÃ³rdoba        Pedro Caixinha
# 24      Avellaneda, Provincia de Buenos Aires        Julio Falcioni
# 25    Capital Federal, Ciudad de Buenos Aires      Alexander Medina
# 26   Mar del Plata, Provincia de Buenos Aires        Leandro Somoza
# 27          LanÃºs, Provincia de Buenos Aires        Luis ZubeldÃ­a

# %%
#establezco índice para evitar conflictos con la base de datos de destino
equipos_df.set_index('nombre equipo', inplace=True)

# %%
equipos_df = equipos_df.assign(liga=liga)

# %%
equipos_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28 entries, Club AtlÃ©tico TucumÃ¡n to Club AtlÃ©tico LanÃºs
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   país        28 non-null     object
#  1   ciudad      28 non-null     object
#  2   entrenador  28 non-null     object
#  3   liga        28 non-null     object
# dtypes: object(4)
# memory usage: 1.1+ KB

# %%
#Exporto a Excel
with pd.ExcelWriter('equipos_ligas1ra_2022-2.xlsx', mode='a', engine ='openpyxl') as writer:
    equipos_df.to_excel(writer, sheet_name= liga)

# %%
#Exporto a sql

# %%
pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in c:\users\danie\anaconda3\lib\site-packages (2.9.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine

# %%
cadena_conexion = 'postgres+psycopg2://postgres:2511@localhost:5432/analisis_futbol'

# %%
engine = create_engine(cadena_conexion)

# %%
equipos_df.to_sql('equipos',con=engine, if_exists= 'append')
