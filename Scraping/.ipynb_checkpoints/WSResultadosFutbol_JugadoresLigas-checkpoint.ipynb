# %% [markdown]
# En este proyecto busco extraer algunos datos de interés de los futbolistas que integran las plantillas de los equipos de las ligas de Venezuela, Colombia, Brasil, Argentina e Inglaterra. Estos datos serán exportados a dos destinos: una hoja de excel y una base de datos en postresql.
#
# En este proyecto trabajaré con las librerias de python: requests, bs4, pandas, sqlachemy y psycopg2
#
# Estos datos formarán parte de la tabla 'jugadores' en la base de datos análisis futbol en postgresql, donde haremos, entre otros, el modelado de datos junto a las tablas 'ligas' y 'equipos'.
#
# Posterior a la extracción y transformacion y carga, haré una presentación visual con algunas comparaciones entre ligas en Power Bi

# %%
url = 'https://www.resultados-futbol.com/premier'

# %%
import requests

# %%
pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\danie\anaconda3\lib\site-packages (4.8.2)
# Requirement already satisfied: soupsieve>=1.2 in c:\users\danie\anaconda3\lib\site-packages (from beautifulsoup4) (1.9.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup

# %%
# esta funcion es para obtener los links de cada una de las ligas de futbol de interés
def obtener_websites_equipos(link_ppal):
    re = requests.get(link_ppal)
    sopa = BeautifulSoup(re.text, 'lxml')
    sopa_equipos_liga = sopa.find('table', attrs= {'id':'tabla2'}).find_all('tr')
    sopa_equipos_liga.pop(0)
    links1 = [url.a.get('href') for url in sopa_equipos_liga]
    links2 = ["https://www.resultados-futbol.com"+url for url in links1]
    return links2

# %%
# función para extraer los datos de cada jugador de todos los equipos de la liga dada
def armar_plantilla(link):  
    
    
    r = requests.get(link)
    sopa = BeautifulSoup(r.text, 'lxml')
    ptll_soup = sopa.find_all('tr', attrs= {'itemprop':'employee'})
    
        
    plantilla = []
    i = 0
    
    while i <  len(ptll_soup):
                    
                   
        print(f"estoy extrayendo los datos del jugador {i}")
        
                #equipo
        equipo =  str(link[34:])
                #posicion
        posicion = ptll_soup[i].find_previous_sibling('tr', attrs = {'class':'first-child'}).get_text(strip = True)
                #nombre
        nombre = ptll_soup[i].find('span').text
               #numero
        numero_jugador = ptll_soup[i].find('td', attrs= {"class":"num"}).text
                #edad
        edad_jugador = ptll_soup[i].find('td', attrs={'itemprop':"birthDate"}).text
                #nacionalidad
        tag_nacionalidad = ptll_soup[i].find('td', attrs= {'itemprop':'nationality'})
        str_nacionalidad = str(tag_nacionalidad)
        nacionalidad = str_nacionalidad[104:106]
                #Altura y peso
        altura_peso = ptll_soup[i].find_all('td', attrs= {'class':'dat'}, limit=2)
        altura= altura_peso[0].text
        peso= altura_peso[1].text

                #agregar nuevo elemento a la lista
        plantilla.extend([equipo])
        plantilla.extend([numero_jugador])
        plantilla.extend([posicion])
        plantilla.extend([nombre])
        plantilla.extend([edad_jugador])
        plantilla.extend([nacionalidad])
        plantilla.extend([altura])
        plantilla.extend([peso])

        i = i+1
        
    else:
        
        return plantilla

# %%
liga = str(url[34:])
liga
# Out:
# 'premier'

# %%
#aplico función al link de la liga para obtener los links de cada equipo que la conforma
links = obtener_websites_equipos(url)

# %%
links
# Out:
# ['https://www.resultados-futbol.com/Manchester-City-Fc',
#  'https://www.resultados-futbol.com/Arsenal',
#  'https://www.resultados-futbol.com/Brentford',
#  'https://www.resultados-futbol.com/Tottenham-Hotspur-Fc',
#  'https://www.resultados-futbol.com/Newcastle-United-Fc',
#  'https://www.resultados-futbol.com/Leeds-United-Afc',
#  'https://www.resultados-futbol.com/Chelsea-Fc',
#  'https://www.resultados-futbol.com/Brighton-Amp-Hov',
#  'https://www.resultados-futbol.com/Aston-Villa-Fc',
#  'https://www.resultados-futbol.com/Nottingham-Forest-Fc',
#  'https://www.resultados-futbol.com/Afc-Bournemouth',
#  'https://www.resultados-futbol.com/Fulham',
#  'https://www.resultados-futbol.com/Liverpool',
#  'https://www.resultados-futbol.com/Wolverhampton',
#  'https://www.resultados-futbol.com/Leicester-City-Fc',
#  'https://www.resultados-futbol.com/Southampton-Fc',
#  'https://www.resultados-futbol.com/Everton-Fc',
#  'https://www.resultados-futbol.com/Crystal-Palace-Fc',
#  'https://www.resultados-futbol.com/West-Ham-United',
#  'https://www.resultados-futbol.com/Manchester-United-Fc']

# %%
#lista donde agrego los datos de cada jugador obtenidos con las función "armar_plantilla"
lis = []
for i in links:
    lis.append(armar_plantilla(i))
# Out:
# estoy extrayendo los datos del jugador 0
# estoy extrayendo los datos del jugador 1
# estoy extrayendo los datos del jugador 2
# estoy extrayendo los datos del jugador 3
# estoy extrayendo los datos del jugador 4
# estoy extrayendo los datos del jugador 5
# estoy extrayendo los datos del jugador 6
# estoy extrayendo los datos del jugador 7
# estoy extrayendo los datos del jugador 8
# estoy extrayendo los datos del jugador 9
# estoy extrayendo los datos del jugador 10
# estoy extrayendo los datos del jugador 11
# estoy extrayendo los datos del jugador 12
# estoy extrayendo los datos del jugador 13
# estoy extrayendo los datos del jugador 14
# estoy extrayendo los datos del jugador 15
# estoy extrayendo los datos del jugador 16
# estoy extrayendo los datos del jugador 17
# estoy extrayendo los datos del jugador 18
# estoy extrayendo los datos del jugador 19
# estoy extrayendo los datos del jugador 20
# estoy extrayendo los datos del jugador 21
# estoy extrayendo los datos del jugador 22
# estoy extrayendo los datos del jugador 23
# estoy extrayendo los datos del jugador 24
# estoy extrayendo los datos del jugador 25
# estoy extrayendo los datos del jugador 26
# estoy extrayendo los datos del jugador 27
# estoy extrayendo los datos del jugador 28
# estoy extrayendo los datos del jugador 0
# estoy extrayendo los datos del jugador 1
# estoy extrayendo los datos del jugador 2
# estoy extrayendo los datos del jugador 3
# estoy extrayendo los datos del jugador 4
# estoy extrayendo los datos del jugador 5
# estoy extrayendo los datos del jugador 6
# estoy extrayendo los datos del jugador 7
# estoy extrayendo los datos del jugador 8
# estoy extrayendo los datos del jugador 9
# estoy extrayendo los datos del jugador 10
# estoy extrayendo los datos del jugador 11
# estoy extrayendo los datos del jugador 12
# estoy extrayendo los datos del jugador 13
# estoy extrayendo los datos del jugador 14
# estoy extrayendo los datos del jugador 15
# estoy extrayendo los datos del jugador 16
# estoy extrayendo los datos del jugador 17
# estoy extrayendo los datos del jugador 18
# estoy extrayendo los datos del jugador 19
# estoy extrayendo los datos del jugador 20
# estoy extrayendo los datos del jugador 21
# estoy extrayendo los datos del jugador 22
# estoy extrayendo los datos del jugador 23
# estoy extrayendo los datos del jugador 24
# estoy extrayendo los datos del jugador 25
# estoy extrayendo los datos del jugador 26
# estoy extrayendo los datos del jugador 0
# estoy extrayendo los datos del jugador 1
# estoy extrayendo los datos del jugador 2
# estoy extrayendo los datos del jugador 3
# estoy extrayendo los datos del jugador 4
# estoy extrayendo los datos del jugador 5
# estoy extrayendo los datos del jugador 6
# estoy extrayendo los datos del jugador 7
# estoy extrayendo los datos del jugador 8
# estoy extrayendo los datos del jugador 9
# estoy extrayendo los datos del jugador 10
# estoy extrayendo los datos del jugador 11
# estoy extrayendo los datos del jugador 12
# estoy extrayendo los datos del jugador 13
# estoy extrayendo los datos del jugador 14
# estoy extrayendo los datos del jugador 15
# estoy extrayendo los datos del jugador 16
# estoy extrayendo los datos del jugador 17
# estoy extrayendo los datos del jugador 18
# estoy extrayendo los datos del jugador 19
# estoy extrayendo los datos del jugador 20
# estoy extrayendo los datos del jugador 21
# estoy extrayendo los datos del jugador 22
# estoy extrayendo los datos del jugador 23
# estoy extrayendo los datos del jugador 24
# estoy extrayendo los datos del jugador 25
# estoy extrayendo los datos del jugador 26
# estoy extrayendo los datos del jugador 27
# estoy extrayendo los datos del jugador 28
# estoy extrayendo los datos del jugador 0
# estoy extrayendo los datos del jugador 1
# estoy extrayendo los datos del jugador 2
# estoy extrayendo los datos del jugador 3
# estoy extrayendo los datos del jugador 4
# estoy extrayendo los datos del jugador 5
# estoy extrayendo los datos del jugador 6
# estoy extrayendo los datos del jugador 7
# estoy extrayendo los datos del jugador 8
# estoy extrayendo los datos del jugador 9
# estoy extrayendo los datos del jugador 10
# estoy extrayendo los datos del jugador 11
# estoy extrayendo los datos del jugador 12
# estoy extrayendo los datos del jugador 13
# estoy extrayendo los datos del jugador 14
# estoy extrayendo los datos del jugador 15
# estoy extrayendo los datos del jugador 16
# estoy extrayendo los datos del jugador 17
# estoy extrayendo los datos del jugador 18
# estoy extrayendo los datos del jugador 19
# estoy extrayendo los datos del jugador 20
# estoy extrayendo los datos del jugador 21
# estoy extrayendo los datos del jugador 22
# estoy extrayendo los datos del jugador 23
# estoy extrayendo los datos del jugador 24
# estoy extrayendo los datos del jugador 25
# estoy extrayendo los datos del jugador 26
# estoy extrayendo los datos del jugador 27
# estoy extrayendo los datos del jugador 0
# estoy extrayendo los datos del jugador 1
# estoy extrayendo los datos del jugador 2
# estoy extrayendo los datos del jugador 3
# estoy extrayendo los datos del jugador 4
# estoy extrayendo los datos del jugador 5
# estoy extrayendo los datos del jugador 6
# estoy extrayendo los datos del jugador 7
# estoy extrayendo los datos del jugador 8
# estoy extrayendo los datos del jugador 9
# estoy extrayendo los datos del jugador 10
# estoy extrayendo los datos del jugador 11
# estoy extrayendo los datos del jugador 12
# estoy extrayendo los datos del jugador 13
# estoy extrayendo los datos del jugador 14
# estoy extrayendo los datos del jugador 15
# estoy extrayendo los datos del jugador 16
# estoy extrayendo los datos del jugador 17
# estoy extrayendo los datos del jugador 18
# estoy extrayendo los datos del jugador 19
# estoy extrayendo los datos del jugador 20
# estoy extrayendo los datos del jugador 21
# estoy extrayendo los datos del jugador 22
# estoy extrayendo los datos del jugador 23
# estoy extrayendo los datos del jugador 24
# estoy extrayendo los datos del jugador 25
# estoy extrayendo los datos del jugador 26
# estoy extrayendo los datos del jugador 27
# estoy extrayendo los datos del jugador 28
# estoy extrayendo los datos del jugador 29
# estoy extrayendo los datos del jugador 0
# estoy extrayendo los datos del jugador 1
# estoy extrayendo los datos del jugador 2
# estoy extrayendo los datos del jugador 3
# estoy extrayendo los datos del jugador 4
# estoy extrayendo los datos del jugador 5
# estoy extrayendo los datos del jugador 6
# estoy extrayendo los datos del jugador 7
# estoy extrayendo los datos del jugador 8
# estoy extrayendo los datos del jugador 9
# estoy extrayendo los datos del jugador 10
# estoy extrayendo los datos del jugador 11
# estoy extrayendo los datos del jugador 12
# estoy extrayendo los datos del jugador 13
# estoy extrayendo los datos del jugador 14
# estoy extrayendo los datos del jugador 15
# estoy extrayendo los datos del jugador 16
# estoy extrayendo los datos del jugador 17
# estoy extrayendo los datos del jugador 18
# estoy extrayendo los datos del jugador 19
# estoy extrayendo los datos del jugador 20
# estoy extrayendo los datos del jugador 21
# estoy extrayendo los datos del jugador 22
# estoy extrayendo los datos del jugador 23
# estoy extrayendo los datos del jugador 24
# estoy extrayendo los datos del jugador 25
# estoy extrayendo los datos del jugador 26
# estoy extrayendo los datos del jugador 27
# estoy extrayendo los datos del jugador 28
# estoy extrayendo los datos del jugador 0
# estoy extrayendo los datos del jugador 1
# estoy extrayendo los datos del jugador 2
# estoy extrayendo los datos del jugador 3
# estoy extrayendo los datos del jugador 4
# estoy extrayendo los datos del jugador 5
# estoy extrayendo los datos del jugador 6
# estoy extrayendo los datos del jugador 7
# estoy extrayendo los datos del jugador 8
# estoy extrayendo los datos del jugador 9
# estoy extrayendo los datos del jugador 10
# estoy extrayendo los datos del jugador 11
# estoy extrayendo los datos del jugador 12
# estoy extrayendo los datos del jugador 13
# estoy extrayendo los datos del jugador 14
# estoy extrayendo los datos del jugador 15
# estoy extrayendo los datos del jugador 16
# estoy extrayendo los datos del jugador 17
# estoy extrayendo los datos del jugador 18
# estoy extrayendo los datos del jugador 19
# estoy extrayendo los datos del jugador 20
# estoy extrayendo los datos del jugador 21
# estoy extrayendo los datos del jugador 22
# estoy extrayendo los datos del jugador 23
# estoy extrayendo los datos del jugador 24
# estoy extrayendo los datos del jugador 25
# estoy extrayendo los datos del jugador 26
# estoy extrayendo los datos del jugador 27
# estoy extrayendo los datos del jugador 28
# estoy extrayendo los datos del jugador 29
# estoy extrayendo los datos del jugador 30
# estoy extrayendo los datos del jugador 0
# estoy extrayendo los datos del jugador 1
# estoy extrayendo los datos del jugador 2
# estoy extrayendo los datos del jugador 3
# estoy extrayendo los datos del jugador 4
# estoy extrayendo los datos del jugador 5
# estoy extrayendo los datos del jugador 6
# estoy extrayendo los datos del jugador 7
# estoy extrayendo los datos del jugador 8
# estoy extrayendo los datos del jugador 9
# estoy extrayendo los datos del jugador 10
# estoy extrayendo los datos del jugador 11
# estoy extrayendo los datos del jugador 12
# estoy extrayendo los datos del jugador 13
# estoy extrayendo los datos del jugador 14
# estoy extrayendo los datos del jugador 15
# estoy extrayendo los datos del jugador 16
# estoy extrayendo los datos del jugador 17
# estoy extrayendo los datos del jugador 18
# estoy extrayendo los datos del jugador 19
# estoy extrayendo los datos del jugador 20
# estoy extrayendo los datos del jugador 21
# estoy extrayendo los datos del jugador 22
# estoy extrayendo los datos del jugador 23
# estoy extrayendo los datos del jugador 24
# estoy extrayendo los datos del jugador 25
# estoy extrayendo los datos del jugador 26
# estoy extrayendo los datos del jugador 27
# estoy extrayendo los datos del jugador 0
# estoy extrayendo los datos del jugador 1
# estoy extrayendo los datos del jugador 2
# estoy extrayendo los datos del jugador 3
# estoy extrayendo los datos del jugador 4
# estoy extrayendo los datos del jugador 5
# estoy extrayendo los datos del jugador 6
# estoy extrayendo los datos del jugador 7
# estoy extrayendo los datos del jugador 8
# estoy extrayendo los datos del jugador 9
# estoy extrayendo los datos del jugador 10
# estoy extrayendo los datos del jugador 11
# estoy extrayendo los datos del jugador 12
# estoy extrayendo los datos del jugador 13
# estoy extrayendo los datos del jugador 14
# estoy extrayendo los datos del jugador 15
# estoy extrayendo los datos del jugador 16
# estoy extrayendo los datos del jugador 17
# estoy extrayendo los datos del jugador 18
# estoy extrayendo los datos del jugador 19
# estoy extrayendo los datos del jugador 20
# estoy extrayendo los datos del jugador 21
# estoy extrayendo los datos del jugador 22
# estoy extrayendo los datos del jugador 23
# estoy extrayendo los datos del jugador 24
# estoy extrayendo los datos del jugador 25
# estoy extrayendo los datos del jugador 26
# estoy extrayendo los datos del jugador 0
# estoy extrayendo los datos del jugador 1
# estoy extrayendo los datos del jugador 2
# estoy extrayendo los datos del jugador 3
# estoy extrayendo los datos del jugador 4
# estoy extrayendo los datos del jugador 5
# estoy extrayendo los datos del jugador 6
# estoy extrayendo los datos del jugador 7
# estoy extrayendo los datos del jugador 8
# estoy extrayendo los datos del jugador 9
# estoy extrayendo los datos del jugador 10
# estoy extrayendo los datos del jugador 11
# estoy extrayendo los datos del jugador 12
# estoy extrayendo los datos del jugador 13
# estoy extrayendo los datos del jugador 14
# estoy extrayendo los datos del jugador 15
# estoy extrayendo los datos del jugador 16
# estoy extrayendo los datos del jugador 17
# estoy extrayendo los datos del jugador 18
# estoy extrayendo los datos del jugador 19
# estoy extrayendo los datos del jugador 20
# estoy extrayendo los datos del jugador 21
# estoy extrayendo los datos del jugador 22
# estoy extrayendo los datos del jugador 23
# estoy extrayendo los datos del jugador 24
# estoy extrayendo los datos del jugador 25
# estoy extrayendo los datos del jugador 26
# estoy extrayendo los datos del jugador 27
# estoy extrayendo los datos del jugador 0
# estoy extrayendo los datos del jugador 1
# estoy extrayendo los datos del jugador 2
# estoy extrayendo los datos del jugador 3
# estoy extrayendo los datos del jugador 4
# estoy extrayendo los datos del jugador 5
# estoy extrayendo los datos del jugador 6
# estoy extrayendo los datos del jugador 7
# estoy extrayendo los datos del jugador 8
# estoy extrayendo los datos del jugador 9
# estoy extrayendo los datos del jugador 10
# estoy extrayendo los datos del jugador 11
# estoy extrayendo los datos del jugador 12
# estoy extrayendo los datos del jugador 13
# estoy extrayendo los datos del jugador 14
# estoy extrayendo los datos del jugador 15
# estoy extrayendo los datos del jugador 16
# estoy extrayendo los datos del jugador 17
# estoy extrayendo los datos del jugador 18
# estoy extrayendo los datos del jugador 19
# estoy extrayendo los datos del jugador 20
# estoy extrayendo los datos del jugador 21
# estoy extrayendo los datos del jugador 22
# estoy extrayendo los datos del jugador 23
# estoy extrayendo los datos del jugador 24
# estoy extrayendo los datos del jugador 25
# estoy extrayendo los datos del jugador 0
# estoy extrayendo los datos del jugador 1
# estoy extrayendo los datos del jugador 2
# estoy extrayendo los datos del jugador 3
# estoy extrayendo los datos del jugador 4
# estoy extrayendo los datos del jugador 5
# estoy extrayendo los datos del jugador 6
# estoy extrayendo los datos del jugador 7
# estoy extrayendo los datos del jugador 8
# estoy extrayendo los datos del jugador 9
# estoy extrayendo los datos del jugador 10
# estoy extrayendo los datos del jugador 11
# estoy extrayendo los datos del jugador 12
# estoy extrayendo los datos del jugador 13
# estoy extrayendo los datos del jugador 14
# estoy extrayendo los datos del jugador 15
# estoy extrayendo los datos del jugador 16
# estoy extrayendo los datos del jugador 17
# estoy extrayendo los datos del jugador 18
# estoy extrayendo los datos del jugador 19
# estoy extrayendo los datos del jugador 20
# estoy extrayendo los datos del jugador 21
# estoy extrayendo los datos del jugador 22
# estoy extrayendo los datos del jugador 23
# estoy extrayendo los datos del jugador 24
# estoy extrayendo los datos del jugador 25
# estoy extrayendo los datos del jugador 26
# estoy extrayendo los datos del jugador 27
# estoy extrayendo los datos del jugador 0
# estoy extrayendo los datos del jugador 1
# estoy extrayendo los datos del jugador 2
# estoy extrayendo los datos del jugador 3
# estoy extrayendo los datos del jugador 4
# estoy extrayendo los datos del jugador 5
# estoy extrayendo los datos del jugador 6
# estoy extrayendo los datos del jugador 7
# estoy extrayendo los datos del jugador 8
# estoy extrayendo los datos del jugador 9
# estoy extrayendo los datos del jugador 10
# estoy extrayendo los datos del jugador 11
# estoy extrayendo los datos del jugador 12
# estoy extrayendo los datos del jugador 13
# estoy extrayendo los datos del jugador 14
# estoy extrayendo los datos del jugador 15
# estoy extrayendo los datos del jugador 16
# estoy extrayendo los datos del jugador 17
# estoy extrayendo los datos del jugador 18
# estoy extrayendo los datos del jugador 19
# estoy extrayendo los datos del jugador 20
# estoy extrayendo los datos del jugador 21
# estoy extrayendo los datos del jugador 22
# estoy extrayendo los datos del jugador 23
# estoy extrayendo los datos del jugador 24
# estoy extrayendo los datos del jugador 25
# estoy extrayendo los datos del jugador 26
# estoy extrayendo los datos del jugador 0
# estoy extrayendo los datos del jugador 1
# estoy extrayendo los datos del jugador 2
# estoy extrayendo los datos del jugador 3
# estoy extrayendo los datos del jugador 4
# estoy extrayendo los datos del jugador 5
# estoy extrayendo los datos del jugador 6
# estoy extrayendo los datos del jugador 7
# estoy extrayendo los datos del jugador 8
# estoy extrayendo los datos del jugador 9
# estoy extrayendo los datos del jugador 10
# estoy extrayendo los datos del jugador 11
# estoy extrayendo los datos del jugador 12
# estoy extrayendo los datos del jugador 13
# estoy extrayendo los datos del jugador 14
# estoy extrayendo los datos del jugador 15
# estoy extrayendo los datos del jugador 16
# estoy extrayendo los datos del jugador 17
# estoy extrayendo los datos del jugador 18
# estoy extrayendo los datos del jugador 19
# estoy extrayendo los datos del jugador 20
# estoy extrayendo los datos del jugador 21
# estoy extrayendo los datos del jugador 22
# estoy extrayendo los datos del jugador 23
# estoy extrayendo los datos del jugador 24
# estoy extrayendo los datos del jugador 25
# estoy extrayendo los datos del jugador 0
# estoy extrayendo los datos del jugador 1
# estoy extrayendo los datos del jugador 2
# estoy extrayendo los datos del jugador 3
# estoy extrayendo los datos del jugador 4
# estoy extrayendo los datos del jugador 5
# estoy extrayendo los datos del jugador 6
# estoy extrayendo los datos del jugador 7
# estoy extrayendo los datos del jugador 8
# estoy extrayendo los datos del jugador 9
# estoy extrayendo los datos del jugador 10
# estoy extrayendo los datos del jugador 11
# estoy extrayendo los datos del jugador 12
# estoy extrayendo los datos del jugador 13
# estoy extrayendo los datos del jugador 14
# estoy extrayendo los datos del jugador 15
# estoy extrayendo los datos del jugador 16
# estoy extrayendo los datos del jugador 17
# estoy extrayendo los datos del jugador 18
# estoy extrayendo los datos del jugador 19
# estoy extrayendo los datos del jugador 20
# estoy extrayendo los datos del jugador 21
# estoy extrayendo los datos del jugador 22
# estoy extrayendo los datos del jugador 23
# estoy extrayendo los datos del jugador 24
# estoy extrayendo los datos del jugador 0
# estoy extrayendo los datos del jugador 1
# estoy extrayendo los datos del jugador 2
# estoy extrayendo los datos del jugador 3
# estoy extrayendo los datos del jugador 4
# estoy extrayendo los datos del jugador 5
# estoy extrayendo los datos del jugador 6
# estoy extrayendo los datos del jugador 7
# estoy extrayendo los datos del jugador 8
# estoy extrayendo los datos del jugador 9
# estoy extrayendo los datos del jugador 10
# estoy extrayendo los datos del jugador 11
# estoy extrayendo los datos del jugador 12
# estoy extrayendo los datos del jugador 13
# estoy extrayendo los datos del jugador 14
# estoy extrayendo los datos del jugador 15
# estoy extrayendo los datos del jugador 16
# estoy extrayendo los datos del jugador 17
# estoy extrayendo los datos del jugador 18
# estoy extrayendo los datos del jugador 19
# estoy extrayendo los datos del jugador 20
# estoy extrayendo los datos del jugador 21
# estoy extrayendo los datos del jugador 22
# estoy extrayendo los datos del jugador 23
# estoy extrayendo los datos del jugador 24
# estoy extrayendo los datos del jugador 25
# estoy extrayendo los datos del jugador 0
# estoy extrayendo los datos del jugador 1
# estoy extrayendo los datos del jugador 2
# estoy extrayendo los datos del jugador 3
# estoy extrayendo los datos del jugador 4
# estoy extrayendo los datos del jugador 5
# estoy extrayendo los datos del jugador 6
# estoy extrayendo los datos del jugador 7
# estoy extrayendo los datos del jugador 8
# estoy extrayendo los datos del jugador 9
# estoy extrayendo los datos del jugador 10
# estoy extrayendo los datos del jugador 11
# estoy extrayendo los datos del jugador 12
# estoy extrayendo los datos del jugador 13
# estoy extrayendo los datos del jugador 14
# estoy extrayendo los datos del jugador 15
# estoy extrayendo los datos del jugador 16
# estoy extrayendo los datos del jugador 17
# estoy extrayendo los datos del jugador 18
# estoy extrayendo los datos del jugador 19
# estoy extrayendo los datos del jugador 20
# estoy extrayendo los datos del jugador 21
# estoy extrayendo los datos del jugador 22
# estoy extrayendo los datos del jugador 23
# estoy extrayendo los datos del jugador 24
# estoy extrayendo los datos del jugador 25
# estoy extrayendo los datos del jugador 26
# estoy extrayendo los datos del jugador 27
# estoy extrayendo los datos del jugador 0
# estoy extrayendo los datos del jugador 1
# estoy extrayendo los datos del jugador 2
# estoy extrayendo los datos del jugador 3
# estoy extrayendo los datos del jugador 4
# estoy extrayendo los datos del jugador 5
# estoy extrayendo los datos del jugador 6
# estoy extrayendo los datos del jugador 7
# estoy extrayendo los datos del jugador 8
# estoy extrayendo los datos del jugador 9
# estoy extrayendo los datos del jugador 10
# estoy extrayendo los datos del jugador 11
# estoy extrayendo los datos del jugador 12
# estoy extrayendo los datos del jugador 13
# estoy extrayendo los datos del jugador 14
# estoy extrayendo los datos del jugador 15
# estoy extrayendo los datos del jugador 16
# estoy extrayendo los datos del jugador 17
# estoy extrayendo los datos del jugador 18
# estoy extrayendo los datos del jugador 19
# estoy extrayendo los datos del jugador 20
# estoy extrayendo los datos del jugador 21
# estoy extrayendo los datos del jugador 22
# estoy extrayendo los datos del jugador 23
# estoy extrayendo los datos del jugador 24
# estoy extrayendo los datos del jugador 0
# estoy extrayendo los datos del jugador 1
# estoy extrayendo los datos del jugador 2
# estoy extrayendo los datos del jugador 3
# estoy extrayendo los datos del jugador 4
# estoy extrayendo los datos del jugador 5
# estoy extrayendo los datos del jugador 6
# estoy extrayendo los datos del jugador 7
# estoy extrayendo los datos del jugador 8
# estoy extrayendo los datos del jugador 9
# estoy extrayendo los datos del jugador 10
# estoy extrayendo los datos del jugador 11
# estoy extrayendo los datos del jugador 12
# estoy extrayendo los datos del jugador 13
# estoy extrayendo los datos del jugador 14
# estoy extrayendo los datos del jugador 15
# estoy extrayendo los datos del jugador 16
# estoy extrayendo los datos del jugador 17
# estoy extrayendo los datos del jugador 18
# estoy extrayendo los datos del jugador 19
# estoy extrayendo los datos del jugador 20
# estoy extrayendo los datos del jugador 21
# estoy extrayendo los datos del jugador 22
# estoy extrayendo los datos del jugador 0
# estoy extrayendo los datos del jugador 1
# estoy extrayendo los datos del jugador 2
# estoy extrayendo los datos del jugador 3
# estoy extrayendo los datos del jugador 4
# estoy extrayendo los datos del jugador 5
# estoy extrayendo los datos del jugador 6
# estoy extrayendo los datos del jugador 7
# estoy extrayendo los datos del jugador 8
# estoy extrayendo los datos del jugador 9
# estoy extrayendo los datos del jugador 10
# estoy extrayendo los datos del jugador 11
# estoy extrayendo los datos del jugador 12
# estoy extrayendo los datos del jugador 13
# estoy extrayendo los datos del jugador 14
# estoy extrayendo los datos del jugador 15
# estoy extrayendo los datos del jugador 16
# estoy extrayendo los datos del jugador 17
# estoy extrayendo los datos del jugador 18
# estoy extrayendo los datos del jugador 19
# estoy extrayendo los datos del jugador 20
# estoy extrayendo los datos del jugador 21
# estoy extrayendo los datos del jugador 22
# estoy extrayendo los datos del jugador 23
# estoy extrayendo los datos del jugador 24
# estoy extrayendo los datos del jugador 25
# estoy extrayendo los datos del jugador 26
# estoy extrayendo los datos del jugador 27
# estoy extrayendo los datos del jugador 28
# estoy extrayendo los datos del jugador 29
# estoy extrayendo los datos del jugador 30
# estoy extrayendo los datos del jugador 31
# estoy extrayendo los datos del jugador 32

# %%
len(lis)
# Out:
# 20

# %%
#hago una (1) lista con todos los datos
lista = []
i = 0
while i < len(lis):
    l1= lis[i]
    lista.extend(l1)
    i = i +1

# %%
len(lista)
# Out:
# 4424

# %%
lista
# Out:
# ['Manchester-City-Fc',
#  '31',
#  'Portero',
#  'Ederson',
#  '28',
#  'BR',
#  '188',
#  '89',
#  'Manchester-City-Fc',
#  '33',
#  'Portero',
#  'S. Carson',
#  '36',
#  'GB',
#  '183',
#  '85',
#  'Manchester-City-Fc',
#  '18',
#  'Portero',
#  'S. Ortega',
#  '29',
#  'DE',
#  '184',
#  '86',
#  'Manchester-City-Fc',
#  '14',
#  'Defensa',
#  'A. Laporte',
#  '28',
#  'ES',
#  '189',
#  '85',
#  'Manchester-City-Fc',
#  '',
#  'Defensa',
#  'B. Mendy',
#  '28',
#  'FR',
#  '185',
#  '83',
#  'Manchester-City-Fc',
#  '',
#  'Defensa',
#  'I. KaborÃ©',
#  '21',
#  'BF',
#  '180',
#  '70',
#  'Manchester-City-Fc',
#  '7',
#  'Defensa',
#  'J. Cancelo',
#  '28',
#  'PT',
#  '182',
#  '74',
#  'Manchester-City-Fc',
#  '5',
#  'Defensa',
#  'J. Stones',
#  '28',
#  'GB',
#  '188',
#  '70',
#  'Manchester-City-Fc',
#  '2',
#  'Defensa',
#  'K. Walker',
#  '32',
#  'GB',
#  '183',
#  '83',
#  'Manchester-City-Fc',
#  '79',
#  'Defensa',
#  'L. Mbete-Tatu',
#  '18',
#  'GB',
#  '181',
#  '68',
#  'Manchester-City-Fc',
#  '6',
#  'Defensa',
#  'N. AkÃ©',
#  '27',
#  'NL',
#  '180',
#  '75',
#  'Manchester-City-Fc',
#  '82',
#  'Defensa',
#  'Rico Lewis',
#  '17',
#  'GB',
#  '-',
#  '-',
#  'Manchester-City-Fc',
#  '3',
#  'Defensa',
#  'RÃºben Dias',
#  '25',
#  'PT',
#  '186',
#  '83',
#  'Manchester-City-Fc',
#  '',
#  'Centrocampista',
#  'A. Palaversa',
#  '22',
#  'HR',
#  '187',
#  '77',
#  'Manchester-City-Fc',
#  '20',
#  'Centrocampista',
#  'Bernardo Silva',
#  '28',
#  'PT',
#  '173',
#  '64',
#  'Manchester-City-Fc',
#  '80',
#  'Centrocampista',
#  'C. Palmer',
#  '20',
#  'GB',
#  '182',
#  '74',
#  'Manchester-City-Fc',
#  '',
#  'Centrocampista',
#  'Diego Rosa',
#  '19',
#  'BR',
#  '180',
#  '68',
#  'Manchester-City-Fc',
#  '8',
#  'Centrocampista',
#  'I. GÃ¼ndogan',
#  '31',
#  'DE',
#  '180',
#  '80',
#  'Manchester-City-Fc',
#  '17',
#  'Centrocampista',
#  'K. De Bruyne',
#  '31',
#  'BE',
#  '181',
#  '68',
#  'Manchester-City-Fc',
#  '4',
#  'Centrocampista',
#  'K. Phillips',
#  '26',
#  'GB',
#  '178',
#  '72',
#  'Manchester-City-Fc',
#  '47',
#  'Centrocampista',
#  'P. Foden',
#  '22',
#  'GB',
#  '171',
#  '70',
#  'Manchester-City-Fc',
#  '16',
#  'Centrocampista',
#  'Rodri',
#  '26',
#  'ES',
#  '191',
#  '82',
#  'Manchester-City-Fc',
#  '9',
#  'Delantero',
#  'E. Haaland',
#  '22',
#  'NO',
#  '194',
#  '88',
#  'Manchester-City-Fc',
#  '19',
#  'Delantero',
#  'J. Ã\x81lvarez',
#  '22',
#  'AR',
#  '173',
#  '68',
#  'Manchester-City-Fc',
#  '10',
#  'Delantero',
#  'J. Grealish',
#  '26',
#  'GB',
#  '179',
#  '74',
#  'Manchester-City-Fc',
#  '48',
#  'Delantero',
#  'L. Delap',
#  '19',
#  'GB',
#  '185',
#  '74',
#  'Manchester-City-Fc',
#  '',
#  'Delantero',
#  'M. Moreno',
#  '25',
#  'CO',
#  '171',
#  '67',
#  'Manchester-City-Fc',
#  '26',
#  'Delantero',
#  'R. Mahrez',
#  '31',
#  'DZ',
#  '179',
#  '61',
#  'Manchester-City-Fc',
#  '',
#  'Delantero',
#  'T. Agyepong',
#  '25',
#  'GH',
#  '183',
#  '76',
#  'Arsenal',
#  '1',
#  'Portero',
#  'A. Ramsdale',
#  '24',
#  'GB',
#  '188',
#  '73',
#  'Arsenal',
#  '30',
#  'Portero',
#  'M. Turner',
#  '28',
#  'US',
#  '191',
#  '79',
#  'Arsenal',
#  '13',
#  'Portero',
#  'R. Runarsson',
#  '27',
#  'IS',
#  '186',
#  '76',
#  'Arsenal',
#  '4',
#  'Defensa',
#  'B. White',
#  '24',
#  'GB',
#  '182',
#  '78',
#  'Arsenal',
#  '17',
#  'Defensa',
#  'CÃ©dric Soares',
#  '30',
#  'PT',
#  '172',
#  '79',
#  'Arsenal',
#  '6',
#  'Defensa',
#  'Gabriel MagalhÃ£es',
#  '24',
#  'BR',
#  '190',
#  '78',
#  'Arsenal',
#  '2',
#  'Defensa',
#  'H. BellerÃ\xadn',
#  '27',
#  'ES',
#  '177',
#  '74',
#  'Arsenal',
#  '3',
#  'Defensa',
#  'K. Tierney',
#  '25',
#  'SS',
#  '178',
#  '70',
#  'Arsenal',
#  '35',
#  'Defensa',
#  'O. Zinchenko',
#  '25',
#  'UA',
#  '175',
#  '61',
#  'Arsenal',
#  '16',
#  'Defensa',
#  'R. Holding',
#  '26',
#  'GB',
#  '182',
#  '75',
#  'Arsenal',
#  '18',
#  'Defensa',
#  'T. Tomiyasu',
#  '23',
#  'JP',
#  '188',
#  '70',
#  'Arsenal',
#  '12',
#  'Defensa',
#  'W. Saliba',
#  '21',
#  'FR',
#  '192',
#  '85',
#  'Arsenal',
#  '23',
#  'Centrocampista',
#  'A. Lokonga',
#  '22',
#  'BE',
#  '183',
#  '70',
#  'Arsenal',
#  '15',
#  'Centrocampista',
#  'A. Maitland-Niles',
#  '24',
#  'GB',
#  '177',
#  '71',
#  'Arsenal',
#  '7',
#  'Centrocampista',
#  'B. Saka',
#  '20',
#  'GB',
#  '178',
#  '65',
#  'Arsenal',
#  '21',
#  'Centrocampista',
#  'FÃ¡bio Vieira',
#  '22',
#  'PT',
#  '170',
#  '58',
#  'Arsenal',
#  '34',
#  'Centrocampista',
#  'G. Xhaka',
#  '29',
#  'CH',
#  '185',
#  '82',
#  'Arsenal',
#  '25',
#  'Centrocampista',
#  'M. Elneny',
#  '30',
#  'EG',
#  '180',
#  '70',
#  'Arsenal',
#  '8',
#  'Centrocampista',
#  'M. Ã\x98degaard',
#  '23',
#  'NO',
#  '176',
#  '68',
#  'Arsenal',
#  '19',
#  'Centrocampista',
#  'N. PÃ©pÃ©',
#  '27',
#  'CI',
#  '175',
#  '70',
#  'Arsenal',
#  '10',
#  'Centrocampista',
#  'Smith Rowe',
#  '22',
#  'GB',
#  '183',
#  '68',
#  'Arsenal',
#  '5',
#  'Centrocampista',
#  'Thomas',
#  '29',
#  'GH',
#  '185',
#  '77',
#  'Arsenal',
#  '14',
#  'Delantero',
#  'E. Nketiah',
#  '23',
#  'GB',
#  '178',
#  '70',
#  'Arsenal',
#  '9',
#  'Delantero',
#  'Gabriel Jesus',
#  '25',
#  'BR',
#  '175',
#  '67',
#  'Arsenal',
#  '27',
#  'Delantero',
#  'Marquinhos',
#  '19',
#  'BR',
#  '175',
#  '77',
#  'Arsenal',
#  '11',
#  'Delantero',
#  'Martinelli',
#  '21',
#  'BR',
#  '180',
#  '75',
#  'Arsenal',
#  '24',
#  'Delantero',
#  'R. Nelson',
#  '22',
#  'GB',
#  '175',
#  '71',
#  'Brentford',
#  '1',
#  'Portero',
#  'D. Raya',
#  '26',
#  'ES',
#  '183',
#  '80',
#  'Brentford',
#  '22',
#  'Portero',
#  'T. Strakosha',
#  '27',
#  'AL',
#  '192',
#  '80',
#  'Brentford',
#  '2',
#  'Defensa',
#  'A. Hickey',
#  '20',
#  'SS',
#  '175',
#  '72',
#  'Brentford',
#  '16',
#  'Defensa',
#  'B. Mee',
#  '32',
#  'GB',
#  '180',
#  '74',
#  'Brentford',
#  '4',
#  'Defensa',
#  'Charlie Goode',
#  '27',
#  'GB',
#  '196',
#  '75',
#  'Brentford',
#  '5',
#  'Defensa',
#  'E. Pinnock',
#  '29',
#  'JM',
#  '187',
#  '75',
#  'Brentford',
#  '33',
#  'Defensa',
#  'F. Stevens',
#  '19',
#  'WA',
#  '173',
#  '73',
#  'Brentford',
#  '20',
#  'Defensa',
#  'K. Ajer',
#  '24',
#  'NO',
#  '196',
#  '84',
#  'Brentford',
#  '32',
#  'Defensa',
#  'L. Racic',
#  '23',
#  'DK',
#  '180',
#  '78',
#  'Brentford',
#  '29',
#  'Defensa',
#  'M. Bech',
#  '23',
#  'DK',
#  '185',
#  '73',
#  'Brentford',
#  '30',
#  'Defensa',
#  'M. Roerslev',
#  '23',
#  'DK',
#  '180',
#  '80',
#  'Brentford',
#  '18',
#  'Defensa',
#  'P. Jansson',
#  '31',
#  'SE',
#  '194',
#  '89',
#  'Brentford',
#  '3',
#  'Defensa',
#  'R. Henry',
#  '25',
#  'GB',
#  '170',
#  '66',
#  'Brentford',
#  '6',
#  'Centrocampista',
#  'C. NÃ¸rgaard',
#  '28',
#  'DK',
#  '185',
#  '70',
#  'Brentford',
#  '10',
#  'Centrocampista',
#  'Josh Dasilva',
#  '23',
#  'GB',
#  '180',
#  '75',
#  'Brentford',
#  '8',
#  'Centrocampista',
#  'M. Jensen',
#  '26',
#  'DK',
#  '180',
#  '68',
#  'Brentford',
#  '15',
#  'Centrocampista',
#  'O. Onyeka',
#  '24',
#  'NG',
#  '183',
#  '70',
#  'Brentford',
#  '26',
#  'Centrocampista',
#  'S. Baptiste',
#  '24',
#  'GD',
#  '180',
#  '67',
#  'Brentford',
#  '14',
#  'Centrocampista',
#  'S. Ghoddos',
#  '28',
#  'IR',
#  '176',
#  '75',
#  'Brentford',
#  '27',
#  'Centrocampista',
#  'V. Janelt',
#  '24',
#  'DE',
#  '184',
#  '79',
#  'Brentford',
#  '19',
#  'Delantero',
#  'B. Mbeumo',
#  '23',
#  'FR',
#  '171',
#  '65',
#  'Brentford',
#  '21',
#  'Delantero',
#  'I. Dervisoglu',
#  '22',
#  'TR',
#  '183',
#  '76',
#  'Brentford',
#  '17',
#  'Delantero',
#  'I. Toney',
#  '26',
#  'GB',
#  '185',
#  '65',
#  'Brentford',
#  '16',
#  'Delantero',
#  'J. Valencia',
#  '27',
#  'EC',
#  '175',
#  '70',
#  'Brentford',
#  '23',
#  'Delantero',
#  'K. Lewis-Potter',
#  '21',
#  'GB',
#  '170',
#  '67',
#  'Brentford',
#  '24',
#  'Delantero',
#  'M. Damsgaard',
#  '22',
#  'DK',
#  '180',
#  '71',
#  'Brentford',
#  '7',
#  'Delantero',
#  'S. CanÃ³s',
#  '25',
#  'ES',
#  '173',
#  '75',
#  'Brentford',
#  '24',
#  'Delantero',
#  'T. Fosu',
#  '26',
#  'GH',
#  '170',
#  '67',
#  'Brentford',
#  '11',
#  'Delantero',
#  'Y. Wissa',
#  '25',
#  'CD',
#  '176',
#  '74',
#  'Tottenham-Hotspur-Fc',
#  '40',
#  'Portero',
#  'B. Austin',
#  '23',
#  'GB',
#  '188',
#  '82',
#  'Tottenham-Hotspur-Fc',
#  '20',
#  'Portero',
#  'F. Forster',
#  '34',
#  'GB',
#  '201',
#  '93',
#  'Tottenham-Hotspur-Fc',
#  '1',
#  'Portero',
#  'H. Lloris',
#  '35',
#  'FR',
#  '188',
#  '73',
#  'Tottenham-Hotspur-Fc',
#  '33',
#  'Defensa',
#  'B. Davies',
#  '29',
#  'WA',
#  '181',
#  '76',
#  'Tottenham-Hotspur-Fc',
#  '34',
#  'Defensa',
#  'C. Lenglet',
#  '27',
#  'FR',
#  '186',
#  '81',
#  'Tottenham-Hotspur-Fc',
#  '17',
#  'Defensa',
#  'C. Romero',
#  '24',
#  'AR',
#  '185',
#  '79',
#  'Tottenham-Hotspur-Fc',
#  '6',
#  'Defensa',
#  'D. SÃ¡nchez',
#  '26',
#  'CO',
#  '187',
#  '81',
#  'Tottenham-Hotspur-Fc',
#  '24',
#  'Defensa',
#  'D. Spence',
#  '22',
#  'GB',
#  '184',
#  '71',
#  'Tottenham-Hotspur-Fc',
#  '15',
#  'Defensa',
#  'E. Dier',
#  '28',
#  'GB',
#  '188',
#  '90',
#  'Tottenham-Hotspur-Fc',
#  '12',
#  'Defensa',
#  'Emerson Royal',
#  '23',
#  'BR',
#  '183',
#  '73',
#  'Tottenham-Hotspur-Fc',
#  '25',
#  'Defensa',
#  'J. Tanganga',
#  '23',
#  'GB',
#  '184',
#  '76',
#  'Tottenham-Hotspur-Fc',
#  '2',
#  'Defensa',
#  'Matt Doherty',
#  '30',
#  'IE',
#  '182',
#  '80',
#  'Tottenham-Hotspur-Fc',
#  '3',
#  'Defensa',
#  'ReguilÃ³n',
#  '25',
#  'ES',
#  '178',
#  '67',
#  'Tottenham-Hotspur-Fc',
#  '8',
#  'Centrocampista',
#  'H. Winks',
#  '26',
#  'GB',
#  '178',
#  '74',
#  'Tottenham-Hotspur-Fc',
#  '14',
#  'Centrocampista',
#  'I. PeriÅ¡iÄ\x87',
#  '33',
#  'HR',
#  '186',
#  '79',
#  'Tottenham-Hotspur-Fc',
#  '4',
#  'Centrocampista',
#  'O. Skipp',
#  '21',
#  'GB',
#  '175',
#  '70',
#  'Tottenham-Hotspur-Fc',
#  '5',
#  'Centrocampista',
#  'P. HÃ¸jbjerg',
#  '27',
#  'DK',
#  '187',
#  '84',
#  'Tottenham-Hotspur-Fc',
#  '29',
#  'Centrocampista',
#  'Pape Sarr',
#  '19',
#  'SN',
#  '185',
#  '70',
#  'Tottenham-Hotspur-Fc',
#  '30',
#  'Centrocampista',
#  'R. Bentancur',
#  '25',
#  'UY',
#  '187',
#  '73',
#  'Tottenham-Hotspur-Fc',
#  '19',
#  'Centrocampista',
#  'R. Sessegnon',
#  '22',
#  'GB',
#  '178',
#  '71',
#  'Tottenham-Hotspur-Fc',
#  '28',
#  'Centrocampista',
#  'T. Ndombele',
#  '25',
#  'FR',
#  '181',
#  '76',
#  'Tottenham-Hotspur-Fc',
#  '38',
#  'Centrocampista',
#  'Y. Bissouma',
#  '25',
#  'ML',
#  '182',
#  '80',
#  'Tottenham-Hotspur-Fc',
#  '11',
#  'Delantero',
#  'Bryan Gil',
#  '21',
#  'ES',
#  '176',
#  '60',
#  'Tottenham-Hotspur-Fc',
#  '21',
#  'Delantero',
#  'D. Kulusevski',
#  '22',
#  'SE',
#  '186',
#  '75',
#  'Tottenham-Hotspur-Fc',
#  '10',
#  'Delantero',
#  'H. Kane',
#  '29',
#  'GB',
#  '188',
#  '86',
#  'Tottenham-Hotspur-Fc',
#  '27',
#  'Delantero',
#  'Lucas Moura',
#  '30',
#  'BR',
#  '172',
#  '66',
#  'Tottenham-Hotspur-Fc',
#  '9',
#  'Delantero',
#  'Richarlison',
#  '25',
#  'BR',
#  '179',
#  '71',
#  'Tottenham-Hotspur-Fc',
#  '7',
#  'Delantero',
#  'Son Heung-Min',
#  '30',
#  'KR',
#  '183',
#  '76',
#  'Newcastle-United-Fc',
#  '26',
#  'Portero',
#  'K. Darlow',
#  '31',
#  'GB',
#  '185',
#  '78',
#  'Newcastle-United-Fc',
#  '1',
#  'Portero',
#  'M. DÃºbravka',
#  '33',
#  'SK',
#  '190',
#  '83',
#  'Newcastle-United-Fc',
#  '29',
#  'Portero',
#  'M. Gillespie',
#  '30',
#  'GB',
#  '188',
#  '83',
#  'Newcastle-United-Fc',
#  '22',
#  'Portero',
#  'Nick Pope',
#  '30',
#  'GB',
#  '191',
#  '76',
#  'Newcastle-United-Fc',
#  '33',
#  'Defensa',
#  'D. Burn',
#  '30',
#  'GB',
#  '198',
#  '87',
#  'Newcastle-United-Fc',
#  '17',
#  'Defensa',
#  'E. Krafth',
#  '28',
#  'SE',
#  '184',
#  '83',
#  'Newcastle-United-Fc',
#  '18',
#  'Defensa',
#  'F. FernÃ¡ndez',
#  '33',
#  'AR',
#  '189',
#  '81',
#  'Newcastle-United-Fc',
#  '5',
#  'Defensa',
#  'F. SchÃ¤r',
#  '30',
#  'CH',
#  '186',
#  '84',
#  'Newcastle-United-Fc',
#  '6',
#  'Defensa',
#  'J. Lascelles',
#  '28',
#  'GB',
#  '189',
#  '70',
#  'Newcastle-United-Fc',
#  '12',
#  'Defensa',
#  'J. Lewis',
#  '24',
#  'I1',
#  '178',
#  '70',
#  'Newcastle-United-Fc',
#  '19',
#  'Defensa',
#  'J. Manquillo',
#  '28',
#  'ES',
#  '180',
#  '76',
#  'Newcastle-United-Fc',
#  '2',
#  'Defensa',
#  'K. Trippier',
#  '31',
#  'GB',
#  '178',
#  '71',
#  ...]

# %%
# separo la lista en sublistas por jugador
n=8

plantilla_final =[lista[i:i + n] for i in range(0, len(lista), n)]
plantilla_final
# Out:
# [['Manchester-City-Fc', '31', 'Portero', 'Ederson', '28', 'BR', '188', '89'],
#  ['Manchester-City-Fc', '33', 'Portero', 'S. Carson', '36', 'GB', '183', '85'],
#  ['Manchester-City-Fc', '18', 'Portero', 'S. Ortega', '29', 'DE', '184', '86'],
#  ['Manchester-City-Fc',
#   '14',
#   'Defensa',
#   'A. Laporte',
#   '28',
#   'ES',
#   '189',
#   '85'],
#  ['Manchester-City-Fc', '', 'Defensa', 'B. Mendy', '28', 'FR', '185', '83'],
#  ['Manchester-City-Fc', '', 'Defensa', 'I. KaborÃ©', '21', 'BF', '180', '70'],
#  ['Manchester-City-Fc', '7', 'Defensa', 'J. Cancelo', '28', 'PT', '182', '74'],
#  ['Manchester-City-Fc', '5', 'Defensa', 'J. Stones', '28', 'GB', '188', '70'],
#  ['Manchester-City-Fc', '2', 'Defensa', 'K. Walker', '32', 'GB', '183', '83'],
#  ['Manchester-City-Fc',
#   '79',
#   'Defensa',
#   'L. Mbete-Tatu',
#   '18',
#   'GB',
#   '181',
#   '68'],
#  ['Manchester-City-Fc', '6', 'Defensa', 'N. AkÃ©', '27', 'NL', '180', '75'],
#  ['Manchester-City-Fc', '82', 'Defensa', 'Rico Lewis', '17', 'GB', '-', '-'],
#  ['Manchester-City-Fc',
#   '3',
#   'Defensa',
#   'RÃºben Dias',
#   '25',
#   'PT',
#   '186',
#   '83'],
#  ['Manchester-City-Fc',
#   '',
#   'Centrocampista',
#   'A. Palaversa',
#   '22',
#   'HR',
#   '187',
#   '77'],
#  ['Manchester-City-Fc',
#   '20',
#   'Centrocampista',
#   'Bernardo Silva',
#   '28',
#   'PT',
#   '173',
#   '64'],
#  ['Manchester-City-Fc',
#   '80',
#   'Centrocampista',
#   'C. Palmer',
#   '20',
#   'GB',
#   '182',
#   '74'],
#  ['Manchester-City-Fc',
#   '',
#   'Centrocampista',
#   'Diego Rosa',
#   '19',
#   'BR',
#   '180',
#   '68'],
#  ['Manchester-City-Fc',
#   '8',
#   'Centrocampista',
#   'I. GÃ¼ndogan',
#   '31',
#   'DE',
#   '180',
#   '80'],
#  ['Manchester-City-Fc',
#   '17',
#   'Centrocampista',
#   'K. De Bruyne',
#   '31',
#   'BE',
#   '181',
#   '68'],
#  ['Manchester-City-Fc',
#   '4',
#   'Centrocampista',
#   'K. Phillips',
#   '26',
#   'GB',
#   '178',
#   '72'],
#  ['Manchester-City-Fc',
#   '47',
#   'Centrocampista',
#   'P. Foden',
#   '22',
#   'GB',
#   '171',
#   '70'],
#  ['Manchester-City-Fc',
#   '16',
#   'Centrocampista',
#   'Rodri',
#   '26',
#   'ES',
#   '191',
#   '82'],
#  ['Manchester-City-Fc',
#   '9',
#   'Delantero',
#   'E. Haaland',
#   '22',
#   'NO',
#   '194',
#   '88'],
#  ['Manchester-City-Fc',
#   '19',
#   'Delantero',
#   'J. Ã\x81lvarez',
#   '22',
#   'AR',
#   '173',
#   '68'],
#  ['Manchester-City-Fc',
#   '10',
#   'Delantero',
#   'J. Grealish',
#   '26',
#   'GB',
#   '179',
#   '74'],
#  ['Manchester-City-Fc',
#   '48',
#   'Delantero',
#   'L. Delap',
#   '19',
#   'GB',
#   '185',
#   '74'],
#  ['Manchester-City-Fc', '', 'Delantero', 'M. Moreno', '25', 'CO', '171', '67'],
#  ['Manchester-City-Fc',
#   '26',
#   'Delantero',
#   'R. Mahrez',
#   '31',
#   'DZ',
#   '179',
#   '61'],
#  ['Manchester-City-Fc',
#   '',
#   'Delantero',
#   'T. Agyepong',
#   '25',
#   'GH',
#   '183',
#   '76'],
#  ['Arsenal', '1', 'Portero', 'A. Ramsdale', '24', 'GB', '188', '73'],
#  ['Arsenal', '30', 'Portero', 'M. Turner', '28', 'US', '191', '79'],
#  ['Arsenal', '13', 'Portero', 'R. Runarsson', '27', 'IS', '186', '76'],
#  ['Arsenal', '4', 'Defensa', 'B. White', '24', 'GB', '182', '78'],
#  ['Arsenal', '17', 'Defensa', 'CÃ©dric Soares', '30', 'PT', '172', '79'],
#  ['Arsenal', '6', 'Defensa', 'Gabriel MagalhÃ£es', '24', 'BR', '190', '78'],
#  ['Arsenal', '2', 'Defensa', 'H. BellerÃ\xadn', '27', 'ES', '177', '74'],
#  ['Arsenal', '3', 'Defensa', 'K. Tierney', '25', 'SS', '178', '70'],
#  ['Arsenal', '35', 'Defensa', 'O. Zinchenko', '25', 'UA', '175', '61'],
#  ['Arsenal', '16', 'Defensa', 'R. Holding', '26', 'GB', '182', '75'],
#  ['Arsenal', '18', 'Defensa', 'T. Tomiyasu', '23', 'JP', '188', '70'],
#  ['Arsenal', '12', 'Defensa', 'W. Saliba', '21', 'FR', '192', '85'],
#  ['Arsenal', '23', 'Centrocampista', 'A. Lokonga', '22', 'BE', '183', '70'],
#  ['Arsenal',
#   '15',
#   'Centrocampista',
#   'A. Maitland-Niles',
#   '24',
#   'GB',
#   '177',
#   '71'],
#  ['Arsenal', '7', 'Centrocampista', 'B. Saka', '20', 'GB', '178', '65'],
#  ['Arsenal', '21', 'Centrocampista', 'FÃ¡bio Vieira', '22', 'PT', '170', '58'],
#  ['Arsenal', '34', 'Centrocampista', 'G. Xhaka', '29', 'CH', '185', '82'],
#  ['Arsenal', '25', 'Centrocampista', 'M. Elneny', '30', 'EG', '180', '70'],
#  ['Arsenal',
#   '8',
#   'Centrocampista',
#   'M. Ã\x98degaard',
#   '23',
#   'NO',
#   '176',
#   '68'],
#  ['Arsenal', '19', 'Centrocampista', 'N. PÃ©pÃ©', '27', 'CI', '175', '70'],
#  ['Arsenal', '10', 'Centrocampista', 'Smith Rowe', '22', 'GB', '183', '68'],
#  ['Arsenal', '5', 'Centrocampista', 'Thomas', '29', 'GH', '185', '77'],
#  ['Arsenal', '14', 'Delantero', 'E. Nketiah', '23', 'GB', '178', '70'],
#  ['Arsenal', '9', 'Delantero', 'Gabriel Jesus', '25', 'BR', '175', '67'],
#  ['Arsenal', '27', 'Delantero', 'Marquinhos', '19', 'BR', '175', '77'],
#  ['Arsenal', '11', 'Delantero', 'Martinelli', '21', 'BR', '180', '75'],
#  ['Arsenal', '24', 'Delantero', 'R. Nelson', '22', 'GB', '175', '71'],
#  ['Brentford', '1', 'Portero', 'D. Raya', '26', 'ES', '183', '80'],
#  ['Brentford', '22', 'Portero', 'T. Strakosha', '27', 'AL', '192', '80'],
#  ['Brentford', '2', 'Defensa', 'A. Hickey', '20', 'SS', '175', '72'],
#  ['Brentford', '16', 'Defensa', 'B. Mee', '32', 'GB', '180', '74'],
#  ['Brentford', '4', 'Defensa', 'Charlie Goode', '27', 'GB', '196', '75'],
#  ['Brentford', '5', 'Defensa', 'E. Pinnock', '29', 'JM', '187', '75'],
#  ['Brentford', '33', 'Defensa', 'F. Stevens', '19', 'WA', '173', '73'],
#  ['Brentford', '20', 'Defensa', 'K. Ajer', '24', 'NO', '196', '84'],
#  ['Brentford', '32', 'Defensa', 'L. Racic', '23', 'DK', '180', '78'],
#  ['Brentford', '29', 'Defensa', 'M. Bech', '23', 'DK', '185', '73'],
#  ['Brentford', '30', 'Defensa', 'M. Roerslev', '23', 'DK', '180', '80'],
#  ['Brentford', '18', 'Defensa', 'P. Jansson', '31', 'SE', '194', '89'],
#  ['Brentford', '3', 'Defensa', 'R. Henry', '25', 'GB', '170', '66'],
#  ['Brentford', '6', 'Centrocampista', 'C. NÃ¸rgaard', '28', 'DK', '185', '70'],
#  ['Brentford',
#   '10',
#   'Centrocampista',
#   'Josh Dasilva',
#   '23',
#   'GB',
#   '180',
#   '75'],
#  ['Brentford', '8', 'Centrocampista', 'M. Jensen', '26', 'DK', '180', '68'],
#  ['Brentford', '15', 'Centrocampista', 'O. Onyeka', '24', 'NG', '183', '70'],
#  ['Brentford', '26', 'Centrocampista', 'S. Baptiste', '24', 'GD', '180', '67'],
#  ['Brentford', '14', 'Centrocampista', 'S. Ghoddos', '28', 'IR', '176', '75'],
#  ['Brentford', '27', 'Centrocampista', 'V. Janelt', '24', 'DE', '184', '79'],
#  ['Brentford', '19', 'Delantero', 'B. Mbeumo', '23', 'FR', '171', '65'],
#  ['Brentford', '21', 'Delantero', 'I. Dervisoglu', '22', 'TR', '183', '76'],
#  ['Brentford', '17', 'Delantero', 'I. Toney', '26', 'GB', '185', '65'],
#  ['Brentford', '16', 'Delantero', 'J. Valencia', '27', 'EC', '175', '70'],
#  ['Brentford', '23', 'Delantero', 'K. Lewis-Potter', '21', 'GB', '170', '67'],
#  ['Brentford', '24', 'Delantero', 'M. Damsgaard', '22', 'DK', '180', '71'],
#  ['Brentford', '7', 'Delantero', 'S. CanÃ³s', '25', 'ES', '173', '75'],
#  ['Brentford', '24', 'Delantero', 'T. Fosu', '26', 'GH', '170', '67'],
#  ['Brentford', '11', 'Delantero', 'Y. Wissa', '25', 'CD', '176', '74'],
#  ['Tottenham-Hotspur-Fc',
#   '40',
#   'Portero',
#   'B. Austin',
#   '23',
#   'GB',
#   '188',
#   '82'],
#  ['Tottenham-Hotspur-Fc',
#   '20',
#   'Portero',
#   'F. Forster',
#   '34',
#   'GB',
#   '201',
#   '93'],
#  ['Tottenham-Hotspur-Fc',
#   '1',
#   'Portero',
#   'H. Lloris',
#   '35',
#   'FR',
#   '188',
#   '73'],
#  ['Tottenham-Hotspur-Fc',
#   '33',
#   'Defensa',
#   'B. Davies',
#   '29',
#   'WA',
#   '181',
#   '76'],
#  ['Tottenham-Hotspur-Fc',
#   '34',
#   'Defensa',
#   'C. Lenglet',
#   '27',
#   'FR',
#   '186',
#   '81'],
#  ['Tottenham-Hotspur-Fc',
#   '17',
#   'Defensa',
#   'C. Romero',
#   '24',
#   'AR',
#   '185',
#   '79'],
#  ['Tottenham-Hotspur-Fc',
#   '6',
#   'Defensa',
#   'D. SÃ¡nchez',
#   '26',
#   'CO',
#   '187',
#   '81'],
#  ['Tottenham-Hotspur-Fc',
#   '24',
#   'Defensa',
#   'D. Spence',
#   '22',
#   'GB',
#   '184',
#   '71'],
#  ['Tottenham-Hotspur-Fc', '15', 'Defensa', 'E. Dier', '28', 'GB', '188', '90'],
#  ['Tottenham-Hotspur-Fc',
#   '12',
#   'Defensa',
#   'Emerson Royal',
#   '23',
#   'BR',
#   '183',
#   '73'],
#  ['Tottenham-Hotspur-Fc',
#   '25',
#   'Defensa',
#   'J. Tanganga',
#   '23',
#   'GB',
#   '184',
#   '76'],
#  ['Tottenham-Hotspur-Fc',
#   '2',
#   'Defensa',
#   'Matt Doherty',
#   '30',
#   'IE',
#   '182',
#   '80'],
#  ['Tottenham-Hotspur-Fc',
#   '3',
#   'Defensa',
#   'ReguilÃ³n',
#   '25',
#   'ES',
#   '178',
#   '67'],
#  ['Tottenham-Hotspur-Fc',
#   '8',
#   'Centrocampista',
#   'H. Winks',
#   '26',
#   'GB',
#   '178',
#   '74'],
#  ['Tottenham-Hotspur-Fc',
#   '14',
#   'Centrocampista',
#   'I. PeriÅ¡iÄ\x87',
#   '33',
#   'HR',
#   '186',
#   '79'],
#  ['Tottenham-Hotspur-Fc',
#   '4',
#   'Centrocampista',
#   'O. Skipp',
#   '21',
#   'GB',
#   '175',
#   '70'],
#  ['Tottenham-Hotspur-Fc',
#   '5',
#   'Centrocampista',
#   'P. HÃ¸jbjerg',
#   '27',
#   'DK',
#   '187',
#   '84'],
#  ['Tottenham-Hotspur-Fc',
#   '29',
#   'Centrocampista',
#   'Pape Sarr',
#   '19',
#   'SN',
#   '185',
#   '70'],
#  ['Tottenham-Hotspur-Fc',
#   '30',
#   'Centrocampista',
#   'R. Bentancur',
#   '25',
#   'UY',
#   '187',
#   '73'],
#  ['Tottenham-Hotspur-Fc',
#   '19',
#   'Centrocampista',
#   'R. Sessegnon',
#   '22',
#   'GB',
#   '178',
#   '71'],
#  ['Tottenham-Hotspur-Fc',
#   '28',
#   'Centrocampista',
#   'T. Ndombele',
#   '25',
#   'FR',
#   '181',
#   '76'],
#  ['Tottenham-Hotspur-Fc',
#   '38',
#   'Centrocampista',
#   'Y. Bissouma',
#   '25',
#   'ML',
#   '182',
#   '80'],
#  ['Tottenham-Hotspur-Fc',
#   '11',
#   'Delantero',
#   'Bryan Gil',
#   '21',
#   'ES',
#   '176',
#   '60'],
#  ['Tottenham-Hotspur-Fc',
#   '21',
#   'Delantero',
#   'D. Kulusevski',
#   '22',
#   'SE',
#   '186',
#   '75'],
#  ['Tottenham-Hotspur-Fc',
#   '10',
#   'Delantero',
#   'H. Kane',
#   '29',
#   'GB',
#   '188',
#   '86'],
#  ['Tottenham-Hotspur-Fc',
#   '27',
#   'Delantero',
#   'Lucas Moura',
#   '30',
#   'BR',
#   '172',
#   '66'],
#  ['Tottenham-Hotspur-Fc',
#   '9',
#   'Delantero',
#   'Richarlison',
#   '25',
#   'BR',
#   '179',
#   '71'],
#  ['Tottenham-Hotspur-Fc',
#   '7',
#   'Delantero',
#   'Son Heung-Min',
#   '30',
#   'KR',
#   '183',
#   '76'],
#  ['Newcastle-United-Fc',
#   '26',
#   'Portero',
#   'K. Darlow',
#   '31',
#   'GB',
#   '185',
#   '78'],
#  ['Newcastle-United-Fc',
#   '1',
#   'Portero',
#   'M. DÃºbravka',
#   '33',
#   'SK',
#   '190',
#   '83'],
#  ['Newcastle-United-Fc',
#   '29',
#   'Portero',
#   'M. Gillespie',
#   '30',
#   'GB',
#   '188',
#   '83'],
#  ['Newcastle-United-Fc',
#   '22',
#   'Portero',
#   'Nick Pope',
#   '30',
#   'GB',
#   '191',
#   '76'],
#  ['Newcastle-United-Fc', '33', 'Defensa', 'D. Burn', '30', 'GB', '198', '87'],
#  ['Newcastle-United-Fc',
#   '17',
#   'Defensa',
#   'E. Krafth',
#   '28',
#   'SE',
#   '184',
#   '83'],
#  ['Newcastle-United-Fc',
#   '18',
#   'Defensa',
#   'F. FernÃ¡ndez',
#   '33',
#   'AR',
#   '189',
#   '81'],
#  ['Newcastle-United-Fc', '5', 'Defensa', 'F. SchÃ¤r', '30', 'CH', '186', '84'],
#  ['Newcastle-United-Fc',
#   '6',
#   'Defensa',
#   'J. Lascelles',
#   '28',
#   'GB',
#   '189',
#   '70'],
#  ['Newcastle-United-Fc', '12', 'Defensa', 'J. Lewis', '24', 'I1', '178', '70'],
#  ['Newcastle-United-Fc',
#   '19',
#   'Defensa',
#   'J. Manquillo',
#   '28',
#   'ES',
#   '180',
#   '76'],
#  ['Newcastle-United-Fc',
#   '2',
#   'Defensa',
#   'K. Trippier',
#   '31',
#   'GB',
#   '178',
#   '71'],
#  ['Newcastle-United-Fc',
#   '31',
#   'Defensa',
#   'Kell Watts',
#   '22',
#   'GB',
#   '193',
#   '75'],
#  ['Newcastle-United-Fc',
#   '11',
#   'Defensa',
#   'M. Ritchie',
#   '32',
#   'SS',
#   '173',
#   '71'],
#  ['Newcastle-United-Fc',
#   '13',
#   'Defensa',
#   'Matt Targett',
#   '26',
#   'GB',
#   '183',
#   '70'],
#  ['Newcastle-United-Fc',
#   '3',
#   'Defensa',
#   'P. Dummett',
#   '30',
#   'WA',
#   '178',
#   '65'],
#  ['Newcastle-United-Fc', '4', 'Defensa', 'S. Botman', '22', 'NL', '193', '85'],
#  ['Newcastle-United-Fc',
#   '39',
#   'Centrocampista',
#   'B. GuimarÃ£es',
#   '24',
#   'BR',
#   '182',
#   '74'],
#  ['Newcastle-United-Fc',
#   '32',
#   'Centrocampista',
#   'E. Anderson',
#   '19',
#   'SS',
#   '179',
#   '63'],
#  ['Newcastle-United-Fc',
#   '8',
#   'Centrocampista',
#   'J. Shelvey',
#   '30',
#   'GB',
#   '183',
#   '70'],
#  ['Newcastle-United-Fc',
#   '28',
#   'Centrocampista',
#   'J. Willock',
#   '22',
#   'GB',
#   '179',
#   '71'],
#  ['Newcastle-United-Fc',
#   '7',
#   'Centrocampista',
#   'Joelinton',
#   '25',
#   'BR',
#   '186',
#   '76'],
#  ['Newcastle-United-Fc',
#   '24',
#   'Centrocampista',
#   'M. Almiron',
#   '28',
#   'PY',
#   '174',
#   '63'],
#  ['Newcastle-United-Fc',
#   '27',
#   'Centrocampista',
#   'M. Longstaff',
#   '22',
#   'GB',
#   '171',
#   '66'],
#  ['Newcastle-United-Fc',
#   '36',
#   'Centrocampista',
#   'S. Longstaff',
#   '24',
#   'GB',
#   '180',
#   '65'],
#  ['Newcastle-United-Fc',
#   '10',
#   'Delantero',
#   'A. Saint-Maximin',
#   '25',
#   'FR',
#   '173',
#   '67'],
#  ['Newcastle-United-Fc',
#   '9',
#   'Delantero',
#   'C. Wilson',
#   '30',
#   'GB',
#   '180',
#   '76'],
#  ['Newcastle-United-Fc',
#   '20',
#   'Delantero',
#   'Chris Wood',
#   '30',
#   'NZ',
#   '191',
#   '80'],
#  ['Newcastle-United-Fc',
#   '23',
#   'Delantero',
#   'J. Murphy',
#   '27',
#   'GB',
#   '176',
#   '71'],
#  ['Newcastle-United-Fc',
#   '21',
#   'Delantero',
#   'R. Fraser',
#   '28',
#   'SS',
#   '163',
#   '60'],
#  ['Leeds-United-Afc', '1', 'Portero', 'I. Meslier', '22', 'FR', '195', '75'],
#  ['Leeds-United-Afc', '', 'Portero', 'Joel Robles', '32', 'ES', '197', '95'],
#  ['Leeds-United-Afc', '13', 'Portero', 'K. Klaesson', '21', 'NO', '189', '76'],
#  ['Leeds-United-Afc', '37', 'Defensa', 'C. Drameh', '20', 'GB', '175', '69'],
#  ['Leeds-United-Afc', '14', 'Defensa', 'D. Llorente', '28', 'ES', '186', '75'],
#  ['Leeds-United-Afc', '3', 'Defensa', 'Junior Firpo', '25', 'DO', '184', '78'],
#  ['Leeds-United-Afc', '2', 'Defensa', 'L. Ayling', '30', 'GB', '183', '72'],
#  ['Leeds-United-Afc', '6', 'Defensa', 'L. Cooper', '30', 'SS', '180', '73'],
#  ['Leeds-United-Afc', '33', 'Defensa', 'Leo Hjelde', '18', 'NO', '188', '74'],
#  ['Leeds-United-Afc', '21', 'Defensa', 'P. Struijk', '23', 'NL', '190', '75'],
#  ['Leeds-United-Afc', '5', 'Defensa', 'R. Koch', '26', 'DE', '190', '84'],
#  ['Leeds-United-Afc',
#   '25',
#   'Defensa',
#   'R. Kristensen',
#   '25',
#   'DK',
#   '176',
#   '70'],
#  ['Leeds-United-Afc', '15', 'Defensa', 'S. Dallas', '31', 'I1', '183', '81'],
#  ['Leeds-United-Afc',
#   '4',
#   'Centrocampista',
#   'A. Forshaw',
#   '30',
#   'GB',
#   '185',
#   '70'],
#  ['Leeds-United-Afc',
#   '7',
#   'Centrocampista',
#   'B. Aaronson',
#   '21',
#   'US',
#   '178',
#   '66'],
#  ['Leeds-United-Afc',
#   '18',
#   'Centrocampista',
#   'D. Gyabi',
#   '18',
#   'GB',
#   '-',
#   '-'],
#  ['Leeds-United-Afc',
#   '44',
#   'Centrocampista',
#   'M. Bogusz',
#   '20',
#   'PL',
#   '177',
#   '68'],
#  ['Leeds-United-Afc',
#   '43',
#   'Centrocampista',
#   'M. Klich',
#   '32',
#   'PL',
#   '183',
#   '68'],
#  ['Leeds-United-Afc',
#   '8',
#   'Centrocampista',
#   'Marc Roca',
#   '25',
#   'ES',
#   '186',
#   '74'],
#  ['Leeds-United-Afc',
#   '12',
#   'Centrocampista',
#   'T. Adams',
#   '23',
#   'US',
#   '175',
#   '68'],
#  ['Leeds-United-Afc',
#   '10',
#   'Delantero',
#   'C. Summerville',
#   '20',
#   'NL',
#   '174',
#   '66'],
#  ['Leeds-United-Afc', '20', 'Delantero', 'D. James', '24', 'WA', '171', '76'],
#  ['Leeds-United-Afc', '', 'Delantero', 'Ian Poveda', '22', 'GB', '167', '64'],
#  ['Leeds-United-Afc',
#   '11',
#   'Delantero',
#   'J. Harrison',
#   '25',
#   'GB',
#   '175',
#   '70'],
#  ['Leeds-United-Afc',
#   '30',
#   'Delantero',
#   'Joe Gelhardt',
#   '20',
#   'GB',
#   '179',
#   '67'],
#  ['Leeds-United-Afc',
#   '23',
#   'Delantero',
#   'L. Sinisterra',
#   '23',
#   'CO',
#   '172',
#   '60'],
#  ['Leeds-United-Afc', '9', 'Delantero', 'P. Bamford', '28', 'GB', '185', '71'],
#  ['Leeds-United-Afc', '19', 'Delantero', 'Rodrigo', '31', 'ES', '182', '77'],
#  ['Leeds-United-Afc',
#   '42',
#   'Delantero',
#   'S. Greenwood',
#   '20',
#   'GB',
#   '185',
#   '76'],
#  ['Chelsea-Fc', '16', 'Portero', 'E. Mendy', '30', 'SN', '197', '86'],
#  ['Chelsea-Fc', '1', 'Portero', 'Kepa', '27', 'ES', '189', '81'],
#  ['Chelsea-Fc', '13', 'Portero', 'M. Bettinelli', '30', 'GB', '194', '82'],
#  ['Chelsea-Fc', '', 'Defensa', 'A. Baba', '28', 'GH', '179', '70'],
#  ['Chelsea-Fc', '21', 'Defensa', 'B. Chilwell', '25', 'GB', '178', '76'],
#  ['Chelsea-Fc', '28', 'Defensa', 'C. Azpilicueta', '32', 'ES', '178', '75'],
#  ['Chelsea-Fc', '44', 'Defensa', 'E. Ampadu', '21', 'WA', '182', '78'],
#  ['Chelsea-Fc', '33', 'Defensa', 'Emerson', '28', 'IT', '176', '63'],
#  ['Chelsea-Fc', '26', 'Defensa', 'K. Koulibaly', '31', 'SN', '187', '80'],
#  ['Chelsea-Fc', '3', 'Defensa', 'M. Alonso', '31', 'ES', '188', '81'],
#  ['Chelsea-Fc', '32', 'Defensa', 'M. Cucurella', '24', 'ES', '173', '68'],
#  ['Chelsea-Fc', '24', 'Defensa', 'R. James', '22', 'GB', '182', '82'],
#  ['Chelsea-Fc', '14', 'Defensa', 'T. Chalobah', '23', 'GB', '190', '80'],
#  ['Chelsea-Fc', '6', 'Defensa', 'Thiago Silva', '37', 'BR', '183', '79'],
#  ['Chelsea-Fc', '35', 'Centrocampista', 'B. Gilmour', '21', 'SS', '170', '66'],
#  ['Chelsea-Fc',
#   '30',
#   'Centrocampista',
#   'C. Chukwuemeka',
#   '18',
#   'GB',
#   '190',
#   '70'],
#  ['Chelsea-Fc',
#   '23',
#   'Centrocampista',
#   'C. Gallagher',
#   '22',
#   'GB',
#   '182',
#   '74'],
#  ['Chelsea-Fc', '22', 'Centrocampista', 'H. Ziyech', '29', 'MA', '180', '70'],
#  ['Chelsea-Fc', '5', 'Centrocampista', 'Jorginho', '30', 'IT', '180', '65'],
#  ['Chelsea-Fc', '29', 'Centrocampista', 'K. Havertz', '23', 'DE', '188', '82'],
#  ['Chelsea-Fc', '23', 'Centrocampista', 'Kenedy', '26', 'BR', '182', '77'],
#  ['Chelsea-Fc',
#   '8',
#   'Centrocampista',
#   'M. KovaÄ\x8diÄ\x87',
#   '28',
#   'HR',
#   '178',
#   '75'],
#  ['Chelsea-Fc', '19', 'Centrocampista', 'M. Mount', '23', 'GB', '178', '64'],
#  ['Chelsea-Fc', '7', 'Centrocampista', 'N. KantÃ©', '31', 'FR', '168', '68'],
#  ['Chelsea-Fc', '18', 'Centrocampista', 'R. Barkley', '28', 'GB', '189', '76'],
#  ['Chelsea-Fc',
#   '12',
#   'Centrocampista',
#   'R. Loftus-Cheek',
#   '26',
#   'GB',
#   '191',
#   '83'],
#  ['Chelsea-Fc', '18', 'Delantero', 'A. Broja', '20', 'AL', '183', '81'],
#  ['Chelsea-Fc', '20', 'Delantero', 'C. Hudson-Odoi', '21', 'GB', '182', '76'],
#  ['Chelsea-Fc', '10', 'Delantero', 'C. Pulisic', '23', 'US', '173', '63'],
#  ['Chelsea-Fc', '30', 'Delantero', 'M. Batshuayi', '28', 'BE', '185', '78'],
#  ['Chelsea-Fc', '17', 'Delantero', 'R. Sterling', '27', 'GB', '170', '69'],
#  ['Brighton-Amp-Hov', '23', 'Portero', 'J. Steele', '31', 'GB', '190', '79'],
#  ['Brighton-Amp-Hov', '16', 'Portero', 'K. Scherpen', '22', 'NL', '202', '85'],
#  ['Brighton-Amp-Hov', '1', 'Portero', 'R. SÃ¡nchez', '24', 'ES', '197', '90'],
#  ['Brighton-Amp-Hov', '4', 'Defensa', 'A. Webster', '27', 'GB', '185', '75'],
#  ['Brighton-Amp-Hov',
#   '29',
#   'Defensa',
#   'J. Van Hecke',
#   '22',
#   'NL',
#   '189',
#   '75'],
#  ['Brighton-Amp-Hov', '34', 'Defensa', 'J. Veltman', '30', 'NL', '182', '73'],
#  ['Brighton-Amp-Hov', '6', 'Defensa', 'L. Colwill', '19', 'GB', '187', '75'],
#  ['Brighton-Amp-Hov', '5', 'Defensa', 'L. Dunk', '30', 'GB', '192', '87'],
#  ['Brighton-Amp-Hov', '26', 'Defensa', 'M. Clarke', '25', 'GB', '180', '70'],
#  ['Brighton-Amp-Hov', '2', 'Defensa', 'T. Lamptey', '21', 'GH', '163', '69'],
#  ['Brighton-Amp-Hov',
#   '14',
#   'Centrocampista',
#   'A. Lallana',
#   '34',
#   'GB',
#   '173',
#   '73'],
#  ['Brighton-Amp-Hov',
#   '10',
#   'Centrocampista',
#   'A. Mac Allister',
#   '23',
#   'AR',
#   '174',
#   '72'],
#  ['Brighton-Amp-Hov',
#   '8',
#   'Centrocampista',
#   'E. Mwepu',
#   '24',
#   'ZM',
#   '184',
#   '77'],
#  ['Brighton-Amp-Hov',
#   '15',
#   'Centrocampista',
#   'J. Moder',
#   '23',
#   'PL',
#   '190',
#   '78'],
#  ['Brighton-Amp-Hov',
#   '19',
#   'Centrocampista',
#   'J. Sarmiento',
#   '20',
#   'EC',
#   '183',
#   '72'],
#  ['Brighton-Amp-Hov',
#   '27',
#   'Centrocampista',
#   'K. Kozlowski',
#   '18',
#   'PL',
#   '177',
#   '67'],
#  ['Brighton-Amp-Hov',
#   '25',
#   'Centrocampista',
#   'MoisÃ©s Caicedo',
#   '20',
#   'EC',
#   '178',
#   '73'],
#  ['Brighton-Amp-Hov',
#   '13',
#   'Centrocampista',
#   'P. Gross',
#   '31',
#   'DE',
#   '181',
#   '72'],
#  ['Brighton-Amp-Hov',
#   '17',
#   'Centrocampista',
#   'S. Alzate',
#   '23',
#   'CO',
#   '177',
#   '65'],
#  ['Brighton-Amp-Hov',
#   '7',
#   'Centrocampista',
#   'S. March',
#   '28',
#   'GB',
#   '185',
#   '77'],
#  ['Brighton-Amp-Hov', '21', 'Delantero', 'D. Undav', '26', 'TR', '178', '85'],
#  ['Brighton-Amp-Hov',
#   '18',
#   'Delantero',
#   'D. Welbeck',
#   '31',
#   'GB',
#   '185',
#   '73'],
#  ['Brighton-Amp-Hov',
#   '28',
#   'Delantero',
#   'E. Ferguson',
#   '17',
#   'IE',
#   '177',
#   '74'],
#  ['Brighton-Amp-Hov', '31', 'Delantero', 'F. Andone', '29', 'RO', '183', '73'],
#  ['Brighton-Amp-Hov', '20', 'Delantero', 'J. Enciso', '18', 'PY', '173', '64'],
#  ['Brighton-Amp-Hov', '22', 'Delantero', 'K. Mitoma', '25', 'JP', '178', '71'],
#  ['Brighton-Amp-Hov',
#   '11',
#   'Delantero',
#   'L. Trossard',
#   '27',
#   'BE',
#   '172',
#   '61'],
#  ['Brighton-Amp-Hov', '9', 'Delantero', 'N. Maupay', '25', 'FR', '171', '69'],
#  ['Aston-Villa-Fc',
#   '1',
#   'Portero',
#   'E. MartÃ\xadnez',
#   '29',
#   'AR',
#   '193',
#   '85'],
#  ['Aston-Villa-Fc', '12', 'Portero', 'J. Steer', '29', 'GB', '182', '80'],
#  ['Aston-Villa-Fc', '25', 'Portero', 'R. Olsen', '32', 'SE', '198', '89'],
#  ['Aston-Villa-Fc', '18', 'Defensa', 'A. Young', '37', 'GB', '175', '65'],
#  ['Aston-Villa-Fc', '16', 'Defensa', 'C. Chambers', '27', 'GB', '182', '66'],
#  ['Aston-Villa-Fc', '3', 'Defensa', 'Diego Carlos', '29', 'BR', '184', '79'],
#  ['Aston-Villa-Fc', '4', 'Defensa', 'E. Konsa', '24', 'GB', '183', '77'],
#  ['Aston-Villa-Fc', '24', 'Defensa', 'F. Guilbert', '27', 'FR', '178', '70'],
#  ['Aston-Villa-Fc', '30', 'Defensa', 'K. Hause', '27', 'GB', '189', '84'],
#  ['Aston-Villa-Fc',
#   '17',
#   'Defensa',
#   'L. Augustinsson',
#   '28',
#   'SE',
#   '181',
#   '74'],
#  ['Aston-Villa-Fc', '27', 'Defensa', 'L. Digne', '29', 'FR', '178', '74'],
#  ['Aston-Villa-Fc', '2', 'Defensa', 'M. Cash', '25', 'PL', '185', '64'],
#  ['Aston-Villa-Fc', '5', 'Defensa', 'T. Mings', '29', 'GB', '191', '80'],
#  ['Aston-Villa-Fc',
#   '44',
#   'Centrocampista',
#   'B. Kamara',
#   '22',
#   'FR',
#   '182',
#   '82'],
#  ['Aston-Villa-Fc',
#   '6',
#   'Centrocampista',
#   'Douglas Luiz',
#   '24',
#   'BR',
#   '178',
#   '65'],
#  ['Aston-Villa-Fc',
#   '7',
#   'Centrocampista',
#   'J. Mcginn',
#   '27',
#   'SS',
#   '175',
#   '68'],
#  ['Aston-Villa-Fc',
#   '41',
#   'Centrocampista',
#   'J. Ramsey',
#   '21',
#   'GB',
#   '180',
#   '70'],
#  ['Aston-Villa-Fc',
#   '19',
#   'Centrocampista',
#   'M. Nakamba',
#   '28',
#   'ZW',
#   '177',
#   '71'],
#  ['Aston-Villa-Fc',
#   '8',
#   'Centrocampista',
#   'M. Sanson',
#   '27',
#   'FR',
#   '182',
#   '70'],
#  ['Aston-Villa-Fc', '21', 'Delantero', 'A. El-Ghazi', '27', 'NL', '188', '76'],
#  ['Aston-Villa-Fc', '15', 'Delantero', 'B. TraorÃ©', '26', 'BF', '177', '72'],
#  ['Aston-Villa-Fc', '35', 'Delantero', 'C. Archer', '20', 'GB', '175', '72'],
#  ['Aston-Villa-Fc', '9', 'Delantero', 'D. Ings', '30', 'GB', '178', '73'],
#  ['Aston-Villa-Fc', '10', 'Delantero', 'E. Buendia', '25', 'AR', '165', '72'],
#  ['Aston-Villa-Fc', '31', 'Delantero', 'L. Bailey', '25', 'JM', '178', '77'],
#  ['Aston-Villa-Fc', '11', 'Delantero', 'O. Watkins', '26', 'GB', '179', '70'],
#  ['Aston-Villa-Fc', '23', 'Delantero', 'P. Coutinho', '30', 'BR', '171', '72'],
#  ['Nottingham-Forest-Fc',
#   '1',
#   'Portero',
#   'D. Henderson',
#   '25',
#   'GB',
#   '188',
#   '85'],
#  ['Nottingham-Forest-Fc',
#   '12',
#   'Portero',
#   'J. Smith',
#   '27',
#   'GB',
#   '183',
#   '75'],
#  ['Nottingham-Forest-Fc',
#   '13',
#   'Portero',
#   'W. Hennessey',
#   '35',
#   'WA',
#   '198',
#   '90'],
#  ['Nottingham-Forest-Fc',
#   '2',
#   'Defensa',
#   'G. Biancone',
#   '22',
#   'FR',
#   '187',
#   '83'],
#  ['Nottingham-Forest-Fc',
#   '15',
#   'Defensa',
#   'H. Toffolo',
#   '26',
#   'GB',
#   '183',
#   '71'],
#  ['Nottingham-Forest-Fc',
#   '4',
#   'Defensa',
#   'J. Worrall',
#   '25',
#   'GB',
#   '190',
#   '64'],
#  ['Nottingham-Forest-Fc',
#   '6',
#   'Defensa',
#   'L. Mbe Soh',
#   '21',
#   'FR',
#   '186',
#   '85'],
#  ['Nottingham-Forest-Fc',
#   '19',
#   'Defensa',
#   'M. NiakhatÃ©',
#   '26',
#   'FR',
#   '175',
#   '75'],
#  ['Nottingham-Forest-Fc',
#   '7',
#   'Defensa',
#   'N. Williams',
#   '21',
#   'WA',
#   '183',
#   '72'],
#  ['Nottingham-Forest-Fc',
#   '40',
#   'Defensa',
#   'O. Hammond',
#   '19',
#   'WA',
#   '179',
#   '64'],
#  ['Nottingham-Forest-Fc',
#   '27',
#   'Defensa',
#   'O. Richards',
#   '24',
#   'GB',
#   '170',
#   '69'],
#  ['Nottingham-Forest-Fc', '3', 'Defensa', 'S. Cook', '31', 'GB', '185', '82'],
#  ['Nottingham-Forest-Fc',
#   '26',
#   'Defensa',
#   'S. McKenna',
#   '25',
#   'SS',
#   '188',
#   '73'],
#  ['Nottingham-Forest-Fc',
#   '20',
#   'Centrocampista',
#   'B. Johnson',
#   '21',
#   'WA',
#   '179',
#   '73'],
#  ['Nottingham-Forest-Fc',
#   '',
#   'Centrocampista',
#   'C. KouyatÃ©',
#   '32',
#   'SN',
#   '189',
#   '74'],
#  ['Nottingham-Forest-Fc',
#   '18',
#   'Centrocampista',
#   'CafÃº',
#   '29',
#   'PT',
#   '185',
#   '82'],
#  ['Nottingham-Forest-Fc',
#   '31',
#   'Centrocampista',
#   'H. Arter',
#   '32',
#   'IE',
#   '178',
#   '73'],
#  ['Nottingham-Forest-Fc',
#   '8',
#   'Centrocampista',
#   'J. Colback',
#   '32',
#   'GB',
#   '175',
#   '72'],
#  ['Nottingham-Forest-Fc',
#   '11',
#   'Centrocampista',
#   'J. Lingard',
#   '29',
#   'GB',
#   '175',
#   '58'],
#  ['Nottingham-Forest-Fc',
#   '14',
#   'Centrocampista',
#   "L. O'Brien",
#   '23',
#   'GB',
#   '173',
#   '63'],
#  ['Nottingham-Forest-Fc',
#   '5',
#   'Centrocampista',
#   'O. Mangala',
#   '24',
#   'BE',
#   '178',
#   '78'],
#  ['Nottingham-Forest-Fc',
#   '22',
#   'Centrocampista',
#   'R. Yates',
#   '24',
#   'GB',
#   '190',
#   '77'],
#  ['Nottingham-Forest-Fc',
#   '17',
#   'Delantero',
#   'A. Mighten',
#   '20',
#   'GB',
#   '171',
#   '71'],
#  ['Nottingham-Forest-Fc',
#   '',
#   'Delantero',
#   'E. Dennis',
#   '24',
#   'NG',
#   '174',
#   '67'],
#  ['Nottingham-Forest-Fc',
#   '23',
#   'Delantero',
#   'J. Lolley',
#   '29',
#   'GB',
#   '178',
#   '72'],
#  ['Nottingham-Forest-Fc',
#   '33',
#   'Delantero',
#   'L. Taylor',
#   '32',
#   'MS',
#   '188',
#   '81'],
#  ['Nottingham-Forest-Fc',
#   '16',
#   'Delantero',
#   'S. Surridge',
#   '24',
#   'GB',
#   '191',
#   '77'],
#  ['Nottingham-Forest-Fc',
#   '9',
#   'Delantero',
#   'T. Awoniyi',
#   '25',
#   'NG',
#   '183',
#   '85'],
#  ['Afc-Bournemouth', '1', 'Portero', 'M. Travers', '23', 'IE', '191', '82'],
#  ['Afc-Bournemouth', '13', 'Portero', 'Neto', '33', 'BR', '190', '84'],
#  ['Afc-Bournemouth', '40', 'Portero', 'W. Dennis', '22', 'GB', '188', '84'],
#  ['Afc-Bournemouth', '15', 'Defensa', 'A. Smith', '31', 'GB', '180', '78'],
#  ['Afc-Bournemouth', '6', 'Defensa', 'C. Mepham', '24', 'WA', '190', '84'],
#  ['Afc-Bournemouth', '23', 'Defensa', 'J. Hill', '20', 'GB', '184', '73'],
#  ['Afc-Bournemouth', '17', 'Defensa', 'J. Stacey', '26', 'GB', '180', '68'],
#  ['Afc-Bournemouth', '33', 'Defensa', 'J. Zemura', '22', 'ZW', '170', '63'],
#  ['Afc-Bournemouth', '5', 'Defensa', 'L. Kelly', '23', 'GB', '178', '70'],
#  ['Afc-Bournemouth', '25', 'Defensa', 'M. Senesi', '25', 'AR', '184', '80'],
#  ['Afc-Bournemouth', '2', 'Defensa', 'R. Fredericks', '29', 'GB', '173', '72'],
#  ['Afc-Bournemouth',
#   '22',
#   'Centrocampista',
#   'B. Pearson',
#   '27',
#   'GB',
#   '166',
#   '71'],
#  ['Afc-Bournemouth',
#   '11',
#   'Centrocampista',
#   'E. Marcondes',
#   '27',
#   'DK',
#   '183',
#   '75'],
#  ['Afc-Bournemouth',
#   '8',
#   'Centrocampista',
#   'J. Lerma',
#   '27',
#   'CO',
#   '179',
#   '70'],
#  ['Afc-Bournemouth',
#   '14',
#   'Centrocampista',
#   'Joe Rothwell',
#   '27',
#   'GB',
#   '185',
#   '77'],
#  ['Afc-Bournemouth',
#   '4',
#   'Centrocampista',
#   'L. Cook',
#   '25',
#   'GB',
#   '175',
#   '66'],
#  ['Afc-Bournemouth',
#   '16',
#   'Centrocampista',
#   'M. Tavernier',
#   '23',
#   'GB',
#   '177',
#   '70'],
#  ['Afc-Bournemouth',
#   '29',
#   'Centrocampista',
#   'P. Billing',
#   '26',
#   'DK',
#   '193',
#   '80'],
#  ['Afc-Bournemouth',
#   '10',
#   'Centrocampista',
#   'R. Christie',
#   '27',
#   'SS',
#   '178',
#   '70'],
#  ['Afc-Bournemouth', '7', 'Delantero', 'D. Brooks', '25', 'WA', '173', '62'],
#  ['Afc-Bournemouth', '9', 'Delantero', 'D. Solanke', '24', 'GB', '182', '75'],
#  ['Afc-Bournemouth', '32', 'Delantero', 'J. Anthony', '22', 'GB', '183', '68'],
#  ['Afc-Bournemouth',
#   '19',
#   'Delantero',
#   'J. Stanislas',
#   '32',
#   'GB',
#   '183',
#   '76'],
#  ['Afc-Bournemouth', '18', 'Delantero', 'Jamal Lowe', '28', 'JM', '183', '79'],
#  ['Afc-Bournemouth', '21', 'Delantero', 'K. Moore', '30', 'WA', '196', '83'],
#  ['Afc-Bournemouth',
#   '20',
#   'Delantero',
#   'S. DembÃ©lÃ©',
#   '25',
#   'SS',
#   '168',
#   '67'],
#  ['Fulham', '17', 'Portero', 'B. Leno', '30', 'DE', '190', '83'],
#  ['Fulham', '1', 'Portero', 'M. Rodak', '25', 'SK', '194', '81'],
#  ['Fulham', '22', 'Portero', 'P. Gazzaniga', '30', 'AR', '196', '90'],
#  ['Fulham', '33', 'Defensa', 'A. Robinson', '25', 'US', '183', '73'],
#  ['Fulham', '31', 'Defensa', 'I. Diop', '25', 'FR', '193', '84'],
#  ['Fulham', '23', 'Defensa', 'J. Bryan', '28', 'GB', '170', '72'],
#  ['Fulham', '27', 'Defensa', 'K. Mbabu', '27', 'CH', '184', '80'],
#  ['Fulham', '2', 'Defensa', 'K. Tete', '26', 'NL', '175', '70'],
#  ['Fulham', '5', 'Defensa', 'S. Duffy', '30', 'IE', '193', '76'],
#  ['Fulham', '', 'Defensa', 'T. Kongolo', '28', 'NL', '183', '70'],
#  ['Fulham', '13', 'Defensa', 'T. Ream', '34', 'US', '185', '72'],
#  ['Fulham', '4', 'Defensa', 'Tosin Adarabioyo', '24', 'GB', '190', '80'],
#  ['Fulham', '18', 'Centrocampista', 'A. Pereira', '26', 'BR', '178', '71'],
#  ['Fulham', '14', 'Centrocampista', 'B. Reid', '29', 'JM', '170', '68'],
#  ['Fulham', '6', 'Centrocampista', 'H. Reed', '27', 'GB', '181', '74'],
#  ['Fulham', '25', 'Centrocampista', 'J. Onomah', '25', 'GB', '180', '78'],
#  ['Fulham', '26', 'Centrocampista', 'J. Palhinha', '27', 'PT', '190', '82'],
#  ['Fulham', '12', 'Centrocampista', 'N. Chalobah', '27', 'GB', '185', '75'],
#  ['Fulham', '10', 'Centrocampista', 'T. Cairney', '31', 'SS', '183', '72'],
#  ['Fulham', '35', 'Centrocampista', 'T. Francois', '22', 'AU', '167', '56'],
#  ['Fulham', '11', 'Delantero', 'A. Knockaert', '30', 'FR', '172', '69'],
#  ['Fulham', '9', 'Delantero', 'A. MitroviÄ\x87', '27', 'RS', '189', '80'],
#  ['Fulham', '8', 'Delantero', 'H. Wilson', '25', 'WA', '173', '70'],
#  ['Fulham', '17', 'Delantero', 'I. Cavaleiro', '28', 'PT', '175', '72'],
#  ['Fulham', '65', 'Delantero', 'J. Stansfield', '19', 'GB', '187', '72'],
#  ['Fulham', '11', 'Delantero', 'M. Solomon', '23', 'IL', '170', '62'],
#  ['Fulham', '7', 'Delantero', 'N. Kebano', '30', 'CD', '170', '65'],
#  ['Fulham', '19', 'Delantero', 'Rodrigo Muniz', '21', 'BR', '182', '79'],
#  ['Liverpool', '13', 'Portero', 'AdriÃ¡n', '35', 'ES', '188', '78'],
#  ['Liverpool', '1', 'Portero', 'Alisson', '29', 'BR', '192', '91'],
#  ['Liverpool', '62', 'Portero', 'C. Kelleher', '23', 'IE', '188', '71'],
#  ['Liverpool', '26', 'Defensa', 'A. Robertson', '28', 'SS', '178', '64'],
#  ['Liverpool', '66', 'Defensa', 'Alexander-Arnold', '23', 'GB', '180', '69'],
#  ['Liverpool', '22', 'Defensa', 'C. Ramsay', '19', 'SS', '177', '68'],
#  ['Liverpool', '5', 'Defensa', 'I. KonatÃ©', '23', 'FR', '194', '95'],
#  ['Liverpool', '32', 'Defensa', 'J. Matip', '31', 'CM', '195', '90'],
#  ['Liverpool', '2', 'Defensa', 'Joe Gomez', '25', 'GB', '188', '77'],
#  ['Liverpool', '21', 'Defensa', 'K. Tsimikas', '26', 'GR', '179', '77'],
#  ['Liverpool', '47', 'Defensa', 'N. Phillips', '25', 'GB', '188', '70'],
#  ['Liverpool', '72', 'Defensa', 'S. Van Den Berg', '20', 'NL', '189', '78'],
#  ['Liverpool', '4', 'Defensa', 'V. Van Dijk', '31', 'NL', '193', '92'],
#  ['Liverpool',
#   '15',
#   'Centrocampista',
#   'A. Oxlade-Chamberlain',
#   '28',
#   'GB',
#   '180',
#   '70'],
#  ['Liverpool', '17', 'Centrocampista', 'C. Jones', '21', 'GB', '185', '75'],
#  ['Liverpool', '28', 'Centrocampista', 'F. Carvalho', '19', 'PT', '170', '58'],
#  ['Liverpool', '3', 'Centrocampista', 'Fabinho', '28', 'BR', '188', '80'],
#  ['Liverpool',
#   '14',
#   'Centrocampista',
#   'J. Henderson',
#   '32',
#   'GB',
#   '184',
#   '67'],
#  ['Liverpool', '7', 'Centrocampista', 'J. Milner', '36', 'GB', '175', '70'],
#  ['Liverpool', '8', 'Centrocampista', 'N. KeÃ¯ta', '27', 'GN', '172', '65'],
#  ['Liverpool', '6', 'Centrocampista', 'Thiago', '31', 'ES', '172', '71'],
#  ['Liverpool', '27', 'Delantero', 'D. NÃºÃ±ez', '23', 'UY', '185', '78'],
#  ['Liverpool', '20', 'Delantero', 'Diogo Jota', '25', 'PT', '178', '70'],
#  ['Liverpool', '19', 'Delantero', 'H. Elliott', '19', 'GB', '170', '68'],
#  ['Liverpool', '23', 'Delantero', 'L. DÃ\xadaz', '25', 'CO', '180', '65'],
#  ['Liverpool', '11', 'Delantero', 'M. Salah', '30', 'EG', '175', '70'],
#  ['Liverpool', '9', 'Delantero', 'R. Firmino', '30', 'BR', '180', '76'],
#  ['Wolverhampton', '1', 'Portero', 'JosÃ© SÃ¡', '29', 'PT', '192', '84'],
#  ['Wolverhampton',
#   '13',
#   'Portero',
#   'M. Å\xa0arkiÄ\x87',
#   '25',
#   'ME',
#   '192',
#   '74'],
#  ['Wolverhampton', '19', 'Defensa', 'Jonny', '28', 'ES', '175', '70'],
#  ['Wolverhampton', '23', 'Defensa', 'M. Kilman', '25', 'GB', '186', '78'],
#  ['Wolverhampton', '4', 'Defensa', 'N. Collins', '21', 'IE', '193', '81'],
#  ['Wolverhampton', '22', 'Defensa', 'N. Semedo', '28', 'PT', '177', '65'],
#  ['Wolverhampton', '3', 'Defensa', 'R. AÃ¯t-Nouri', '21', 'FR', '179', '70'],
#  ['Wolverhampton', '24', 'Defensa', 'Toti Gomes', '23', 'PT', '187', '-'],
#  ['Wolverhampton', '15', 'Defensa', 'W. Boly', '31', 'CI', '191', '81'],
#  ['Wolverhampton', '14', 'Defensa', 'Y. Mosquera', '21', 'CO', '188', '76'],
#  ['Wolverhampton',
#   '6',
#   'Centrocampista',
#   'Bruno JordÃ£o',
#   '23',
#   'PT',
#   '180',
#   '73'],
#  ['Wolverhampton',
#   '25',
#   'Centrocampista',
#   'C. Ronan',
#   '24',
#   'IE',
#   '178',
#   '74'],
#  ['Wolverhampton',
#   '28',
#   'Centrocampista',
#   'JoÃ£o Moutinho',
#   '35',
#   'PT',
#   '171',
#   '61'],
#  ['Wolverhampton',
#   '39',
#   'Centrocampista',
#   'L. Cundle',
#   '20',
#   'GB',
#   '170',
#   '62'],
#  ['Wolverhampton',
#   '32',
#   'Centrocampista',
#   'L. Dendoncker',
#   '27',
#   'BE',
#   '188',
#   '83'],
#  ['Wolverhampton',
#   '18',
#   'Centrocampista',
#   'M. Gibbs-White',
#   '22',
#   'GB',
#   '178',
#   '70'],
#  ['Wolverhampton',
#   '8',
#   'Centrocampista',
#   'RÃºben Neves',
#   '25',
#   'PT',
#   '180',
#   '72'],
#  ['Wolverhampton', '37', 'Delantero', 'A. TraorÃ©', '26', 'ES', '178', '86'],
#  ['Wolverhampton', '20', 'Delantero', 'Chiquinho', '22', 'PT', '179', '72'],
#  ['Wolverhampton', '10', 'Delantero', 'D. Podence', '26', 'PT', '165', '58'],
#  ['Wolverhampton', '17', 'Delantero', 'G. Guedes', '25', 'PT', '179', '73'],
#  ['Wolverhampton',
#   '11',
#   'Delantero',
#   'Hwang Hee-Chan',
#   '26',
#   'KR',
#   '177',
#   '77'],
#  ['Wolverhampton', '', 'Delantero', 'L. Bonatini', '28', 'BR', '184', '82'],
#  ['Wolverhampton', '', 'Delantero', 'P. Cutrone', '24', 'IT', '183', '75'],
#  ['Wolverhampton', '7', 'Delantero', 'P. Neto', '22', 'PT', '173', '62'],
#  ['Wolverhampton', '9', 'Delantero', 'R. JimÃ©nez', '31', 'MX', '187', '76'],
#  ['Leicester-City-Fc', '31', 'Portero', 'D. Iversen', '25', 'DK', '190', '80'],
#  ['Leicester-City-Fc', '1', 'Portero', 'D. Ward', '29', 'WA', '191', '88'],
#  ['Leicester-City-Fc',
#   '4',
#   'Defensa',
#   'C. SÃ¶yÃ¼ncÃ¼',
#   '26',
#   'TR',
#   '187',
#   '80'],
#  ['Leicester-City-Fc', '18', 'Defensa', 'D. Amartey', '27', 'GH', '182', '76'],
#  ['Leicester-City-Fc', '6', 'Defensa', 'J. Evans', '34', 'I1', '188', '77'],
#  ['Leicester-City-Fc', '2', 'Defensa', 'J. Justin', '24', 'GB', '183', '71'],
#  ['Leicester-City-Fc',
#   '23',
#   'Defensa',
#   'J. Vestergaard',
#   '30',
#   'DK',
#   '199',
#   '98'],
#  ['Leicester-City-Fc', '33', 'Defensa', 'L. Thomas', '21', 'GB', '181', '68'],
#  ['Leicester-City-Fc', '5', 'Defensa', 'R. Bertrand', '33', 'GB', '179', '85'],
#  ['Leicester-City-Fc',
#   '21',
#   'Defensa',
#   'Ricardo Pereira',
#   '28',
#   'PT',
#   '175',
#   '70'],
#  ['Leicester-City-Fc',
#   '27',
#   'Defensa',
#   'T. Castagne',
#   '26',
#   'BE',
#   '185',
#   '80'],
#  ['Leicester-City-Fc', '3', 'Defensa', 'W. Fofana', '21', 'FR', '190', '76'],
#  ['Leicester-City-Fc',
#   '42',
#   'Centrocampista',
#   'B. SoumarÃ©',
#   '23',
#   'FR',
#   '189',
#   '82'],
#  ['Leicester-City-Fc',
#   '26',
#   'Centrocampista',
#   'D. Praet',
#   '28',
#   'BE',
#   '181',
#   '78'],
#  ['Leicester-City-Fc',
#   '7',
#   'Centrocampista',
#   'H. Barnes',
#   '24',
#   'GB',
#   '180',
#   '66'],
#  ['Leicester-City-Fc',
#   '10',
#   'Centrocampista',
#   'J. Maddison',
#   '25',
#   'GB',
#   '179',
#   '73'],
#  ['Leicester-City-Fc',
#   '22',
#   'Centrocampista',
#   'K. Dewsbury-Hall',
#   '23',
#   'GB',
#   '177',
#   '70'],
#  ['Leicester-City-Fc',
#   '11',
#   'Centrocampista',
#   'M. Albrighton',
#   '32',
#   'GB',
#   '174',
#   '67'],
#  ['Leicester-City-Fc',
#   '24',
#   'Centrocampista',
#   'N. Mendy',
#   '30',
#   'SN',
#   '168',
#   '68'],
#  ['Leicester-City-Fc',
#   '25',
#   'Centrocampista',
#   'W. Ndidi',
#   '25',
#   'NG',
#   '181',
#   '81'],
#  ['Leicester-City-Fc',
#   '8',
#   'Centrocampista',
#   'Y. Tielemans',
#   '25',
#   'BE',
#   '176',
#   '72'],
#  ['Leicester-City-Fc', '17', 'Delantero', 'Ayoze', '29', 'ES', '172', '66'],
#  ['Leicester-City-Fc', '9', 'Delantero', 'J. Vardy', '35', 'GB', '178', '76'],
#  ['Leicester-City-Fc',
#   '14',
#   'Delantero',
#   'K. Iheanacho',
#   '25',
#   'NG',
#   '187',
#   '77'],
#  ['Leicester-City-Fc', '20', 'Delantero', 'P. Daka', '23', 'ZM', '183', '71'],
#  ['Southampton-Fc', '1', 'Portero', 'A. Mccarthy', '32', 'GB', '193', '79'],
#  ['Southampton-Fc', '31', 'Portero', 'G. Bazunu', '20', 'IE', '189', '79'],
#  ['Southampton-Fc', '30', 'Portero', 'M. Lis', '25', 'PL', '192', '83'],
#  ['Southampton-Fc', '13', 'Portero', 'W. Caballero', '40', 'AR', '185', '83'],
#  ['Southampton-Fc',
#   '37',
#   'Defensa',
#   'A. Bella-Kotchap',
#   '20',
#   'DE',
#   '190',
#   '87'],
#  ['Southampton-Fc', '35', 'Defensa', 'J. Bednarek', '26', 'PL', '190', '77'],
#  ['Southampton-Fc', '5', 'Defensa', 'J. Stephens', '28', 'GB', '185', '84'],
#  ['Southampton-Fc',
#   '2',
#   'Defensa',
#   'K. Walker-Peters',
#   '25',
#   'GB',
#   '173',
#   '69'],
#  ['Southampton-Fc', '4', 'Defensa', 'Lyanco', '25', 'BR', '188', '83'],
#  ['Southampton-Fc', '22', 'Defensa', 'M. Salisu', '23', 'GH', '191', '82'],
#  ['Southampton-Fc', '15', 'Defensa', 'R. Perraud', '24', 'FR', '170', '63'],
#  ['Southampton-Fc', '21', 'Defensa', 'V. Livramento', '19', 'GB', '173', '63'],
#  ['Southampton-Fc', '43', 'Defensa', 'Y. Valery', '23', 'FR', '180', '70'],
#  ['Southampton-Fc',
#   '27',
#   'Centrocampista',
#   'I. Diallo',
#   '23',
#   'FR',
#   '179',
#   '68'],
#  ['Southampton-Fc',
#   '7',
#   'Centrocampista',
#   'J. Aribo',
#   '26',
#   'NG',
#   '182',
#   '76'],
#  ['Southampton-Fc',
#   '8',
#   'Centrocampista',
#   'J. Ward-Prowse',
#   '27',
#   'GB',
#   '173',
#   '66'],
#  ['Southampton-Fc',
#   '6',
#   'Centrocampista',
#   'O. Romeu',
#   '30',
#   'ES',
#   '182',
#   '82'],
#  ['Southampton-Fc',
#   '45',
#   'Centrocampista',
#   'R. Lavia',
#   '18',
#   'BE',
#   '181',
#   '76'],
#  ['Southampton-Fc',
#   '17',
#   'Centrocampista',
#   'S. Armstrong',
#   '30',
#   'SS',
#   '183',
#   '75'],
#  ['Southampton-Fc', '9', 'Delantero', 'A. Armstrong', '25', 'GB', '172', '69'],
#  ['Southampton-Fc', '10', 'Delantero', 'Che Adams', '26', 'SS', '178', '66'],
#  ['Southampton-Fc', '19', 'Delantero', 'M. Djenepo', '24', 'ML', '177', '65'],
#  ['Southampton-Fc',
#   '24',
#   'Delantero',
#   'M. Elyounoussi',
#   '28',
#   'NO',
#   '178',
#   '70'],
#  ['Southampton-Fc', '11', 'Delantero', 'N. Redmond', '28', 'GB', '173', '75'],
#  ['Southampton-Fc', '18', 'Delantero', 'S. Mara', '20', 'FR', '184', '74'],
#  ['Southampton-Fc', '32', 'Delantero', 'T. Walcott', '33', 'GB', '175', '67'],
#  ['Everton-Fc', '15', 'Portero', 'A. BegoviÄ\x87', '35', 'BA', '198', '84'],
#  ['Everton-Fc', '31', 'Portero', 'A. Lonergan', '38', 'GB', '192', '87'],
#  ['Everton-Fc', '1', 'Portero', 'J. Pickford', '28', 'GB', '185', '77'],
#  ['Everton-Fc', '22', 'Defensa', 'B. Godfrey', '24', 'GB', '183', '74'],
#  ['Everton-Fc', '30', 'Defensa', 'C. Coady', '29', 'GB', '184', '75'],
#  ['Everton-Fc', '2', 'Defensa', 'J. Tarkowski', '29', 'GB', '185', '79'],
#  ['Everton-Fc', '4', 'Defensa', 'M. Holgate', '25', 'GB', '181', '63'],
#  ['Everton-Fc', '5', 'Defensa', 'M. Keane', '29', 'GB', '191', '68'],
#  ['Everton-Fc', '18', 'Defensa', 'N. Nkounkou', '21', 'FR', '185', '75'],
#  ['Everton-Fc', '3', 'Defensa', 'N. Patterson', '20', 'SS', '183', '72'],
#  ['Everton-Fc', '29', 'Defensa', 'RÃºben Vinagre', '23', 'PT', '174', '67'],
#  ['Everton-Fc', '23', 'Defensa', 'S. Coleman', '33', 'IE', '178', '67'],
#  ['Everton-Fc', '19', 'Defensa', 'V. Mykolenko', '23', 'UA', '180', '71'],
#  ['Everton-Fc', '13', 'Defensa', 'Y. Mina', '27', 'CO', '195', '94'],
#  ['Everton-Fc',
#   '16',
#   'Centrocampista',
#   'A. Doucoure',
#   '29',
#   'ML',
#   '182',
#   '69'],
#  ['Everton-Fc', '21', 'Centrocampista', 'A. Gomes', '29', 'PT', '188', '83'],
#  ['Everton-Fc', '8', 'Centrocampista', 'A. Onana', '20', 'BE', '188', '67'],
#  ['Everton-Fc', '6', 'Centrocampista', 'Allan', '31', 'BR', '173', '73'],
#  ['Everton-Fc', '20', 'Centrocampista', 'D. Alli', '26', 'GB', '188', '80'],
#  ['Everton-Fc', '25', 'Centrocampista', 'J. Gbamin', '26', 'CI', '186', '83'],
#  ['Everton-Fc', '26', 'Centrocampista', 'T. Davies', '24', 'GB', '180', '70'],
#  ['Everton-Fc', '10', 'Delantero', 'A. Gordon', '21', 'GB', '182', '70'],
#  ['Everton-Fc', '17', 'Delantero', 'A. Iwobi', '26', 'NG', '180', '75'],
#  ['Everton-Fc', '14', 'Delantero', 'A. Townsend', '31', 'GB', '183', '77'],
#  ['Everton-Fc', '9', 'Delantero', 'D. Calvert-Lewin', '25', 'GB', '187', '71'],
#  ['Everton-Fc', '11', 'Delantero', 'D. Gray', '26', 'GB', '183', '75'],
#  ['Everton-Fc', '7', 'Delantero', 'D. McNeil', '22', 'GB', '183', '68'],
#  ['Everton-Fc', '33', 'Delantero', 'S. RondÃ³n', '32', 'VE', '186', '86'],
#  ['Crystal-Palace-Fc', '1', 'Portero', 'J. Butland', '29', 'GB', '193', '95'],
#  ['Crystal-Palace-Fc',
#   '21',
#   'Portero',
#   'S. Johnstone',
#   '29',
#   'GB',
#   '193',
#   '85'],
#  ['Crystal-Palace-Fc', '13', 'Portero', 'V. Guaita', '35', 'ES', '190', '80'],
#  ['Crystal-Palace-Fc',
#   '26',
#   'Defensa',
#   'Chris Richards',
#   '22',
#   'US',
#   '188',
#   '87'],
#  ['Crystal-Palace-Fc',
#   '16',
#   'Defensa',
#   'J. Andersen',
#   '26',
#   'DK',
#   '192',
#   '90'],
#  ['Crystal-Palace-Fc', '5', 'Defensa', 'J. Tomkins', '33', 'GB', '190', '74'],
#  ['Crystal-Palace-Fc', '2', 'Defensa', 'J. Ward', '32', 'GB', '188', '83'],
#  ['Crystal-Palace-Fc', '6', 'Defensa', 'Marc Guehi', '22', 'GB', '182', '82'],
#  ['Crystal-Palace-Fc', '17', 'Defensa', 'N. Clyne', '31', 'GB', '175', '69'],
#  ['Crystal-Palace-Fc',
#   '36',
#   'Defensa',
#   'N. Ferguson',
#   '21',
#   'GB',
#   '181',
#   '70'],
#  ['Crystal-Palace-Fc', '3', 'Defensa', 'T. Mitchell', '22', 'GB', '185', '79'],
#  ['Crystal-Palace-Fc',
#   '28',
#   'Centrocampista',
#   'C. DoucourÃ©',
#   '22',
#   'ML',
#   '180',
#   '73'],
#  ['Crystal-Palace-Fc',
#   '10',
#   'Centrocampista',
#   'E. Eze',
#   '24',
#   'GB',
#   '173',
#   '67'],
#  ['Crystal-Palace-Fc',
#   '18',
#   'Centrocampista',
#   'J. Mcarthur',
#   '34',
#   'SS',
#   '178',
#   '64'],
#  ['Crystal-Palace-Fc',
#   '44',
#   'Centrocampista',
#   'J. Riedewald',
#   '25',
#   'NL',
#   '186',
#   '77'],
#  ['Crystal-Palace-Fc',
#   '15',
#   'Centrocampista',
#   'J. Schlupp',
#   '29',
#   'GH',
#   '178',
#   '72'],
#  ['Crystal-Palace-Fc',
#   '4',
#   'Centrocampista',
#   'L. Milivojevic',
#   '31',
#   'RS',
#   '186',
#   '80'],
#  ['Crystal-Palace-Fc',
#   '7',
#   'Centrocampista',
#   'M. Olise',
#   '20',
#   'FR',
#   '176',
#   '70'],
#  ['Crystal-Palace-Fc',
#   '19',
#   'Centrocampista',
#   'W. Hughes',
#   '27',
#   'GB',
#   '185',
#   '74'],
#  ['Crystal-Palace-Fc', '9', 'Delantero', 'J. Ayew', '30', 'GH', '182', '80'],
#  ['Crystal-Palace-Fc',
#   '14',
#   'Delantero',
#   'J. Mateta',
#   '25',
#   'FR',
#   '190',
#   '84'],
#  ['Crystal-Palace-Fc',
#   '48',
#   'Delantero',
#   'L. Plange',
#   '19',
#   'GB',
#   '183',
#   '76'],
#  ['Crystal-Palace-Fc',
#   '23',
#   'Delantero',
#   'M. Ebiowei',
#   '18',
#   'GB',
#   '185',
#   '80'],
#  ['Crystal-Palace-Fc',
#   '22',
#   'Delantero',
#   'O. Edouard',
#   '24',
#   'FR',
#   '187',
#   '83'],
#  ['Crystal-Palace-Fc', '11', 'Delantero', 'W. Zaha', '29', 'CI', '180', '66'],
#  ['West-Ham-United', '13', 'Portero', 'A. Areola', '29', 'FR', '195', '92'],
#  ['West-Ham-United', '35', 'Portero', 'D. Randolph', '35', 'IE', '185', '78'],
#  ['West-Ham-United', '1', 'Portero', 'L. Fabianski', '37', 'PL', '190', '83'],
#  ['West-Ham-United', '25', 'Portero', 'N. Trott', '23', 'GB', '188', '75'],
#  ['West-Ham-United', '3', 'Defensa', 'A. Cresswell', '32', 'GB', '170', '66'],
#  ['West-Ham-United', '21', 'Defensa', 'A. Ogbonna', '34', 'IT', '191', '86'],
#  ['West-Ham-United', '2', 'Defensa', 'B. Johnson', '22', 'GB', '175', '67'],
#  ['West-Ham-United', '15', 'Defensa', 'C. Dawson', '32', 'GB', '188', '82'],
#  ['West-Ham-United', '50', 'Defensa', 'H. Ashby', '20', 'SS', '179', '72'],
#  ['West-Ham-United', '4', 'Defensa', 'K. Zouma', '27', 'FR', '190', '92'],
#  ['West-Ham-United', '27', 'Defensa', 'N. Aguerd', '26', 'MA', '188', '76'],
#  ['West-Ham-United', '5', 'Defensa', 'V. Coufal', '29', 'CZ', '177', '76'],
#  ['West-Ham-United',
#   '32',
#   'Centrocampista',
#   'C. Coventry',
#   '22',
#   'IE',
#   '180',
#   '70'],
#  ['West-Ham-United',
#   '41',
#   'Centrocampista',
#   'D. Rice',
#   '23',
#   'GB',
#   '185',
#   '80'],
#  ['West-Ham-United',
#   '12',
#   'Centrocampista',
#   'F. Downes',
#   '23',
#   'GB',
#   '172',
#   '70'],
#  ['West-Ham-United',
#   '10',
#   'Centrocampista',
#   'M. Lanzini',
#   '29',
#   'AR',
#   '170',
#   '66'],
#  ['West-Ham-United',
#   '8',
#   'Centrocampista',
#   'P. Fornals',
#   '26',
#   'ES',
#   '178',
#   '67'],
#  ['West-Ham-United',
#   '28',
#   'Centrocampista',
#   'T. Soucek',
#   '27',
#   'CZ',
#   '192',
#   '86'],
#  ['West-Ham-United', '7', 'Delantero', 'G. Scamacca', '23', 'IT', '195', '85'],
#  ['West-Ham-United', '20', 'Delantero', 'J. Bowen', '25', 'GB', '174', '70'],
#  ['West-Ham-United', '9', 'Delantero', 'M. Antonio', '32', 'JM', '180', '81'],
#  ['West-Ham-United', '14', 'Delantero', 'M. Cornet', '25', 'CI', '190', '86'],
#  ['West-Ham-United',
#   '22',
#   'Delantero',
#   'S. Benrahma',
#   '27',
#   'DZ',
#   '172',
#   '67'],
#  ['Manchester-United-Fc',
#   '1',
#   'Portero',
#   'D. De Gea',
#   '31',
#   'ES',
#   '192',
#   '76'],
#  ['Manchester-United-Fc',
#   '22',
#   'Portero',
#   'T. Heaton',
#   '36',
#   'GB',
#   '185',
#   '85'],
#  ['Manchester-United-Fc',
#   '38',
#   'Defensa',
#   'A. Tuanzebe',
#   '24',
#   'GB',
#   '182',
#   '75'],
#  ['Manchester-United-Fc',
#   '29',
#   'Defensa',
#   'A. Wan-Bissaka',
#   '24',
#   'GB',
#   '183',
#   '72'],
#  ['Manchester-United-Fc',
#   '33',
#   'Defensa',
#   'B. Williams',
#   '21',
#   'GB',
#   '180',
#   '63'],
#  ['Manchester-United-Fc',
#   '20',
#   'Defensa',
#   'D. Dalot',
#   '23',
#   'PT',
#   '184',
#   '71'],
#  ['Manchester-United-Fc',
#   '3',
#   'Defensa',
#   'E. Bailly',
#   '28',
#   'CI',
#   '188',
#   '75'],
#  ['Manchester-United-Fc',
#   '5',
#   'Defensa',
#   'H. Maguire',
#   '29',
#   'GB',
#   '194',
#   '79'],
#  ['Manchester-United-Fc', '23', 'Defensa', 'L. Shaw', '27', 'GB', '183', '75'],
#  ['Manchester-United-Fc',
#   '6',
#   'Defensa',
#   'Lisandro MartÃ\xadnez',
#   '24',
#   'AR',
#   '178',
#   '77'],
#  ['Manchester-United-Fc',
#   '4',
#   'Defensa',
#   'Phil Jones',
#   '30',
#   'GB',
#   '185',
#   '71'],
#  ['Manchester-United-Fc',
#   '19',
#   'Defensa',
#   'R. Varane',
#   '29',
#   'FR',
#   '191',
#   '78'],
#  ['Manchester-United-Fc',
#   '12',
#   'Defensa',
#   'T. Malacia',
#   '22',
#   'NL',
#   '173',
#   '67'],
#  ['Manchester-United-Fc',
#   '43',
#   'Defensa',
#   'T. Mengi',
#   '20',
#   'GB',
#   '183',
#   '78'],
#  ['Manchester-United-Fc',
#   '2',
#   'Defensa',
#   'V. LindelÃ¶f',
#   '28',
#   'SE',
#   '187',
#   '80'],
#  ['Manchester-United-Fc',
#   '8',
#   'Centrocampista',
#   'Bruno Fernandes',
#   '27',
#   'PT',
#   '179',
#   '69'],
#  ['Manchester-United-Fc',
#   '14',
#   'Centrocampista',
#   'C. Eriksen',
#   '30',
#   'DK',
#   '181',
#   '71'],
#  ['Manchester-United-Fc',
#   '34',
#   'Centrocampista',
#   'D. Van De Beek',
#   '25',
#   'NL',
#   '184',
#   '73'],
#  ['Manchester-United-Fc',
#   '17',
#   'Centrocampista',
#   'Fred',
#   '29',
#   'BR',
#   '169',
#   '62'],
#  ['Manchester-United-Fc',
#   '46',
#   'Centrocampista',
#   'H. Mejbri',
#   '19',
#   'TN',
#   '184',
#   '70'],
#  ['Manchester-United-Fc',
#   '37',
#   'Centrocampista',
#   'J. Garner',
#   '21',
#   'GB',
#   '182',
#   '75'],
#  ['Manchester-United-Fc',
#   '39',
#   'Centrocampista',
#   'S. Mctominay',
#   '25',
#   'SS',
#   '193',
#   '80'],
#  ['Manchester-United-Fc',
#   '36',
#   'Delantero',
#   'A. Elanga',
#   '20',
#   'SE',
#   '178',
#   '71'],
#  ['Manchester-United-Fc',
#   '49',
#   'Delantero',
#   'A. Garnacho',
#   '18',
#   'AR',
#   '180',
#   '80'],
#  ['Manchester-United-Fc',
#   '9',
#   'Delantero',
#   'A. Martial',
#   '26',
#   'FR',
#   '181',
#   '76'],
#  ['Manchester-United-Fc',
#   '16',
#   'Delantero',
#   'Amad Diallo',
#   '20',
#   'CI',
#   '173',
#   '70'],
#  ['Manchester-United-Fc',
#   '7',
#   'Delantero',
#   'C. Ronaldo',
#   '37',
#   'PT',
#   '185',
#   '80'],
#  ['Manchester-United-Fc',
#   '28',
#   'Delantero',
#   'F. Pellistri',
#   '20',
#   'UY',
#   '174',
#   '65'],
#  ['Manchester-United-Fc',
#   '25',
#   'Delantero',
#   'J. Sancho',
#   '22',
#   'GB',
#   '179',
#   '74'],
#  ['Manchester-United-Fc',
#   '11',
#   'Delantero',
#   'M. Greenwood',
#   '20',
#   'GB',
#   '181',
#   '70'],
#  ['Manchester-United-Fc',
#   '10',
#   'Delantero',
#   'M. Rashford',
#   '24',
#   'GB',
#   '185',
#   '70'],
#  ['Manchester-United-Fc',
#   '47',
#   'Delantero',
#   'S. Shoretire',
#   '18',
#   'GB',
#   '170',
#   '66'],
#  ['Manchester-United-Fc',
#   '44',
#   'Delantero',
#   'T. Chong',
#   '22',
#   'NL',
#   '185',
#   '70']]

# %%
import pandas as pd

# %%
#Expreso como DataFrame
plantillas_df = pd.DataFrame(plantilla_final)
plantillas_df
# Out:
#                         0   1          2             3   4   5    6   7
# 0      Manchester-City-Fc  31    Portero       Ederson  28  BR  188  89
# 1      Manchester-City-Fc  33    Portero     S. Carson  36  GB  183  85
# 2      Manchester-City-Fc  18    Portero     S. Ortega  29  DE  184  86
# 3      Manchester-City-Fc  14    Defensa    A. Laporte  28  ES  189  85
# 4      Manchester-City-Fc        Defensa      B. Mendy  28  FR  185  83
# ..                    ...  ..        ...           ...  ..  ..  ...  ..
# 548  Manchester-United-Fc  25  Delantero     J. Sancho  22  GB  179  74
# 549  Manchester-United-Fc  11  Delantero  M. Greenwood  20  GB  181  70
# 550  Manchester-United-Fc  10  Delantero   M. Rashford  24  GB  185  70
# 551  Manchester-United-Fc  47  Delantero  S. Shoretire  18  GB  170  66
# 552  Manchester-United-Fc  44  Delantero      T. Chong  22  NL  185  70
#
# [553 rows x 8 columns]

# %%
#Nombro columnas
plantillas_df.columns=['equipo','numero','posicion', 'nombre','edad','nacionalidad','altura','peso']

# %%
#establezco índice para evitar conflictos con la base de datos de destino
plantillas_df.set_index('equipo', inplace=True)

# %%
# asigno una columna con el nombre de la liga a la cual pertenece cada jugador
plantillas_df= plantillas_df.assign(Liga= liga)

# %%
plantillas_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 553 entries, Manchester-City-Fc to Manchester-United-Fc
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   numero        553 non-null    object
#  1   posicion      553 non-null    object
#  2   nombre        553 non-null    object
#  3   edad          553 non-null    object
#  4   nacionalidad  553 non-null    object
#  5   altura        553 non-null    object
#  6   peso          553 non-null    object
#  7   Liga          553 non-null    object
# dtypes: object(8)
# memory usage: 38.9+ KB

# %%
plantillas_df
# Out:
#                      numero   posicion        nombre edad nacionalidad altura  \
# equipo
# Manchester-City-Fc       31    Portero       Ederson   28           BR    188
# Manchester-City-Fc       33    Portero     S. Carson   36           GB    183
# Manchester-City-Fc       18    Portero     S. Ortega   29           DE    184
# Manchester-City-Fc       14    Defensa    A. Laporte   28           ES    189
# Manchester-City-Fc             Defensa      B. Mendy   28           FR    185
# ...                     ...        ...           ...  ...          ...    ...
# Manchester-United-Fc     25  Delantero     J. Sancho   22           GB    179
# Manchester-United-Fc     11  Delantero  M. Greenwood   20           GB    181
# Manchester-United-Fc     10  Delantero   M. Rashford   24           GB    185
# Manchester-United-Fc     47  Delantero  S. Shoretire   18           GB    170
# Manchester-United-Fc     44  Delantero      T. Chong   22           NL    185
#
#                      peso     Liga
# equipo
# Manchester-City-Fc     89  premier
# Manchester-City-Fc     85  premier
# Manchester-City-Fc     86  premier
# Manchester-City-Fc     85  premier
# Manchester-City-Fc     83  premier
# ...                   ...      ...
# Manchester-United-Fc   74  premier
# Manchester-United-Fc   70  premier
# Manchester-United-Fc   70  premier
# Manchester-United-Fc   66  premier
# Manchester-United-Fc   70  premier
#
# [553 rows x 8 columns]

# %%
#cambio tipo de datos
plantillas_df['altura'] = pd.to_numeric(plantillas_df['altura'], errors= 'coerce')
plantillas_df['peso'] = pd.to_numeric(plantillas_df['peso'], errors= 'coerce')
plantillas_df['edad'] = pd.to_numeric(plantillas_df['edad'], errors= 'coerce')

# %%
plantillas_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 553 entries, Manchester-City-Fc to Manchester-United-Fc
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   numero        553 non-null    object
#  1   posicion      553 non-null    object
#  2   nombre        553 non-null    object
#  3   edad          553 non-null    int64
#  4   nacionalidad  553 non-null    object
#  5   altura        551 non-null    float64
#  6   peso          550 non-null    float64
#  7   Liga          553 non-null    object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 38.9+ KB

# %%
#Exporto a Exel
with pd.ExcelWriter('plantillas-ligas-jugadores2022-2.xlsx', mode='a', engine ='openpyxl') as writer:
    plantillas_df.to_excel(writer, sheet_name= liga)

# %%
#Exporto a SQL

# %%
pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in c:\users\danie\anaconda3\lib\site-packages (2.9.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine

# %%
cadena_conexion = 'postgres+psycopg2://postgres:2511@localhost:5432/analisis_futbol'

# %%
engine = create_engine(cadena_conexion)

# %%
plantillas_df.to_sql('jugadores',con=engine, if_exists= 'append')
